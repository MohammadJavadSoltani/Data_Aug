# %% [markdown]
# ### Do to high valeus in NANs, prefer to create dataset here :)

# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import re
import warnings
warnings.filterwarnings('ignore')

class RemoteSensingMergeProcessor:
    """
    Pipeline for merging Spectral + GLCM + SAR data and comprehensive NaN preprocessing
    """
    
    def __init__(self):
        self.spectral_gdf = None
        self.glcm_gdf = None
        self.sar_gdf = None
        self.final_gdf = None
        self.nan_report = {}
        
    def load_and_merge_all_data(self, seg_shp, glcm_shp, sar_shp, band_names_file):
        """
        Load and merge all three datasets: Spectral + GLCM + SAR
        """
        print("🚀 STARTING DATA MERGING AND PREPROCESSING PIPELINE")
        print("=" * 80)
        
        # 1. Load Spectral Data
        print("\n1️⃣ LOADING SPECTRAL DATA")
        print("-" * 50)
        print(f"📂 Path: {seg_shp}")
        
        self.spectral_gdf = gpd.read_file(seg_shp)
        print(f"✅ Loaded successfully!")
        print(f"   📊 Segments: {len(self.spectral_gdf)}")
        print(f"   📋 Total columns: {len(self.spectral_gdf.columns)}")
        print(f"   🔢 Band columns: {len([c for c in self.spectral_gdf.columns if c.startswith('_b')])}")
        
        # 2. Map Spectral Band Names
        print(f"\n   🗺️ Mapping spectral band names...")
        self.spectral_gdf = self._map_spectral_names(self.spectral_gdf, band_names_file)
        
        # 3. Load GLCM Data
        print("\n2️⃣ LOADING GLCM DATA")
        print("-" * 50)
        print(f"📂 Path: {glcm_shp}")
        
        self.glcm_gdf = gpd.read_file(glcm_shp)
        print(f"✅ Loaded successfully!")
        print(f"   📊 Segments: {len(self.glcm_gdf)}")
        print(f"   📋 Total columns: {len(self.glcm_gdf.columns)}")
        print(f"   🔲 GLCM columns: {len([c for c in self.glcm_gdf.columns if c.startswith('_b')])}")
        
        # 4. Process GLCM Data
        print(f"\n   🔄 Processing GLCM data...")
        self.glcm_processed = self._process_glcm_data(band_names_file)
        
        # 5. Load SAR Data
        print("\n3️⃣ LOADING SAR DATA")
        print("-" * 50)
        print(f"📂 Path: {sar_shp}")
        
        self.sar_gdf = gpd.read_file(sar_shp)
        print(f"✅ Loaded successfully!")
        print(f"   📊 Segments: {len(self.sar_gdf)}")
        print(f"   📋 Total columns: {len(self.sar_gdf.columns)}")
        print(f"   📶 SAR columns: {len([c for c in self.sar_gdf.columns if c.startswith('_b')])}")
        
        # 6. Map SAR Band Names
        print(f"\n   🗺️ Mapping SAR band names...")
        self.sar_processed = self._map_sar_names(self.sar_gdf, band_names_file)
        
        # 7. Merge All Datasets
        print("\n4️⃣ MERGING ALL DATASETS")
        print("-" * 50)
        self._merge_all_datasets()
        
    def _map_spectral_names(self, seg_gdf, band_names_file):
        """
        Map generic band names to real spectral band names
        """
        with open(band_names_file, 'r') as f:
            all_band_names = [line.strip() for line in f.readlines()]
        
        optical_bands = [name for name in all_band_names if name.startswith('B')]
        print(f"      📡 Found {len(optical_bands)} optical bands in names file")
        
        # Create mapping
        band_name_mapping = {}
        band_cols = [col for col in seg_gdf.columns if col.startswith('_b')]
        
        for i, col in enumerate(band_cols):
            if i < len(optical_bands):
                band_name_mapping[col] = optical_bands[i]
        
        # Rename columns
        seg_gdf_renamed = seg_gdf.rename(columns=band_name_mapping)
        print(f"      ✅ Mapped {len(band_name_mapping)} spectral bands")
        print(f"      📋 Sample: {list(seg_gdf_renamed.columns)[1:6]}")
        
        return seg_gdf_renamed
    
    def _process_glcm_data(self, band_names_file):
        """
        Process GLCM data with proper naming and zero-to-NaN conversion
        """
        # Get spectral dates for mapping
        spectral_dates = []
        for col in self.spectral_gdf.columns:
            if col.startswith('B2_') and '_2024' in col:
                date_str = col.split('_')[1]
                if date_str not in spectral_dates:
                    spectral_dates.append(date_str)
        
        spectral_dates = sorted(spectral_dates)
        print(f"      📅 Found {len(spectral_dates)} unique dates for GLCM mapping")
        
        # GLCM metrics
        glcm_metrics = [
            'Mean', 'Variance', 'Homogeneity',
            'Contrast', 'Dissimilarity', 'Entropy',
            'Second_Moment', 'Correlation'
        ]
        
        # Build GLCM column mapping
        feature_mapping = {}
        glcm_cols = [col for col in self.glcm_gdf.columns if col.startswith('_b')]
        
        variance_variants = ['_varian', '_var', '_variance']
        
        for col in glcm_cols:
            try:
                band_num = int(col.split('_')[1][1:])
                date_idx = ((band_num - 1) // 8)
                metric_idx = (band_num - 1) % 8
                
                if date_idx < len(spectral_dates):
                    date = spectral_dates[date_idx]
                    metric = glcm_metrics[metric_idx]
                    
                    # Determine if it's mean or variance
                    is_variance = any(variant in col for variant in variance_variants)
                    stat_type = 'var' if is_variance else 'mean'
                    
                    feature_mapping[col] = f"GLCM_{date}_{metric}_{stat_type}"
            except:
                continue
        
        # Rename GLCM columns
        glcm_renamed = self.glcm_gdf[['PXLVAL'] + list(feature_mapping.keys())].copy()
        glcm_renamed = glcm_renamed.rename(columns=feature_mapping)
        
        # Convert zeros to NaN (GLCM convention)
        feature_cols = [col for col in glcm_renamed.columns if col != 'PXLVAL']
        total_zeros = 0
        
        for col in feature_cols:
            zero_count = (glcm_renamed[col] == 0).sum()
            total_zeros += zero_count
            glcm_renamed.loc[glcm_renamed[col] == 0, col] = np.nan
        
        print(f"      🔢 Mapped {len(feature_mapping)} GLCM features")
        print(f"      🔄 Converted {total_zeros:,} zeros to NaN")
        print(f"      📋 Sample: {[col for col in glcm_renamed.columns if 'GLCM' in col][:3]}")
        
        return glcm_renamed
    
    def _map_sar_names(self, sar_gdf, band_names_file):
        """
        Map generic SAR band names to real SAR band names
        """
        with open(band_names_file, 'r') as f:
            all_band_names = [line.strip() for line in f.readlines()]
        
        sar_bands = sorted([name for name in all_band_names if name.startswith(('VV_', 'VH_'))])
        print(f"      📶 Found {len(sar_bands)} SAR bands in names file")
        
        # Create SAR mapping
        sar_mapping = {}
        sar_cols = [col for col in sar_gdf.columns if col.startswith('_b')]
        
        for i, col in enumerate(sar_cols):
            if i < len(sar_bands):
                sar_mapping[col] = sar_bands[i]
        
        # Rename SAR columns
        sar_renamed = sar_gdf.rename(columns=sar_mapping)
        
        # Keep only PXLVAL and SAR features
        sar_features = [col for col in sar_renamed.columns if col.startswith(('VV_', 'VH_'))]
        sar_final = sar_renamed[['PXLVAL'] + sar_features]
        
        print(f"      ✅ Mapped {len(sar_mapping)} SAR bands")
        print(f"      📋 Sample: {sar_features[:5]}")
        
        return sar_final
    
    def _merge_all_datasets(self):
        """
        Merge Spectral + GLCM + SAR datasets
        """
        print("   🤝 Merging Spectral + GLCM + SAR datasets...")
        
        # Start with spectral data
        self.final_gdf = self.spectral_gdf.copy()
        
        # Merge GLCM
        self.final_gdf = self.final_gdf.merge(
            self.glcm_processed,
            on='PXLVAL',
            how='left'
        )
        
        # Merge SAR
        self.final_gdf = self.final_gdf.merge(
            self.sar_processed,
            on='PXLVAL',
            how='left'
        )
        
        print(f"   ✅ Merge completed!")
        print(f"      📊 Final shape: {self.final_gdf.shape}")
        
        # Count feature types
        spectral_count = len([c for c in self.final_gdf.columns if re.match(r'B\d+_\d{8}', c)])
        glcm_count = len([c for c in self.final_gdf.columns if 'GLCM' in c])
        sar_count = len([c for c in self.final_gdf.columns if c.startswith(('VV_', 'VH_'))])
        
        print(f"      📡 Spectral bands: {spectral_count}")
        print(f"      🔲 GLCM features: {glcm_count}")
        print(f"      📶 SAR features: {sar_count}")
        print(f"      🔢 Total features: {spectral_count + glcm_count + sar_count}")
        
        # Sort columns chronologically
        self._sort_columns_chronologically()
        
        # Analyze NaN after merge
        self._analyze_nan_values("AFTER_MERGE")
    
    def _sort_columns_chronologically(self):
        """
        Sort columns by date for better organization
        """
        print("   📅 Sorting columns chronologically...")
        
        def get_date_from_column(col):
            # Extract date from various formats
            if '2024' in col:
                parts = col.split('_')
                for part in parts:
                    if part.startswith('2024') and len(part) == 8:
                        return part
            return '99999999'  # Non-date columns go to end
        
        # Separate columns by type
        id_cols = ['PXLVAL']
        geometry_cols = ['geometry'] if 'geometry' in self.final_gdf.columns else []
        date_cols = [col for col in self.final_gdf.columns if '2024' in col]
        other_cols = [col for col in self.final_gdf.columns 
                     if col not in id_cols + geometry_cols + date_cols]
        
        # Sort date columns
        sorted_date_cols = sorted(date_cols, key=get_date_from_column)
        
        # Reorder dataframe
        new_order = id_cols + sorted_date_cols + other_cols + geometry_cols
        self.final_gdf = self.final_gdf[new_order]
        
        print(f"      ✅ Columns sorted chronologically")
        print(f"      📅 Date range: {get_date_from_column(sorted_date_cols[0])} to {get_date_from_column(sorted_date_cols[-1])}")
    
    def _analyze_nan_values(self, stage):
        """
        Comprehensive NaN analysis
        """
        print(f"\n🔍 NaN ANALYSIS - {stage}")
        print("-" * 50)
        
        df = self.final_gdf
        total_cells = df.shape[0] * df.shape[1]
        nan_cells = df.isnull().sum().sum()
        nan_percentage = (nan_cells / total_cells) * 100
        
        print(f"   📊 Dataset shape: {df.shape}")
        print(f"   ❌ Total NaN cells: {nan_cells:,} ({nan_percentage:.2f}%)")
        
        # Analyze by feature type
        feature_types = {
            'Spectral': [c for c in df.columns if re.match(r'B\d+_\d{8}', c)],
            'GLCM': [c for c in df.columns if 'GLCM' in c],
            'SAR': [c for c in df.columns if c.startswith(('VV_', 'VH_'))]
        }
        
        for ftype, cols in feature_types.items():
            if cols:
                type_nan = df[cols].isnull().sum().sum()
                type_cells = len(df) * len(cols)
                type_percentage = (type_nan / type_cells) * 100
                print(f"   🔸 {ftype}: {type_nan:,}/{type_cells:,} NaN ({type_percentage:.2f}%)")
        
        # Find columns with high NaN percentage
        nan_cols = df.isnull().sum()
        high_nan_cols = nan_cols[nan_cols > len(df) * 0.5].sort_values(ascending=False)
        
        if len(high_nan_cols) > 0:
            print(f"   🚨 Columns with >50% NaN: {len(high_nan_cols)}")
            print("   🔝 Top 10 high-NaN columns:")
            for col, count in high_nan_cols.head(10).items():
                percentage = (count / len(df)) * 100
                print(f"      {col[:50]:50}: {count:4d} ({percentage:5.1f}%)")
        else:
            print("   ✅ No columns with >50% NaN values")
        
        self.nan_report[stage] = {
            'total_nan': nan_cells,
            'nan_percentage': nan_percentage,
            'high_nan_columns': len(high_nan_cols)
        }
    
    def preprocess_nan_values(self):
        """
        Comprehensive NaN preprocessing:
        1. Remove columns with >50% NaN
        2. Temporal interpolation (previous/next dates)
        3. Monthly mean filling
        4. Seasonal mean filling
        """
        print("\n5️⃣ COMPREHENSIVE NaN PREPROCESSING")
        print("-" * 50)
        
        # STEP 1: Remove columns with >50% NaN
        print("\n   📊 STEP 1: Removing columns with >50% NaN values")
        
        total_segments = len(self.final_gdf)
        threshold = total_segments * 0.5
        
        # Get all feature columns (exclude PXLVAL and geometry)
        feature_cols = [col for col in self.final_gdf.columns 
                       if col not in ['PXLVAL', 'geometry']]
        
        cols_to_drop = []
        cols_analysis = {'Spectral': 0, 'GLCM': 0, 'SAR': 0, 'Other': 0}
        
        for col in feature_cols:
            nan_count = self.final_gdf[col].isna().sum()
            
            if nan_count > threshold:
                cols_to_drop.append(col)
                
                # Categorize dropped column
                if re.match(r'B\d+_\d{8}', col):
                    cols_analysis['Spectral'] += 1
                    category = 'Spectral'
                elif 'GLCM' in col:
                    cols_analysis['GLCM'] += 1
                    category = 'GLCM'
                elif col.startswith(('VV_', 'VH_')):
                    cols_analysis['SAR'] += 1
                    category = 'SAR'
                else:
                    cols_analysis['Other'] += 1
                    category = 'Other'
                
                print(f"      🗑️ Dropping {category:8} column: {col[:50]:50} ({nan_count:4d}/{total_segments} NaN = {nan_count/total_segments*100:5.1f}%)")
        
        # Drop the columns
        self.final_gdf = self.final_gdf.drop(columns=cols_to_drop)
        
        print(f"\n   ✅ Dropped {len(cols_to_drop)} columns:")
        for ftype, count in cols_analysis.items():
            if count > 0:
                print(f"      🔸 {ftype}: {count} columns")
        
        remaining_features = [col for col in self.final_gdf.columns 
                             if col not in ['PXLVAL', 'geometry']]
        print(f"   📊 Remaining features: {len(remaining_features)}")
        
        # STEP 2: Temporal interpolation
        print(f"\n   🔄 STEP 2: Temporal interpolation (date-wise filling)")
        self._temporal_interpolation(remaining_features)
        
        # STEP 3: Monthly mean filling
        print(f"\n   📅 STEP 3: Monthly mean filling")
        self._monthly_mean_filling(remaining_features)
        
        # STEP 4: Seasonal mean filling
        print(f"\n   🍂 STEP 4: Seasonal mean filling")
        self._seasonal_mean_filling(remaining_features)
        
        # STEP 5: Final cleanup
        print(f"\n   🧹 STEP 5: Final cleanup with overall mean")
        self._final_nan_cleanup(remaining_features)
        
        # Final analysis
        self._analyze_nan_values("AFTER_PREPROCESSING")
    
    def _temporal_interpolation(self, feature_cols):
        """
        Fill NaN values using temporal interpolation (previous/next dates)
        """
        filled_count = 0
        
        for col in tqdm(feature_cols, desc="   Processing temporal interpolation"):
            if not self.final_gdf[col].isna().any():
                continue
            
            try:
                # Extract date from column name
                date_str = None
                if '2024' in col:
                    parts = col.split('_')
                    for part in parts:
                        if part.startswith('2024') and len(part) == 8:
                            date_str = part
                            break
                
                if not date_str:
                    continue
                
                # Find same-type columns from adjacent dates
                base_name = col.replace(date_str, '')
                
                # Find all dates for this feature type
                same_type_cols = [c for c in feature_cols if base_name in c and '2024' in c]
                same_type_dates = []
                
                for c in same_type_cols:
                    parts = c.split('_')
                    for part in parts:
                        if part.startswith('2024') and len(part) == 8:
                            same_type_dates.append((part, c))
                
                same_type_dates = sorted(same_type_dates)
                
                if len(same_type_dates) > 1:
                    # Find adjacent dates
                    current_idx = next((i for i, (d, c) in enumerate(same_type_dates) if c == col), -1)
                    
                    if current_idx >= 0:
                        adjacent_cols = []
                        if current_idx > 0:
                            adjacent_cols.append(same_type_dates[current_idx-1][1])
                        if current_idx < len(same_type_dates) - 1:
                            adjacent_cols.append(same_type_dates[current_idx+1][1])
                        
                        if adjacent_cols:
                            adjacent_mean = self.final_gdf[adjacent_cols].mean(axis=1)
                            before_fill = self.final_gdf[col].isna().sum()
                            self.final_gdf[col] = self.final_gdf[col].fillna(adjacent_mean)
                            after_fill = self.final_gdf[col].isna().sum()
                            filled_count += (before_fill - after_fill)
            
            except Exception as e:
                continue
        
        print(f"      ✅ Filled {filled_count:,} NaN values using temporal interpolation")
    
    def _monthly_mean_filling(self, feature_cols):
        """
        Fill NaN values using monthly mean
        """
        filled_count = 0
        
        for col in tqdm(feature_cols, desc="   Processing monthly mean filling"):
            if not self.final_gdf[col].isna().any():
                continue
            
            try:
                # Extract year-month from column
                date_str = None
                if '2024' in col:
                    parts = col.split('_')
                    for part in parts:
                        if part.startswith('2024') and len(part) == 8:
                            date_str = part
                            break
                
                if not date_str:
                    continue
                
                year_month = date_str[:6]  # YYYYMM
                base_name = col.replace(date_str, '')
                
                # Find all columns from same month and same feature type
                same_month_cols = []
                for c in feature_cols:
                    if base_name in c and year_month in c:
                        same_month_cols.append(c)
                
                if len(same_month_cols) > 1:
                    monthly_mean = self.final_gdf[same_month_cols].mean(axis=1)
                    before_fill = self.final_gdf[col].isna().sum()
                    self.final_gdf[col] = self.final_gdf[col].fillna(monthly_mean)
                    after_fill = self.final_gdf[col].isna().sum()
                    filled_count += (before_fill - after_fill)
            
            except Exception as e:
                continue
        
        print(f"      ✅ Filled {filled_count:,} NaN values using monthly mean")
    
    def _seasonal_mean_filling(self, feature_cols):
        """
        Fill NaN values using seasonal mean (current + adjacent months)
        """
        filled_count = 0
        
        for col in tqdm(feature_cols, desc="   Processing seasonal mean filling"):
            if not self.final_gdf[col].isna().any():
                continue
            
            try:
                # Extract year-month
                date_str = None
                if '2024' in col:
                    parts = col.split('_')
                    for part in parts:
                        if part.startswith('2024') and len(part) == 8:
                            date_str = part
                            break
                
                if not date_str:
                    continue
                
                year = int(date_str[:4])
                month = int(date_str[4:6])
                base_name = col.replace(date_str, '')
                
                # Calculate adjacent months
                prev_month = month - 1 if month > 1 else 12
                next_month = month + 1 if month < 12 else 1
                prev_year = year if month > 1 else year - 1
                next_year = year if month < 12 else year + 1
                
                # Create patterns for current and adjacent months
                patterns = [
                    f"{year}{month:02d}",
                    f"{prev_year}{prev_month:02d}",
                    f"{next_year}{next_month:02d}"
                ]
                
                # Find matching columns
                seasonal_cols = []
                for c in feature_cols:
                    if base_name in c:
                        for pattern in patterns:
                            if pattern in c:
                                seasonal_cols.append(c)
                                break
                
                if len(seasonal_cols) > 1:
                    seasonal_mean = self.final_gdf[seasonal_cols].mean(axis=1)
                    before_fill = self.final_gdf[col].isna().sum()
                    self.final_gdf[col] = self.final_gdf[col].fillna(seasonal_mean)
                    after_fill = self.final_gdf[col].isna().sum()
                    filled_count += (before_fill - after_fill)
            
            except Exception as e:
                continue
        
        print(f"      ✅ Filled {filled_count:,} NaN values using seasonal mean")
    
    def _final_nan_cleanup(self, feature_cols):
        """
        Final cleanup: fill remaining NaN with overall feature mean
        """
        filled_count = 0
        
        for col in feature_cols:
            if self.final_gdf[col].isna().any():
                before_fill = self.final_gdf[col].isna().sum()
                overall_mean = self.final_gdf[col].mean()
                self.final_gdf[col] = self.final_gdf[col].fillna(overall_mean)
                filled_count += before_fill
        
        print(f"      ✅ Filled {filled_count:,} remaining NaN values with overall mean")
    
    def generate_processing_report(self):
        """
        Generate comprehensive processing report
        """
        print("\n" + "=" * 80)
        print("📋 DATA PROCESSING REPORT")
        print("=" * 80)
        
        # Dataset overview
        print(f"\n📊 FINAL DATASET OVERVIEW:")
        print(f"   Total segments: {len(self.final_gdf)}")
        print(f"   Total features: {len(self.final_gdf.columns) - 2}")  # Exclude PXLVAL and geometry
        
        # Feature breakdown
        spectral_count = len([c for c in self.final_gdf.columns if re.match(r'B\d+_\d{8}', c)])
        glcm_count = len([c for c in self.final_gdf.columns if 'GLCM' in c])
        sar_count = len([c for c in self.final_gdf.columns if c.startswith(('VV_', 'VH_'))])
        
        print(f"\n📡 FEATURE BREAKDOWN:")
        print(f"   Spectral bands: {spectral_count}")
        print(f"   GLCM features: {glcm_count}")
        print(f"   SAR features: {sar_count}")
        print(f"   Total features: {spectral_count + glcm_count + sar_count}")
        
        # NaN processing summary
        print(f"\n❌ NaN PROCESSING SUMMARY:")
        for stage, stats in self.nan_report.items():
            print(f"   {stage}: {stats['nan_percentage']:.2f}% NaN values")
        
        # Final verification
        final_nan_count = self.final_gdf.isnull().sum().sum()
        print(f"\n✅ FINAL VERIFICATION:")
        print(f"   Remaining NaN values: {final_nan_count}")
        print(f"   Data quality: {'CLEAN' if final_nan_count == 0 else 'NEEDS ATTENTION'}")
        
        print(f"\n🎯 READY FOR NEXT STEPS:")
        print(f"   ✓ Calculate Vegetation Indices")
        print(f"   ✓ Assign labels")
        print(f"   ✓ Feature engineering")
        print(f"   ✓ Model training")
        
        print("=" * 80)


def main():
    """
    Main execution function for data merging and preprocessing
    """
    # Define paths
    raw_base = r"F:\_____My_Thesies____\_ImpFiles"
    
    seg_shp = os.path.join(raw_base, "3. Feature Selection", "_Sentinel Data", 
                          "2. Divided Data", "6.Segmentation", "Seg_2024", 
                          "1. Opt", "2024_Seg_With_Mean_Opt.shp")
    
    glcm_shp = os.path.join(raw_base, "3. Feature Selection", "_Sentinel Data",
                           "2. Divided Data", "6.Segmentation", "Seg_2024",
                           "4. GLCM", "2024_Seg_With_Mean_GLCM.shp")
    
    sar_shp = os.path.join(raw_base, "3. Feature Selection", "_Sentinel Data",
                          "2. Divided Data", "6.Segmentation", "Seg_2024",
                          "2. SAR", "2024_Seg_With_Mean_SAR.shp")
    
    band_names_file = os.path.join(raw_base, "3. Feature Selection", "_Sentinel Data",
                                  "2. Divided Data", "_Bands_Names", "2024_SR Bands Names.txt")
    
    # Initialize processor
    processor = RemoteSensingMergeProcessor()
    
    # Execute pipeline steps
    print("🎯 Starting comprehensive data merging and preprocessing...")
    
    # Step 1: Load and merge all data
    processor.load_and_merge_all_data(seg_shp, glcm_shp, sar_shp, band_names_file)
    
    # Step 2: Comprehensive NaN preprocessing
    processor.preprocess_nan_values()
    
    # Step 3: Generate final report
    processor.generate_processing_report()
    
    # Return the processed dataset for further use
    return processor.final_gdf

# Execute the pipeline
if __name__ == "__main__":
    print("🚀 EXECUTING REMOTE SENSING DATA PIPELINE")
    print("=" * 80)
    
    try:
        final_dataset = main()
        print(f"\n🎉 SUCCESS! Final dataset shape: {final_dataset.shape}")
        print(f"📊 Dataset ready for vegetation indices calculation and labeling")
        
        # Quick preview of the final dataset
        print(f"\n👀 QUICK PREVIEW:")
        print(f"First 5 columns: {list(final_dataset.columns)[:5]}")
        print(f"Last 5 columns: {list(final_dataset.columns)[-5:]}")
        
        # Sample data check
        feature_cols = [col for col in final_dataset.columns if col not in ['PXLVAL', 'geometry']]
        print(f"\n🔍 DATA QUALITY CHECK:")
        print(f"Total features: {len(feature_cols)}")
        print(f"Any remaining NaN: {final_dataset[feature_cols].isnull().sum().sum()}")
        print(f"Sample values from first feature:")
        print(final_dataset[feature_cols[0]].head())
        
    except Exception as e:
        print(f"❌ ERROR: {str(e)}")
        print("Please check file paths and data integrity")
        
    print("\n" + "=" * 80)
    print("🏁 PIPELINE EXECUTION COMPLETED")
    print("=" * 80)
# Out:
# 🚀 EXECUTING REMOTE SENSING DATA PIPELINE
# ================================================================================
# 🎯 Starting comprehensive data merging and preprocessing...
# 🚀 STARTING DATA MERGING AND PREPROCESSING PIPELINE
# ================================================================================
#
# 1️⃣ LOADING SPECTRAL DATA
# --------------------------------------------------
# 📂 Path: F:\_____My_Thesies____\_ImpFiles\3. Feature Selection\_Sentinel Data\2. Divided Data\6.Segmentation\Seg_2024\1. Opt\2024_Seg_With_Mean_Opt.shp
# ✅ Loaded successfully!
#    📊 Segments: 6311
#    📋 Total columns: 732
#    🔢 Band columns: 730
#
#    🗺️ Mapping spectral band names...
#       📡 Found 730 optical bands in names file
#       ✅ Mapped 730 spectral bands
#       📋 Sample: ['B2_20240105', 'B3_20240105', 'B4_20240105', 'B5_20240105', 'B6_20240105']
#
# 2️⃣ LOADING GLCM DATA
# --------------------------------------------------
# 📂 Path: F:\_____My_Thesies____\_ImpFiles\3. Feature Selection\_Sentinel Data\2. Divided Data\6.Segmentation\Seg_2024\4. GLCM\2024_Seg_With_Mean_GLCM.shp
# ✅ Loaded successfully!
#    📊 Segments: 6311
#    📋 Total columns: 1170
#    🔲 GLCM columns: 1168
#
#    🔄 Processing GLCM data...
#       📅 Found 72 unique dates for GLCM mapping
#       🔢 Mapped 1152 GLCM features
#       🔄 Converted 1,049,619 zeros to NaN
#       📋 Sample: ['GLCM_20240105_Mean_mean', 'GLCM_20240105_Mean_var', 'GLCM_20240105_Variance_mean']
#
# 3️⃣ LOADING SAR DATA
# --------------------------------------------------
# 📂 Path: F:\_____My_Thesies____\_ImpFiles\3. Feature Selection\_Sentinel Data\2. Divided Data\6.Segmentation\Seg_2024\2. SAR\2024_Seg_With_Mean_SAR.shp
# ✅ Loaded successfully!
#    📊 Segments: 6311
#    📋 Total columns: 124
#    📶 SAR columns: 122
#
#    🗺️ Mapping SAR band names...
#       📶 Found 122 SAR bands in names file
#       ✅ Mapped 122 SAR bands
#       📋 Sample: ['VH_20240105', 'VH_20240106', 'VH_20240117', 'VH_20240118', 'VH_20240129']
#
# 4️⃣ MERGING ALL DATASETS
# --------------------------------------------------
#    🤝 Merging Spectral + GLCM + SAR datasets...
#    ✅ Merge completed!
#       📊 Final shape: (6311, 2006)
#       📡 Spectral bands: 657
#       🔲 GLCM features: 1152
#       📶 SAR features: 122
#       🔢 Total features: 1931
#    📅 Sorting columns chronologically...
#       ✅ Columns sorted chronologically
#       📅 Date range: 20240105 to 20241231
#
# 🔍 NaN ANALYSIS - AFTER_MERGE
# --------------------------------------------------
#    📊 Dataset shape: (6311, 2006)
#    ❌ Total NaN cells: 1,858,379 (14.68%)
#    🔸 Spectral: 727,884/4,146,327 NaN (17.55%)
#    🔸 GLCM: 1,049,619/7,270,272 NaN (14.44%)
#    🔸 SAR: 0/769,942 NaN (0.00%)
#    🚨 Columns with >50% NaN: 287
#    🔝 Top 10 high-NaN columns:
#       GLCM_20240224_Mean_mean                           : 6311 (100.0%)
#       GLCM_20240224_Mean_var                            : 6311 (100.0%)
#       GLCM_20240224_Variance_var                        : 6311 (100.0%)
#       GLCM_20240224_Contrast_mean                       : 6311 (100.0%)
#       GLCM_20240224_Entropy_var                         : 6311 (100.0%)
#       GLCM_20240224_Dissimilarity_mean                  : 6311 (100.0%)
#       GLCM_20240224_Dissimilarity_var                   : 6311 (100.0%)
#       GLCM_20240224_Entropy_mean                        : 6311 (100.0%)
#       GLCM_20240224_Contrast_var                        : 6311 (100.0%)
#       GLCM_20240224_Variance_mean                       : 6311 (100.0%)
#
# 5️⃣ COMPREHENSIVE NaN PREPROCESSING
# --------------------------------------------------
#
#    📊 STEP 1: Removing columns with >50% NaN values
#       🗑️ Dropping Spectral column: B2_20240120                                        (3949/6311 NaN =  62.6%)
#       🗑️ Dropping Spectral column: B3_20240120                                        (3949/6311 NaN =  62.6%)
#       🗑️ Dropping Spectral column: B4_20240120                                        (3949/6311 NaN =  62.6%)
#       🗑️ Dropping Spectral column: B5_20240120                                        (3949/6311 NaN =  62.6%)
#       🗑️ Dropping Spectral column: B6_20240120                                        (3949/6311 NaN =  62.6%)
#       🗑️ Dropping Spectral column: B7_20240120                                        (3949/6311 NaN =  62.6%)
#       🗑️ Dropping Spectral column: B8_20240120                                        (3949/6311 NaN =  62.6%)
#       🗑️ Dropping Other    column: B8A_20240120                                       (3949/6311 NaN =  62.6%)
#       🗑️ Dropping Spectral column: B11_20240120                                       (3949/6311 NaN =  62.6%)
#       🗑️ Dropping Spectral column: B12_20240120                                       (3949/6311 NaN =  62.6%)
#       🗑️ Dropping GLCM     column: GLCM_20240120_Mean_mean                            (3853/6311 NaN =  61.1%)
#       🗑️ Dropping GLCM     column: GLCM_20240120_Mean_var                             (3858/6311 NaN =  61.1%)
#       🗑️ Dropping GLCM     column: GLCM_20240120_Variance_mean                        (3854/6311 NaN =  61.1%)
#       🗑️ Dropping GLCM     column: GLCM_20240120_Variance_var                         (3862/6311 NaN =  61.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240120_Homogeneity_var                      (3568/6311 NaN =  56.5%)
#       🗑️ Dropping GLCM     column: GLCM_20240120_Contrast_mean                        (3801/6311 NaN =  60.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240120_Contrast_var                         (3804/6311 NaN =  60.3%)
#       🗑️ Dropping GLCM     column: GLCM_20240120_Dissimilarity_mean                   (3801/6311 NaN =  60.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240120_Dissimilarity_var                    (3805/6311 NaN =  60.3%)
#       🗑️ Dropping GLCM     column: GLCM_20240120_Entropy_mean                         (3801/6311 NaN =  60.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240120_Entropy_var                          (3810/6311 NaN =  60.4%)
#       🗑️ Dropping GLCM     column: GLCM_20240120_Second_Moment_var                    (3578/6311 NaN =  56.7%)
#       🗑️ Dropping GLCM     column: GLCM_20240120_Correlation_var                      (3632/6311 NaN =  57.6%)
#       🗑️ Dropping Spectral column: B2_20240219                                        (3801/6311 NaN =  60.2%)
#       🗑️ Dropping Spectral column: B3_20240219                                        (3801/6311 NaN =  60.2%)
#       🗑️ Dropping Spectral column: B4_20240219                                        (3801/6311 NaN =  60.2%)
#       🗑️ Dropping Spectral column: B5_20240219                                        (3801/6311 NaN =  60.2%)
#       🗑️ Dropping Spectral column: B6_20240219                                        (3801/6311 NaN =  60.2%)
#       🗑️ Dropping Spectral column: B7_20240219                                        (3801/6311 NaN =  60.2%)
#       🗑️ Dropping Spectral column: B8_20240219                                        (3801/6311 NaN =  60.2%)
#       🗑️ Dropping Other    column: B8A_20240219                                       (3801/6311 NaN =  60.2%)
#       🗑️ Dropping Spectral column: B11_20240219                                       (3801/6311 NaN =  60.2%)
#       🗑️ Dropping Spectral column: B12_20240219                                       (3801/6311 NaN =  60.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240219_Mean_mean                            (3668/6311 NaN =  58.1%)
#       🗑️ Dropping GLCM     column: GLCM_20240219_Mean_var                             (3670/6311 NaN =  58.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240219_Variance_mean                        (3668/6311 NaN =  58.1%)
#       🗑️ Dropping GLCM     column: GLCM_20240219_Variance_var                         (3673/6311 NaN =  58.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240219_Homogeneity_var                      (3389/6311 NaN =  53.7%)
#       🗑️ Dropping GLCM     column: GLCM_20240219_Contrast_mean                        (3607/6311 NaN =  57.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240219_Contrast_var                         (3617/6311 NaN =  57.3%)
#       🗑️ Dropping GLCM     column: GLCM_20240219_Dissimilarity_mean                   (3607/6311 NaN =  57.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240219_Dissimilarity_var                    (3615/6311 NaN =  57.3%)
#       🗑️ Dropping GLCM     column: GLCM_20240219_Entropy_mean                         (3607/6311 NaN =  57.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240219_Entropy_var                          (3652/6311 NaN =  57.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240219_Second_Moment_var                    (3431/6311 NaN =  54.4%)
#       🗑️ Dropping GLCM     column: GLCM_20240219_Correlation_var                      (3455/6311 NaN =  54.7%)
#       🗑️ Dropping Spectral column: B2_20240224                                        (6311/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B3_20240224                                        (6311/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B4_20240224                                        (6311/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B5_20240224                                        (6311/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B6_20240224                                        (6311/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B7_20240224                                        (6311/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B8_20240224                                        (6311/6311 NaN = 100.0%)
#       🗑️ Dropping Other    column: B8A_20240224                                       (6311/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B11_20240224                                       (6311/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B12_20240224                                       (6311/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240224_Mean_mean                            (6311/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240224_Mean_var                             (6311/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240224_Variance_mean                        (6311/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240224_Variance_var                         (6311/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240224_Homogeneity_var                      (5961/6311 NaN =  94.5%)
#       🗑️ Dropping GLCM     column: GLCM_20240224_Contrast_mean                        (6311/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240224_Contrast_var                         (6311/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240224_Dissimilarity_mean                   (6311/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240224_Dissimilarity_var                    (6311/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240224_Entropy_mean                         (6311/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240224_Entropy_var                          (6311/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240224_Second_Moment_var                    (5961/6311 NaN =  94.5%)
#       🗑️ Dropping GLCM     column: GLCM_20240224_Correlation_var                      (5961/6311 NaN =  94.5%)
#       🗑️ Dropping Spectral column: B2_20240310                                        (5612/6311 NaN =  88.9%)
#       🗑️ Dropping Spectral column: B3_20240310                                        (5612/6311 NaN =  88.9%)
#       🗑️ Dropping Spectral column: B4_20240310                                        (5612/6311 NaN =  88.9%)
#       🗑️ Dropping Spectral column: B5_20240310                                        (5612/6311 NaN =  88.9%)
#       🗑️ Dropping Spectral column: B6_20240310                                        (5612/6311 NaN =  88.9%)
#       🗑️ Dropping Spectral column: B7_20240310                                        (5612/6311 NaN =  88.9%)
#       🗑️ Dropping Spectral column: B8_20240310                                        (5612/6311 NaN =  88.9%)
#       🗑️ Dropping Other    column: B8A_20240310                                       (5612/6311 NaN =  88.9%)
#       🗑️ Dropping Spectral column: B11_20240310                                       (5612/6311 NaN =  88.9%)
#       🗑️ Dropping Spectral column: B12_20240310                                       (5612/6311 NaN =  88.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240310_Mean_mean                            (5553/6311 NaN =  88.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240310_Mean_var                             (5553/6311 NaN =  88.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240310_Variance_mean                        (5553/6311 NaN =  88.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240310_Variance_var                         (5553/6311 NaN =  88.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240310_Homogeneity_var                      (5238/6311 NaN =  83.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240310_Contrast_mean                        (5526/6311 NaN =  87.6%)
#       🗑️ Dropping GLCM     column: GLCM_20240310_Contrast_var                         (5526/6311 NaN =  87.6%)
#       🗑️ Dropping GLCM     column: GLCM_20240310_Dissimilarity_mean                   (5526/6311 NaN =  87.6%)
#       🗑️ Dropping GLCM     column: GLCM_20240310_Dissimilarity_var                    (5526/6311 NaN =  87.6%)
#       🗑️ Dropping GLCM     column: GLCM_20240310_Entropy_mean                         (5526/6311 NaN =  87.6%)
#       🗑️ Dropping GLCM     column: GLCM_20240310_Entropy_var                          (5547/6311 NaN =  87.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240310_Second_Moment_var                    (5259/6311 NaN =  83.3%)
#       🗑️ Dropping GLCM     column: GLCM_20240310_Correlation_var                      (5273/6311 NaN =  83.6%)
#       🗑️ Dropping Spectral column: B2_20240315                                        (3990/6311 NaN =  63.2%)
#       🗑️ Dropping Spectral column: B3_20240315                                        (3990/6311 NaN =  63.2%)
#       🗑️ Dropping Spectral column: B4_20240315                                        (3990/6311 NaN =  63.2%)
#       🗑️ Dropping Spectral column: B5_20240315                                        (3990/6311 NaN =  63.2%)
#       🗑️ Dropping Spectral column: B6_20240315                                        (3990/6311 NaN =  63.2%)
#       🗑️ Dropping Spectral column: B7_20240315                                        (3990/6311 NaN =  63.2%)
#       🗑️ Dropping Spectral column: B8_20240315                                        (3990/6311 NaN =  63.2%)
#       🗑️ Dropping Other    column: B8A_20240315                                       (3990/6311 NaN =  63.2%)
#       🗑️ Dropping Spectral column: B11_20240315                                       (3990/6311 NaN =  63.2%)
#       🗑️ Dropping Spectral column: B12_20240315                                       (3990/6311 NaN =  63.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240315_Mean_mean                            (3822/6311 NaN =  60.6%)
#       🗑️ Dropping GLCM     column: GLCM_20240315_Mean_var                             (3824/6311 NaN =  60.6%)
#       🗑️ Dropping GLCM     column: GLCM_20240315_Variance_mean                        (3822/6311 NaN =  60.6%)
#       🗑️ Dropping GLCM     column: GLCM_20240315_Variance_var                         (3824/6311 NaN =  60.6%)
#       🗑️ Dropping GLCM     column: GLCM_20240315_Homogeneity_var                      (3559/6311 NaN =  56.4%)
#       🗑️ Dropping GLCM     column: GLCM_20240315_Contrast_mean                        (3754/6311 NaN =  59.5%)
#       🗑️ Dropping GLCM     column: GLCM_20240315_Contrast_var                         (3755/6311 NaN =  59.5%)
#       🗑️ Dropping GLCM     column: GLCM_20240315_Dissimilarity_mean                   (3754/6311 NaN =  59.5%)
#       🗑️ Dropping GLCM     column: GLCM_20240315_Dissimilarity_var                    (3756/6311 NaN =  59.5%)
#       🗑️ Dropping GLCM     column: GLCM_20240315_Entropy_mean                         (3754/6311 NaN =  59.5%)
#       🗑️ Dropping GLCM     column: GLCM_20240315_Entropy_var                          (3772/6311 NaN =  59.8%)
#       🗑️ Dropping GLCM     column: GLCM_20240315_Second_Moment_var                    (3577/6311 NaN =  56.7%)
#       🗑️ Dropping GLCM     column: GLCM_20240315_Correlation_var                      (3650/6311 NaN =  57.8%)
#       🗑️ Dropping Spectral column: B2_20240320                                        (3220/6311 NaN =  51.0%)
#       🗑️ Dropping Spectral column: B3_20240320                                        (3220/6311 NaN =  51.0%)
#       🗑️ Dropping Spectral column: B4_20240320                                        (3220/6311 NaN =  51.0%)
#       🗑️ Dropping Spectral column: B5_20240320                                        (3220/6311 NaN =  51.0%)
#       🗑️ Dropping Spectral column: B6_20240320                                        (3220/6311 NaN =  51.0%)
#       🗑️ Dropping Spectral column: B7_20240320                                        (3220/6311 NaN =  51.0%)
#       🗑️ Dropping Spectral column: B8_20240320                                        (3220/6311 NaN =  51.0%)
#       🗑️ Dropping Other    column: B8A_20240320                                       (3220/6311 NaN =  51.0%)
#       🗑️ Dropping Spectral column: B11_20240320                                       (3220/6311 NaN =  51.0%)
#       🗑️ Dropping Spectral column: B12_20240320                                       (3220/6311 NaN =  51.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240320_Entropy_var                          (3170/6311 NaN =  50.2%)
#       🗑️ Dropping Spectral column: B2_20240325                                        (6235/6311 NaN =  98.8%)
#       🗑️ Dropping Spectral column: B3_20240325                                        (6235/6311 NaN =  98.8%)
#       🗑️ Dropping Spectral column: B4_20240325                                        (6235/6311 NaN =  98.8%)
#       🗑️ Dropping Spectral column: B5_20240325                                        (6235/6311 NaN =  98.8%)
#       🗑️ Dropping Spectral column: B6_20240325                                        (6235/6311 NaN =  98.8%)
#       🗑️ Dropping Spectral column: B7_20240325                                        (6235/6311 NaN =  98.8%)
#       🗑️ Dropping Spectral column: B8_20240325                                        (6235/6311 NaN =  98.8%)
#       🗑️ Dropping Other    column: B8A_20240325                                       (6235/6311 NaN =  98.8%)
#       🗑️ Dropping Spectral column: B11_20240325                                       (6235/6311 NaN =  98.8%)
#       🗑️ Dropping Spectral column: B12_20240325                                       (6235/6311 NaN =  98.8%)
#       🗑️ Dropping GLCM     column: GLCM_20240325_Mean_mean                            (6232/6311 NaN =  98.7%)
#       🗑️ Dropping GLCM     column: GLCM_20240325_Mean_var                             (6232/6311 NaN =  98.7%)
#       🗑️ Dropping GLCM     column: GLCM_20240325_Variance_mean                        (6232/6311 NaN =  98.7%)
#       🗑️ Dropping GLCM     column: GLCM_20240325_Variance_var                         (6232/6311 NaN =  98.7%)
#       🗑️ Dropping GLCM     column: GLCM_20240325_Homogeneity_var                      (5882/6311 NaN =  93.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240325_Contrast_mean                        (6232/6311 NaN =  98.7%)
#       🗑️ Dropping GLCM     column: GLCM_20240325_Contrast_var                         (6232/6311 NaN =  98.7%)
#       🗑️ Dropping GLCM     column: GLCM_20240325_Dissimilarity_mean                   (6232/6311 NaN =  98.7%)
#       🗑️ Dropping GLCM     column: GLCM_20240325_Dissimilarity_var                    (6233/6311 NaN =  98.8%)
#       🗑️ Dropping GLCM     column: GLCM_20240325_Entropy_mean                         (6232/6311 NaN =  98.7%)
#       🗑️ Dropping GLCM     column: GLCM_20240325_Entropy_var                          (6236/6311 NaN =  98.8%)
#       🗑️ Dropping GLCM     column: GLCM_20240325_Second_Moment_var                    (5886/6311 NaN =  93.3%)
#       🗑️ Dropping GLCM     column: GLCM_20240325_Correlation_var                      (5883/6311 NaN =  93.2%)
#       🗑️ Dropping Spectral column: B2_20240424                                        (6245/6311 NaN =  99.0%)
#       🗑️ Dropping Spectral column: B3_20240424                                        (6245/6311 NaN =  99.0%)
#       🗑️ Dropping Spectral column: B4_20240424                                        (6245/6311 NaN =  99.0%)
#       🗑️ Dropping Spectral column: B5_20240424                                        (6245/6311 NaN =  99.0%)
#       🗑️ Dropping Spectral column: B6_20240424                                        (6245/6311 NaN =  99.0%)
#       🗑️ Dropping Spectral column: B7_20240424                                        (6245/6311 NaN =  99.0%)
#       🗑️ Dropping Spectral column: B8_20240424                                        (6245/6311 NaN =  99.0%)
#       🗑️ Dropping Other    column: B8A_20240424                                       (6245/6311 NaN =  99.0%)
#       🗑️ Dropping Spectral column: B11_20240424                                       (6245/6311 NaN =  99.0%)
#       🗑️ Dropping Spectral column: B12_20240424                                       (6245/6311 NaN =  99.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240424_Mean_mean                            (6241/6311 NaN =  98.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240424_Mean_var                             (6241/6311 NaN =  98.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240424_Variance_mean                        (6241/6311 NaN =  98.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240424_Variance_var                         (6241/6311 NaN =  98.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240424_Homogeneity_var                      (5901/6311 NaN =  93.5%)
#       🗑️ Dropping GLCM     column: GLCM_20240424_Contrast_mean                        (6240/6311 NaN =  98.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240424_Contrast_var                         (6240/6311 NaN =  98.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240424_Dissimilarity_mean                   (6240/6311 NaN =  98.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240424_Dissimilarity_var                    (6240/6311 NaN =  98.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240424_Entropy_mean                         (6240/6311 NaN =  98.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240424_Entropy_var                          (6240/6311 NaN =  98.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240424_Second_Moment_var                    (5901/6311 NaN =  93.5%)
#       🗑️ Dropping GLCM     column: GLCM_20240424_Correlation_var                      (5904/6311 NaN =  93.6%)
#       🗑️ Dropping Spectral column: B2_20240504                                        (5541/6311 NaN =  87.8%)
#       🗑️ Dropping Spectral column: B3_20240504                                        (5541/6311 NaN =  87.8%)
#       🗑️ Dropping Spectral column: B4_20240504                                        (5541/6311 NaN =  87.8%)
#       🗑️ Dropping Spectral column: B5_20240504                                        (5541/6311 NaN =  87.8%)
#       🗑️ Dropping Spectral column: B6_20240504                                        (5541/6311 NaN =  87.8%)
#       🗑️ Dropping Spectral column: B7_20240504                                        (5541/6311 NaN =  87.8%)
#       🗑️ Dropping Spectral column: B8_20240504                                        (5541/6311 NaN =  87.8%)
#       🗑️ Dropping Other    column: B8A_20240504                                       (5541/6311 NaN =  87.8%)
#       🗑️ Dropping Spectral column: B11_20240504                                       (5541/6311 NaN =  87.8%)
#       🗑️ Dropping Spectral column: B12_20240504                                       (5541/6311 NaN =  87.8%)
#       🗑️ Dropping GLCM     column: GLCM_20240504_Mean_mean                            (5499/6311 NaN =  87.1%)
#       🗑️ Dropping GLCM     column: GLCM_20240504_Mean_var                             (5500/6311 NaN =  87.1%)
#       🗑️ Dropping GLCM     column: GLCM_20240504_Variance_mean                        (5499/6311 NaN =  87.1%)
#       🗑️ Dropping GLCM     column: GLCM_20240504_Variance_var                         (5500/6311 NaN =  87.1%)
#       🗑️ Dropping GLCM     column: GLCM_20240504_Homogeneity_var                      (5223/6311 NaN =  82.8%)
#       🗑️ Dropping GLCM     column: GLCM_20240504_Contrast_mean                        (5483/6311 NaN =  86.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240504_Contrast_var                         (5483/6311 NaN =  86.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240504_Dissimilarity_mean                   (5483/6311 NaN =  86.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240504_Dissimilarity_var                    (5484/6311 NaN =  86.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240504_Entropy_mean                         (5483/6311 NaN =  86.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240504_Entropy_var                          (5489/6311 NaN =  87.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240504_Second_Moment_var                    (5229/6311 NaN =  82.9%)
#       🗑️ Dropping GLCM     column: GLCM_20240504_Correlation_var                      (5247/6311 NaN =  83.1%)
#       🗑️ Dropping Spectral column: B2_20240623                                        (5340/6311 NaN =  84.6%)
#       🗑️ Dropping Spectral column: B3_20240623                                        (5340/6311 NaN =  84.6%)
#       🗑️ Dropping Spectral column: B4_20240623                                        (5340/6311 NaN =  84.6%)
#       🗑️ Dropping Spectral column: B5_20240623                                        (5340/6311 NaN =  84.6%)
#       🗑️ Dropping Spectral column: B6_20240623                                        (5340/6311 NaN =  84.6%)
#       🗑️ Dropping Spectral column: B7_20240623                                        (5340/6311 NaN =  84.6%)
#       🗑️ Dropping Spectral column: B8_20240623                                        (5340/6311 NaN =  84.6%)
#       🗑️ Dropping Other    column: B8A_20240623                                       (5340/6311 NaN =  84.6%)
#       🗑️ Dropping Spectral column: B11_20240623                                       (5340/6311 NaN =  84.6%)
#       🗑️ Dropping Spectral column: B12_20240623                                       (5340/6311 NaN =  84.6%)
#       🗑️ Dropping GLCM     column: GLCM_20240623_Mean_mean                            (5322/6311 NaN =  84.3%)
#       🗑️ Dropping GLCM     column: GLCM_20240623_Mean_var                             (5325/6311 NaN =  84.4%)
#       🗑️ Dropping GLCM     column: GLCM_20240623_Variance_mean                        (5322/6311 NaN =  84.3%)
#       🗑️ Dropping GLCM     column: GLCM_20240623_Variance_var                         (5328/6311 NaN =  84.4%)
#       🗑️ Dropping GLCM     column: GLCM_20240623_Homogeneity_var                      (5048/6311 NaN =  80.0%)
#       🗑️ Dropping GLCM     column: GLCM_20240623_Contrast_mean                        (5310/6311 NaN =  84.1%)
#       🗑️ Dropping GLCM     column: GLCM_20240623_Contrast_var                         (5316/6311 NaN =  84.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240623_Dissimilarity_mean                   (5310/6311 NaN =  84.1%)
#       🗑️ Dropping GLCM     column: GLCM_20240623_Dissimilarity_var                    (5317/6311 NaN =  84.2%)
#       🗑️ Dropping GLCM     column: GLCM_20240623_Entropy_mean                         (5310/6311 NaN =  84.1%)
#       🗑️ Dropping GLCM     column: GLCM_20240623_Entropy_var                          (5320/6311 NaN =  84.3%)
#       🗑️ Dropping GLCM     column: GLCM_20240623_Second_Moment_var                    (5054/6311 NaN =  80.1%)
#       🗑️ Dropping GLCM     column: GLCM_20240623_Correlation_var                      (5055/6311 NaN =  80.1%)
#       🗑️ Dropping Spectral column: B2_20241026                                        (6156/6311 NaN =  97.5%)
#       🗑️ Dropping Spectral column: B3_20241026                                        (6156/6311 NaN =  97.5%)
#       🗑️ Dropping Spectral column: B4_20241026                                        (6156/6311 NaN =  97.5%)
#       🗑️ Dropping Spectral column: B5_20241026                                        (6156/6311 NaN =  97.5%)
#       🗑️ Dropping Spectral column: B6_20241026                                        (6156/6311 NaN =  97.5%)
#       🗑️ Dropping Spectral column: B7_20241026                                        (6156/6311 NaN =  97.5%)
#       🗑️ Dropping Spectral column: B8_20241026                                        (6156/6311 NaN =  97.5%)
#       🗑️ Dropping Other    column: B8A_20241026                                       (6156/6311 NaN =  97.5%)
#       🗑️ Dropping Spectral column: B11_20241026                                       (6156/6311 NaN =  97.5%)
#       🗑️ Dropping Spectral column: B12_20241026                                       (6156/6311 NaN =  97.5%)
#       🗑️ Dropping GLCM     column: GLCM_20241026_Mean_mean                            (6139/6311 NaN =  97.3%)
#       🗑️ Dropping GLCM     column: GLCM_20241026_Mean_var                             (6139/6311 NaN =  97.3%)
#       🗑️ Dropping GLCM     column: GLCM_20241026_Variance_mean                        (6139/6311 NaN =  97.3%)
#       🗑️ Dropping GLCM     column: GLCM_20241026_Variance_var                         (6139/6311 NaN =  97.3%)
#       🗑️ Dropping GLCM     column: GLCM_20241026_Homogeneity_var                      (5785/6311 NaN =  91.7%)
#       🗑️ Dropping GLCM     column: GLCM_20241026_Contrast_mean                        (6135/6311 NaN =  97.2%)
#       🗑️ Dropping GLCM     column: GLCM_20241026_Contrast_var                         (6135/6311 NaN =  97.2%)
#       🗑️ Dropping GLCM     column: GLCM_20241026_Dissimilarity_mean                   (6135/6311 NaN =  97.2%)
#       🗑️ Dropping GLCM     column: GLCM_20241026_Dissimilarity_var                    (6135/6311 NaN =  97.2%)
#       🗑️ Dropping GLCM     column: GLCM_20241026_Entropy_mean                         (6135/6311 NaN =  97.2%)
#       🗑️ Dropping GLCM     column: GLCM_20241026_Entropy_var                          (6136/6311 NaN =  97.2%)
#       🗑️ Dropping GLCM     column: GLCM_20241026_Second_Moment_var                    (5786/6311 NaN =  91.7%)
#       🗑️ Dropping GLCM     column: GLCM_20241026_Correlation_var                      (5793/6311 NaN =  91.8%)
#       🗑️ Dropping Spectral column: B2_20241031                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B3_20241031                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B4_20241031                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B5_20241031                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B6_20241031                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B7_20241031                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B8_20241031                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Other    column: B8A_20241031                                       (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B11_20241031                                       (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B12_20241031                                       (6308/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20241031_Mean_mean                            (6308/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20241031_Mean_var                             (6308/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20241031_Variance_mean                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20241031_Variance_var                         (6308/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20241031_Homogeneity_var                      (5960/6311 NaN =  94.4%)
#       🗑️ Dropping GLCM     column: GLCM_20241031_Contrast_mean                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20241031_Contrast_var                         (6308/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20241031_Dissimilarity_mean                   (6308/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20241031_Dissimilarity_var                    (6308/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20241031_Entropy_mean                         (6308/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20241031_Entropy_var                          (6308/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20241031_Second_Moment_var                    (5960/6311 NaN =  94.4%)
#       🗑️ Dropping GLCM     column: GLCM_20241031_Correlation_var                      (5960/6311 NaN =  94.4%)
#       🗑️ Dropping Spectral column: B2_20241125                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B3_20241125                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B4_20241125                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B5_20241125                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B6_20241125                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B7_20241125                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B8_20241125                                        (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Other    column: B8A_20241125                                       (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B11_20241125                                       (6308/6311 NaN = 100.0%)
#       🗑️ Dropping Spectral column: B12_20241125                                       (6308/6311 NaN = 100.0%)
#       🗑️ Dropping GLCM     column: GLCM_20241125_Mean_mean                            (6307/6311 NaN =  99.9%)
#       🗑️ Dropping GLCM     column: GLCM_20241125_Mean_var                             (6307/6311 NaN =  99.9%)
#       🗑️ Dropping GLCM     column: GLCM_20241125_Variance_mean                        (6307/6311 NaN =  99.9%)
#       🗑️ Dropping GLCM     column: GLCM_20241125_Variance_var                         (6307/6311 NaN =  99.9%)
#       🗑️ Dropping GLCM     column: GLCM_20241125_Homogeneity_var                      (5957/6311 NaN =  94.4%)
#       🗑️ Dropping GLCM     column: GLCM_20241125_Contrast_mean                        (6307/6311 NaN =  99.9%)
#       🗑️ Dropping GLCM     column: GLCM_20241125_Contrast_var                         (6307/6311 NaN =  99.9%)
#       🗑️ Dropping GLCM     column: GLCM_20241125_Dissimilarity_mean                   (6307/6311 NaN =  99.9%)
#       🗑️ Dropping GLCM     column: GLCM_20241125_Dissimilarity_var                    (6307/6311 NaN =  99.9%)
#       🗑️ Dropping GLCM     column: GLCM_20241125_Entropy_mean                         (6307/6311 NaN =  99.9%)
#       🗑️ Dropping GLCM     column: GLCM_20241125_Entropy_var                          (6307/6311 NaN =  99.9%)
#       🗑️ Dropping GLCM     column: GLCM_20241125_Second_Moment_var                    (5957/6311 NaN =  94.4%)
#       🗑️ Dropping GLCM     column: GLCM_20241125_Correlation_var                      (5958/6311 NaN =  94.4%)
#
#    ✅ Dropped 287 columns:
#       🔸 Spectral: 117 columns
#       🔸 GLCM: 157 columns
#       🔸 Other: 13 columns
#    📊 Remaining features: 1717
#
#    🔄 STEP 2: Temporal interpolation (date-wise filling)
#    Processing temporal interpolation: 100%|██████████| 1717/1717 [00:00<00:00, 1829.21it/s]
#       ✅ Filled 118,600 NaN values using temporal interpolation
#
#    📅 STEP 3: Monthly mean filling
#    Processing monthly mean filling: 100%|██████████| 1717/1717 [00:00<00:00, 4031.53it/s]
#       ✅ Filled 0 NaN values using monthly mean
#
#    🍂 STEP 4: Seasonal mean filling
#    Processing seasonal mean filling: 100%|██████████| 1717/1717 [00:00<00:00, 4833.51it/s]
#       ✅ Filled 0 NaN values using seasonal mean
#
#    🧹 STEP 5: Final cleanup with overall mean
#       ✅ Filled 210,330 remaining NaN values with overall mean
#
# 🔍 NaN ANALYSIS - AFTER_PREPROCESSING
# --------------------------------------------------
#    📊 Dataset shape: (6311, 1719)
#    ❌ Total NaN cells: 0 (0.00%)
#    🔸 Spectral: 0/3,407,940 NaN (0.00%)
#    🔸 GLCM: 0/6,279,445 NaN (0.00%)
#    🔸 SAR: 0/769,942 NaN (0.00%)
#    ✅ No columns with >50% NaN values
#
# ================================================================================
# 📋 DATA PROCESSING REPORT
# ================================================================================
#
# 📊 FINAL DATASET OVERVIEW:
#    Total segments: 6311
#    Total features: 1717
#
# 📡 FEATURE BREAKDOWN:
#    Spectral bands: 540
#    GLCM features: 995
#    SAR features: 122
#    Total features: 1657
#
# ❌ NaN PROCESSING SUMMARY:
#    AFTER_MERGE: 14.68% NaN values
#    AFTER_PREPROCESSING: 0.00% NaN values
#
# ✅ FINAL VERIFICATION:
#    Remaining NaN values: 0
#    Data quality: CLEAN
#
# 🎯 READY FOR NEXT STEPS:
#    ✓ Calculate Vegetation Indices
#    ✓ Assign labels
#    ✓ Feature engineering
#    ✓ Model training
# ================================================================================
#
# 🎉 SUCCESS! Final dataset shape: (6311, 1719)
# 📊 Dataset ready for vegetation indices calculation and labeling
#
# 👀 QUICK PREVIEW:
# First 5 columns: ['PXLVAL', 'B2_20240105', 'B3_20240105', 'B4_20240105', 'B5_20240105']
# Last 5 columns: ['VH_20241230', 'VV_20241230', 'VH_20241231', 'VV_20241231', 'geometry']
#
# 🔍 DATA QUALITY CHECK:
# Total features: 1717
# Any remaining NaN: 0
# Sample values from first feature:
# 0    755.000000
# 1    682.666667
# 2    601.250000
# 3    750.600000
# 4    731.000000
# Name: B2_20240105, dtype: float64
#
# ================================================================================
# 🏁 PIPELINE EXECUTION COMPLETED
# ================================================================================

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import os
from typing import Dict, List, Tuple
import re
from tqdm import tqdm

class VegetationIndicesProcessor:
    """
    Process final dataset to calculate vegetation indices for each date
    """
    
    def __init__(self, final_dataset):
        """
        Initialize with the final merged dataset
        
        Args:
            final_dataset: GeoDataFrame containing merged spectral, GLCM, and SAR data
        """
        self.final_dataset = final_dataset.copy()
        self.spectral_columns = []
        self.date_groups = {}
        self.vi_columns = []
        
    def identify_spectral_bands(self):
        """
        Identify spectral band columns and group them by date
        """
        print("🔍 Identifying spectral bands and dates...")
        
        # Get all column names
        all_columns = self.final_dataset.columns.tolist()
        
        # Filter spectral columns (exclude GLCM and SAR)
        spectral_patterns = [
            r'.*B[2-9].*',  # Blue, Green, Red, NIR bands
            r'.*B1[1-2].*',  # SWIR bands
            r'.*B[5-8]A.*', # Red edge bands
        ]
        
        self.spectral_columns = []
        for col in all_columns:
            for pattern in spectral_patterns:
                if re.match(pattern, col, re.IGNORECASE):
                    # Exclude GLCM and SAR columns
                    if not any(x in col.upper() for x in ['GLCM', 'SAR', 'VV', 'VH']):
                        self.spectral_columns.append(col)
                        break
        
        print(f"📡 Found {len(self.spectral_columns)} spectral columns")
        
        # Extract dates from column names
        date_pattern = r'(\d{4})[-_]?(\d{2})[-_]?(\d{2})'
        
        for col in self.spectral_columns:
            date_match = re.search(date_pattern, col)
            if date_match:
                date_str = f"{date_match.group(1)}-{date_match.group(2)}-{date_match.group(3)}"
                
                if date_str not in self.date_groups:
                    self.date_groups[date_str] = []
                self.date_groups[date_str].append(col)
        
        print(f"📅 Found {len(self.date_groups)} unique dates:")
        for date, bands in self.date_groups.items():
            print(f"   {date}: {len(bands)} bands")
    
    def extract_band_order(self, band_columns: List[str]) -> List[str]:
        """
        Extract and order bands according to Sentinel-2 standard order
        Expected order: B02(Blue), B03(Green), B04(Red), B05(RedEdge1), 
                       B06(RedEdge2), B07(RedEdge3), B08(NIR), B8A(RedEdge4), 
                       B11(SWIR1), B12(SWIR2)
        """
        band_order = ['B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12']
        ordered_bands = []
        
        for band_code in band_order:
            for col in band_columns:
                if band_code in col.upper():
                    ordered_bands.append(col)
                    break
        
        return ordered_bands
    
    def calculate_all_indices(self, image_data: np.ndarray) -> Dict[str, np.ndarray]:
        """
        Calculate 18 vegetation indices from Sentinel-2 bands
        
        Args:
            image_data: Array with shape (10, n_pixels) containing band values
        
        Returns:
            Dictionary of calculated indices
        """
        indices = {}
        
        # Convert to reflectance (assuming input is in DN or already scaled)
        blue = image_data[0] / 10000
        green = image_data[1] / 10000
        red = image_data[2] / 10000
        red_edge1 = image_data[3] / 10000
        red_edge2 = image_data[4] / 10000
        red_edge3 = image_data[5] / 10000
        nir = image_data[6] / 10000
        red_edge4 = image_data[7] / 10000
        swir1 = image_data[8] / 10000
        swir2 = image_data[9] / 10000
        
        L = 0.5  # Soil adjustment factor for SAVI
        
        # Calculate indices with error handling
        try:
            indices['NDVI'] = (nir - red) / (nir + red + 1e-6)
            indices['EVI'] = 2.5 * ((nir - red) / (nir + 6 * red - 7.5 * blue + 1))
            indices['SAVI'] = ((nir - red) / (nir + red + L)) * (1 + L)
            indices['TDVI'] = 1.5 * ((nir - red) / np.sqrt((nir ** 2 + red + 0.5)))
            indices['NDWI'] = (green - nir) / (green + nir + 1e-6)
            indices['2BDA'] = red_edge1 / (red + 1e-6)
            indices['NDCI'] = (red_edge1 - red) / (red_edge1 + red + 1e-6)
            indices['ENDVI'] = ((nir + green) - 2 * blue) / ((nir + green) + 2 * blue + 1e-6)
            indices['GNDVI'] = (nir - green) / (nir + green + 1e-6)
            indices['NDRE'] = (nir - red_edge2) / (nir + red_edge2 + 1e-6)
            indices['GRVI'] = nir / (green + 1e-6)
            indices['MSAVI'] = (2 * nir + 1 - np.sqrt((2 * nir + 1) ** 2 - 8 * (nir - red))) / 2
            indices['LSWI'] = (nir - swir1) / (nir + swir1 + 1e-6)
            indices['NDMI'] = (nir - swir1) / (nir + swir1 + 1e-6)
            indices['MNDWI'] = (green - swir1) / (green + swir1 + 1e-6)
            
            # Calculate MBI first for EMBI calculation
            indices['MBI'] = ((swir1 - swir2 - nir) / (swir1 + swir2 + nir + 1e-6)) + 0.5
            indices['EMBI'] = (indices['MBI'] - indices['MNDWI'] - 0.5) / (indices['MBI'] + indices['MNDWI'] + 1.5)
            
            # MCARI2 with more robust calculation
            sqrt_term = np.sqrt(np.maximum((2 * nir + 1) ** 2 - (6 * nir - 5 * np.sqrt(np.maximum(red, 0) + 1e-6)), 1e-6))
            indices['MCARI2'] = 1.5 * (2.5 * (nir - red) - 1.3 * (nir - green)) / (sqrt_term - 0.5 + 1e-6)
            
        except Exception as e:
            print(f"⚠️ Warning in index calculation: {e}")
            # Fill with NaN if calculation fails
            for key in ['NDVI', 'EVI', 'SAVI', 'TDVI', 'NDWI', '2BDA', 'NDCI', 'ENDVI', 
                       'GNDVI', 'NDRE', 'GRVI', 'MSAVI', 'LSWI', 'NDMI', 'MNDWI', 'MBI', 'EMBI', 'MCARI2']:
                if key not in indices:
                    indices[key] = np.full_like(nir, np.nan)
        
        return indices
    
    def process_vegetation_indices(self):
        """
        Calculate vegetation indices for each date and add to dataset
        """
        print("🌱 Calculating vegetation indices for each date...")
        
        final_dataset_with_vis = self.final_dataset.copy()
        
        for date, band_columns in tqdm(self.date_groups.items(), desc="Processing dates"):
            print(f"\n📅 Processing date: {date}")
            
            # Order bands correctly
            ordered_bands = self.extract_band_order(band_columns)
            
            if len(ordered_bands) < 10:
                print(f"⚠️ Warning: Only {len(ordered_bands)} bands found for {date}, skipping...")
                continue
            
            print(f"   Using bands: {[col.split('_')[-1] if '_' in col else col for col in ordered_bands[:5]]}...")
            
            # Extract band data for all segments
            try:
                band_data = []
                for band_col in ordered_bands[:10]:  # Use first 10 ordered bands
                    if band_col in self.final_dataset.columns:
                        band_data.append(self.final_dataset[band_col].values)
                    else:
                        print(f"⚠️ Warning: Band {band_col} not found")
                        band_data.append(np.zeros(len(self.final_dataset)))
                
                # Convert to numpy array: shape (n_bands, n_segments)
                band_array = np.array(band_data)
                
                # Calculate indices for all segments at once
                indices_dict = self.calculate_all_indices(band_array)
                
                # Add indices to dataset with date prefix
                for idx_name, idx_values in indices_dict.items():
                    col_name = f"{idx_name}_{date}"
                    final_dataset_with_vis[col_name] = idx_values
                    self.vi_columns.append(col_name)
                    
            except Exception as e:
                print(f"❌ Error processing date {date}: {e}")
                continue
        
        self.final_dataset_with_vis = final_dataset_with_vis
        print(f"\n✅ Added {len(self.vi_columns)} vegetation index columns")
    
    def generate_summary_report(self):
        """
        Generate comprehensive summary of the enhanced dataset
        """
        print("\n" + "="*80)
        print("📋 ENHANCED DATASET SUMMARY REPORT")
        print("="*80)
        
        total_features = len(self.final_dataset_with_vis.columns) - 1  # Exclude geometry
        
        print(f"📊 FINAL ENHANCED DATASET:")
        print(f"   Total segments: {len(self.final_dataset_with_vis)}")
        print(f"   Total features: {total_features}")
        
        print(f"\n📡 FEATURE BREAKDOWN:")
        print(f"   Spectral bands: {len(self.spectral_columns)}")
        print(f"   Vegetation indices: {len(self.vi_columns)}")
        
        # Count other features
        glcm_features = len([col for col in self.final_dataset_with_vis.columns if 'GLCM' in col.upper()])
        sar_features = len([col for col in self.final_dataset_with_vis.columns if any(x in col.upper() for x in ['SAR', 'VV', 'VH'])])
        
        print(f"   GLCM features: {glcm_features}")
        print(f"   SAR features: {sar_features}")
        
        print(f"\n🌱 VEGETATION INDICES BY DATE:")
        dates_with_vis = list(set([col.split('_')[0] for col in self.vi_columns]))
        for date in sorted(dates_with_vis):
            date_vis = [col for col in self.vi_columns if col.startswith(date)]
            print(f"   {date}: {len(date_vis)} indices")
        
        print(f"\n✅ DATA QUALITY:")
        nan_count = self.final_dataset_with_vis.isnull().sum().sum()
        print(f"   Total NaN values: {nan_count}")
        print(f"   Data completeness: {((total_features * len(self.final_dataset_with_vis) - nan_count) / (total_features * len(self.final_dataset_with_vis)) * 100):.2f}%")
    

# Main execution function
def enhance_dataset_with_vegetation_indices(final_dataset, output_base_path):
    """
    Main function to enhance dataset with vegetation indices
    
    Args:
        final_dataset: The merged GeoDataFrame from previous processing
        output_base_path: Base path for saving enhanced dataset
    
    Returns:
        Enhanced GeoDataFrame with vegetation indices
    """
    
    print("🚀 Starting vegetation indices enhancement...")
    
    # Initialize processor
    processor = VegetationIndicesProcessor(final_dataset)
    
    # Step 1: Identify spectral bands and dates
    processor.identify_spectral_bands()
    
    # Step 2: Calculate vegetation indices
    processor.process_vegetation_indices()
    
    # Step 3: Generate summary report
    processor.generate_summary_report()
    
    print(f"\n🎉 Enhancement complete!")
    
    return processor.final_dataset_with_vis

# Execute the enhancement
if __name__ == "__main__":
    # Assuming final_dataset is available from previous processing
    output_path = r"F:\_____My_Thesies____\Implimantation\3.Train_Model\_Base_Data"
    
    # Enhance dataset with vegetation indices
    final_dataset_with_VIs = enhance_dataset_with_vegetation_indices(final_dataset, output_path)
    
    print("\n✅ Dataset enhancement completed successfully!")
    print(f"Enhanced dataset shape: {final_dataset_with_VIs.shape}")
# Out:
# 🚀 Starting vegetation indices enhancement...
# 🔍 Identifying spectral bands and dates...
# 📡 Found 600 spectral columns
# 📅 Found 59 unique dates:
#    2024-01-05: 10 bands
#    2024-01-10: 10 bands
#    2024-01-25: 10 bands
#    2024-01-30: 10 bands
#    2024-02-04: 10 bands
#    2024-02-09: 10 bands
#    2024-02-14: 10 bands
#    2024-02-29: 10 bands
#    2024-03-05: 10 bands
#    2024-03-30: 10 bands
#    2024-04-04: 10 bands
#    2024-04-09: 10 bands
#    2024-04-14: 10 bands
#    2024-04-19: 10 bands
#    2024-04-29: 10 bands
#    2024-05-09: 10 bands
#    2024-05-14: 10 bands
#    2024-05-19: 10 bands
#    2024-05-24: 10 bands
#    2024-05-29: 10 bands
#    2024-06-03: 10 bands
#    2024-06-08: 10 bands
#    2024-06-13: 10 bands
#    2024-06-18: 10 bands
#    2024-06-28: 10 bands
#    2024-07-03: 10 bands
#    2024-07-08: 10 bands
#    2024-07-13: 10 bands
#    2024-07-18: 10 bands
#    2024-07-23: 10 bands
#    2024-07-28: 10 bands
#    2024-08-02: 10 bands
#    2024-08-07: 10 bands
#    2024-08-12: 10 bands
#    2024-08-17: 10 bands
#    2024-08-22: 10 bands
#    2024-08-27: 10 bands
#    2024-09-01: 10 bands
#    2024-09-06: 10 bands
#    2024-09-11: 10 bands
#    2024-09-16: 10 bands
#    2024-09-21: 10 bands
#    2024-09-26: 10 bands
#    2024-10-01: 10 bands
#    2024-10-06: 10 bands
#    2024-10-11: 10 bands
#    2024-10-16: 10 bands
#    2024-10-21: 10 bands
#    2024-11-05: 10 bands
#    2024-11-10: 10 bands
#    2024-11-15: 10 bands
#    2024-11-20: 10 bands
#    2024-11-30: 10 bands
#    2024-12-05: 10 bands
#    2024-12-10: 10 bands
#    2024-12-15: 20 bands
#    2024-12-20: 10 bands
#    2024-12-25: 10 bands
#    2024-12-30: 10 bands
# 🌱 Calculating vegetation indices for each date...
# Processing dates:  17%|█▋        | 10/59 [00:00<00:00, 90.66it/s]
# 📅 Processing date: 2024-01-05
#    Using bands: ['20240105', '20240105', '20240105', '20240105', '20240105']...
#
# 📅 Processing date: 2024-01-10
#    Using bands: ['20240110', '20240110', '20240110', '20240110', '20240110']...
#
# 📅 Processing date: 2024-01-25
#    Using bands: ['20240125', '20240125', '20240125', '20240125', '20240125']...
#
# 📅 Processing date: 2024-01-30
#    Using bands: ['20240130', '20240130', '20240130', '20240130', '20240130']...
#
# 📅 Processing date: 2024-02-04
#    Using bands: ['20240204', '20240204', '20240204', '20240204', '20240204']...
#
# 📅 Processing date: 2024-02-09
#    Using bands: ['20240209', '20240209', '20240209', '20240209', '20240209']...
#
# 📅 Processing date: 2024-02-14
#    Using bands: ['20240214', '20240214', '20240214', '20240214', '20240214']...
#
# 📅 Processing date: 2024-02-29
#    Using bands: ['20240229', '20240229', '20240229', '20240229', '20240229']...
#
# 📅 Processing date: 2024-03-05
#    Using bands: ['20240305', '20240305', '20240305', '20240305', '20240305']...
#
# 📅 Processing date: 2024-03-30
#    Using bands: ['20240330', '20240330', '20240330', '20240330', '20240330']...
#
# 📅 Processing date: 2024-04-04
#    Using bands: ['20240404', '20240404', '20240404', '20240404', '20240404']...
#
# 📅 Processing date: 2024-04-09
#    Using bands: ['20240409', '20240409', '20240409', '20240409', '20240409']...
#
# 📅 Processing date: 2024-04-14
#    Using bands: ['20240414', '20240414', '20240414', '20240414', '20240414']...
#
# 📅 Processing date: 2024-04-19
#    Using bands: ['20240419', '20240419', '20240419', '20240419', '20240419']...
#
# 📅 Processing date: 2024-04-29
#    Using bands: ['20240429', '20240429', '20240429', '20240429', '20240429']...
#
# 📅 Processing date: 2024-05-09
#    Using bands: ['20240509', '20240509', '20240509', '20240509', '20240509']...
# Processing dates:  34%|███▍      | 20/59 [00:00<00:00, 74.11it/s]
# 📅 Processing date: 2024-05-14
#    Using bands: ['20240514', '20240514', '20240514', '20240514', '20240514']...
#
# 📅 Processing date: 2024-05-19
#    Using bands: ['20240519', '20240519', '20240519', '20240519', '20240519']...
#
# 📅 Processing date: 2024-05-24
#    Using bands: ['20240524', '20240524', '20240524', '20240524', '20240524']...
#
# 📅 Processing date: 2024-05-29
#    Using bands: ['20240529', '20240529', '20240529', '20240529', '20240529']...
#
# 📅 Processing date: 2024-06-03
#    Using bands: ['20240603', '20240603', '20240603', '20240603', '20240603']...
#
# 📅 Processing date: 2024-06-08
#    Using bands: ['20240608', '20240608', '20240608', '20240608', '20240608']...
#
# 📅 Processing date: 2024-06-13
#    Using bands: ['20240613', '20240613', '20240613', '20240613', '20240613']...
#
# 📅 Processing date: 2024-06-18
#    Using bands: ['20240618', '20240618', '20240618', '20240618', '20240618']...
#
# 📅 Processing date: 2024-06-28
#    Using bands: ['20240628', '20240628', '20240628', '20240628', '20240628']...
#
# 📅 Processing date: 2024-07-03
#    Using bands: ['20240703', '20240703', '20240703', '20240703', '20240703']...
#
# 📅 Processing date: 2024-07-08
#    Using bands: ['20240708', '20240708', '20240708', '20240708', '20240708']...
#
# 📅 Processing date: 2024-07-13
#    Using bands: ['20240713', '20240713', '20240713', '20240713', '20240713']...
# Processing dates:  47%|████▋     | 28/59 [00:00<00:00, 67.93it/s]
# 📅 Processing date: 2024-07-18
#    Using bands: ['20240718', '20240718', '20240718', '20240718', '20240718']...
# Processing dates:  59%|█████▉    | 35/59 [00:00<00:00, 63.66it/s]
# 📅 Processing date: 2024-07-23
#    Using bands: ['20240723', '20240723', '20240723', '20240723', '20240723']...
#
# 📅 Processing date: 2024-07-28
#    Using bands: ['20240728', '20240728', '20240728', '20240728', '20240728']...
#
# 📅 Processing date: 2024-08-02
#    Using bands: ['20240802', '20240802', '20240802', '20240802', '20240802']...
#
# 📅 Processing date: 2024-08-07
#    Using bands: ['20240807', '20240807', '20240807', '20240807', '20240807']...
#
# 📅 Processing date: 2024-08-12
#    Using bands: ['20240812', '20240812', '20240812', '20240812', '20240812']...
#
# 📅 Processing date: 2024-08-17
#    Using bands: ['20240817', '20240817', '20240817', '20240817', '20240817']...
#
# 📅 Processing date: 2024-08-22
#    Using bands: ['20240822', '20240822', '20240822', '20240822', '20240822']...
#
# 📅 Processing date: 2024-08-27
#    Using bands: ['20240827', '20240827', '20240827', '20240827', '20240827']...
#
# 📅 Processing date: 2024-09-01
#    Using bands: ['20240901', '20240901', '20240901', '20240901', '20240901']...
#
# 📅 Processing date: 2024-09-06
#    Using bands: ['20240906', '20240906', '20240906', '20240906', '20240906']...
#
# 📅 Processing date: 2024-09-11
#    Using bands: ['20240911', '20240911', '20240911', '20240911', '20240911']...
#
# 📅 Processing date: 2024-09-16
#    Using bands: ['20240916', '20240916', '20240916', '20240916', '20240916']...
#
# 📅 Processing date: 2024-09-21
#    Using bands: ['20240921', '20240921', '20240921', '20240921', '20240921']...
# Processing dates:  83%|████████▎ | 49/59 [00:00<00:00, 57.05it/s]
# 📅 Processing date: 2024-09-26
#    Using bands: ['20240926', '20240926', '20240926', '20240926', '20240926']...
#
# 📅 Processing date: 2024-10-01
#    Using bands: ['20241001', '20241001', '20241001', '20241001', '20241001']...
#
# 📅 Processing date: 2024-10-06
#    Using bands: ['20241006', '20241006', '20241006', '20241006', '20241006']...
#
# 📅 Processing date: 2024-10-11
#    Using bands: ['20241011', '20241011', '20241011', '20241011', '20241011']...
#
# 📅 Processing date: 2024-10-16
#    Using bands: ['20241016', '20241016', '20241016', '20241016', '20241016']...
#
# 📅 Processing date: 2024-10-21
#    Using bands: ['20241021', '20241021', '20241021', '20241021', '20241021']...
#
# 📅 Processing date: 2024-11-05
#    Using bands: ['20241105', '20241105', '20241105', '20241105', '20241105']...
#
# 📅 Processing date: 2024-11-10
#    Using bands: ['20241110', '20241110', '20241110', '20241110', '20241110']...
#
# 📅 Processing date: 2024-11-15
#    Using bands: ['20241115', '20241115', '20241115', '20241115', '20241115']...
#
# 📅 Processing date: 2024-11-20
#    Using bands: ['20241120', '20241120', '20241120', '20241120', '20241120']...
#
# 📅 Processing date: 2024-11-30
#    Using bands: ['20241130', '20241130', '20241130', '20241130', '20241130']...
# Processing dates:  93%|█████████▎| 55/59 [00:00<00:00, 55.48it/s]
# 📅 Processing date: 2024-12-05
#    Using bands: ['20241205', '20241205', '20241205', '20241205', '20241205']...
#
# 📅 Processing date: 2024-12-10
#    Using bands: ['20241210', '20241210', '20241210', '20241210', '20241210']...
#
# 📅 Processing date: 2024-12-15
#    Using bands: ['20241215', '20241215', '20241215', '20241215', '20241215']...
#
# 📅 Processing date: 2024-12-20
#    Using bands: ['20241220', '20241220', '20241220', '20241220', '20241220']...
#
# 📅 Processing date: 2024-12-25
#    Using bands: ['20241225', '20241225', '20241225', '20241225', '20241225']...
#
# 📅 Processing date: 2024-12-30
#    Using bands: ['20241230', '20241230', '20241230', '20241230', '20241230']...
# Processing dates: 100%|██████████| 59/59 [00:01<00:00, 57.46it/s]
# ✅ Added 1062 vegetation index columns
#
# ================================================================================
# 📋 ENHANCED DATASET SUMMARY REPORT
# ================================================================================
# 📊 FINAL ENHANCED DATASET:
#    Total segments: 6311
#    Total features: 2780
#
# 📡 FEATURE BREAKDOWN:
#    Spectral bands: 600
#    Vegetation indices: 1062
#    GLCM features: 995
#    SAR features: 122
#
# 🌱 VEGETATION INDICES BY DATE:
#    2BDA: 59 indices
#    EMBI: 59 indices
#    ENDVI: 59 indices
#    EVI: 59 indices
#    GNDVI: 59 indices
#    GRVI: 59 indices
#    LSWI: 59 indices
#    MBI: 59 indices
#    MCARI2: 59 indices
#    MNDWI: 59 indices
#    MSAVI: 59 indices
#    NDCI: 59 indices
#    NDMI: 59 indices
#    NDRE: 59 indices
#    NDVI: 59 indices
#    NDWI: 59 indices
#    SAVI: 59 indices
#    TDVI: 59 indices
#
# ✅ DATA QUALITY:
#    Total NaN values: 0
#    Data completeness: 100.00%
#
# 🎉 Enhancement complete!
#
# ✅ Dataset enhancement completed successfully!
# Enhanced dataset shape: (6311, 2781)

# %% [markdown]
# ## Labellize data, and Variance check for Feature Eng.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
from typing import Dict, List, Tuple
import warnings
warnings.filterwarnings('ignore')

class FeatureEngineeringAnalyzer:
    """
    Comprehensive feature engineering and variance analysis for remote sensing data
    """
    
    def __init__(self, final_dataset_with_vis):
        """
        Initialize with the enhanced dataset containing vegetation indices
        
        Args:
            final_dataset_with_vis: GeoDataFrame with all features including VIs
        """
        self.final_dataset = final_dataset_with_vis.copy()
        self.labeled_dataset = None
        self.reference_gdf = None
        self.feature_groups = {
            'Spectral': [],
            'SAR': [],
            'VIs': [],
            'GLCM': []
        }
        self.compactness_scores = {}
        
    def load_reference_shapefile(self, ref_shp_path: str):
        """
        Load reference shapefile for labeling
        
        Args:
            ref_shp_path: Path to reference shapefile
        """
        print(f"📂 Loading reference shapefile: {ref_shp_path}")
        
        try:
            self.reference_gdf = gpd.read_file(ref_shp_path)
            print(f"✅ Reference shapefile loaded")
            print(f"   Columns: {list(self.reference_gdf.columns)}")
            print(f"   Number of polygons: {len(self.reference_gdf)}")
            print(f"   Unique classes in 'layer': {self.reference_gdf['layer'].unique()}")
            
            return True
            
        except Exception as e:
            print(f"❌ Error loading reference shapefile: {e}")
            return False
    
    def label_segments_with_reference(self):
        """
        Label segments using the reference shapefile with spatial intersection,
        then apply post-processing to merge or remove specific classes.
        """
        print("🏷️ Starting segment labeling process...")

        if self.reference_gdf is None:
            print("❌ Reference shapefile not loaded!")
            return False

        # Initialize labeling columns
        segments_gdf = self.final_dataset.copy()
        segments_gdf['label'] = 'Unlabeled'
        segments_gdf['layer'] = 'Unknown'

        # Tracking variables
        iou_values = {}
        over_segmentation_values = []
        weighted_iou_values = []
        eliminated_polygons = []

        print(f"🔄 Processing {len(self.reference_gdf)} reference polygons...")

        for ref_idx, ref_row in self.reference_gdf.iterrows():
            ref_geom = ref_row.geometry
            ref_label = ref_row.get("Name", f"Ref_{ref_idx}")
            ref_layer = ref_row.get("layer", "Unknown")
            ref_area = ref_geom.area

            if ref_idx % 50 == 0:
                print(f"   Processing reference polygon {ref_idx + 1}/{len(self.reference_gdf)}")

            try:
                intersecting_segments = segments_gdf[segments_gdf.geometry.intersects(ref_geom)].copy()

                if intersecting_segments.empty:
                    eliminated_polygons.append(ref_idx)
                    iou_values[ref_idx] = 0
                    continue

                # Calculate intersection metrics
                intersecting_segments["intersection_area"] = intersecting_segments.geometry.apply(
                    lambda seg: seg.intersection(ref_geom).area if seg.is_valid and ref_geom.is_valid else 0
                )
                intersecting_segments["segment_area"] = intersecting_segments.geometry.area
                intersecting_segments["overlap_ratio"] = (
                    intersecting_segments["intersection_area"] /
                    intersecting_segments["segment_area"].replace(0, np.inf)
                )

                # Find significant overlaps (>50% of segment area)
                significant_segments = intersecting_segments[intersecting_segments["overlap_ratio"] > 0.5]
                over_segmentation_values.append(len(significant_segments))

                if not significant_segments.empty:
                    for idx in significant_segments.index:
                        segments_gdf.at[idx, 'label'] = ref_label
                        segments_gdf.at[idx, 'layer'] = ref_layer

                    try:
                        combined_geometry = significant_segments.geometry.union_all()
                        intersection_area = combined_geometry.intersection(ref_geom).area
                        union_area = combined_geometry.union(ref_geom).area
                        iou = intersection_area / union_area if union_area > 0 else 0
                        iou_values[ref_idx] = iou
                        weighted_iou_values.append(iou * ref_area)
                    except:
                        iou_values[ref_idx] = 0

                else:
                    most_representative = intersecting_segments.loc[
                        intersecting_segments["intersection_area"].idxmax()
                    ]
                    idx = most_representative.name
                    segments_gdf.at[idx, 'label'] = ref_label
                    segments_gdf.at[idx, 'layer'] = ref_layer

                    try:
                        intersection_area = most_representative.geometry.intersection(ref_geom).area
                        union_area = most_representative.geometry.union(ref_geom).area
                        iou = intersection_area / union_area if union_area > 0 else 0
                        iou_values[ref_idx] = iou
                        weighted_iou_values.append(iou * ref_area)
                    except:
                        iou_values[ref_idx] = 0

            except Exception as e:
                print(f"⚠️ Error processing reference polygon {ref_idx}: {e}")
                eliminated_polygons.append(ref_idx)
                iou_values[ref_idx] = 0
                continue

        # ===== POST-PROCESSING: Merge & Remove classes =====
        print("\n🔧 Applying post-processing to layers...")
        merge_wetland = ["Mixed_TP-polygon", "Tamarix-polygon"]
        remove_classes = ["Plowed-polygon"]

        # Merge Wetland_Vegs
        segments_gdf.loc[segments_gdf['layer'].isin(merge_wetland), 'layer'] = "Wetland_Vegs"
        # Remove unwanted classes
        before_count = len(segments_gdf)
        segments_gdf = segments_gdf[~segments_gdf['layer'].isin(remove_classes)]
        after_count = len(segments_gdf)
        print(f"   Removed {before_count - after_count} segments belonging to {remove_classes}")

        self.labeled_dataset = segments_gdf

        # ===== STATS =====
        print("\n📊 LABELING RESULTS:")
        print(f"   Total segments: {len(segments_gdf)}")
        print(f"   Labeled segments: {len(segments_gdf[segments_gdf['label'] != 'Unlabeled'])}")
        print(f"   Unlabeled segments: {len(segments_gdf[segments_gdf['label'] == 'Unlabeled'])}")
        print(f"   Average IoU: {np.mean(list(iou_values.values())):.3f}")
        print(f"   Eliminated reference polygons: {len(eliminated_polygons)}")

        print("\n🏷️ CLASS DISTRIBUTION:")
        class_counts = segments_gdf['layer'].value_counts()
        for class_name, count in class_counts.items():
            print(f"   {class_name}: {count} segments")

        return True

    
    def categorize_features(self):
        """
        Categorize features into different groups for analysis
        """
        print("🔍 Categorizing features...")
        
        if self.labeled_dataset is None:
            print("❌ Dataset not labeled yet!")
            return False
        
        # Get all feature columns (exclude geometry and label columns)
        exclude_cols = ['geometry', 'label', 'layer']
        feature_columns = [col for col in self.labeled_dataset.columns if col not in exclude_cols]
        
        # Categorize features
        for col in feature_columns:
            col_upper = col.upper()
            
            # Check for vegetation indices (contains date pattern and VI name)
            vi_names = ['NDVI', 'EVI', 'SAVI', 'TDVI', 'NDWI', '2BDA', 'NDCI', 'ENDVI', 
                       'GNDVI', 'NDRE', 'GRVI', 'MSAVI', 'LSWI', 'NDMI', 'MNDWI', 
                       'MBI', 'EMBI', 'MCARI2']
            
            if any(vi in col_upper for vi in vi_names):
                self.feature_groups['VIs'].append(col)
            elif 'GLCM' in col_upper:
                self.feature_groups['GLCM'].append(col)
            elif any(x in col_upper for x in ['SAR', 'VV', 'VH']):
                self.feature_groups['SAR'].append(col)
            elif any(band in col_upper for band in ['B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12']):
                self.feature_groups['Spectral'].append(col)
        
        print(f"📊 FEATURE CATEGORIZATION:")
        for group, features in self.feature_groups.items():
            print(f"   {group}: {len(features)} features")
        
        return True
    
    def calculate_feature_compactness(self, feature_col: str) -> float:
        """
        Calculate compactness score for a feature across classes
        
        Args:
            feature_col: Name of the feature column
            
        Returns:
            Average compactness score (lower is better for class separation)
        """
        if self.labeled_dataset is None:
            return np.inf
        
        # Get labeled data only
        labeled_data = self.labeled_dataset[self.labeled_dataset['label'] != 'Unlabeled'].copy()
        
        if len(labeled_data) == 0:
            return np.inf
        
        compactness_values = []
        
        for class_name in labeled_data['layer'].unique():
            if class_name == 'Unknown':
                continue
                
            class_data = labeled_data[labeled_data['layer'] == class_name][feature_col].dropna()
            
            if len(class_data) > 1:
                # Calculate 5th and 95th percentiles for compactness
                q5, q95 = np.percentile(class_data, [5, 95])
                compactness_values.append(q95 - q5)
        
        return np.mean(compactness_values) if compactness_values else np.inf
    
    def plot_feature_variance_analysis(self, feature_group: str = None, max_features: int = 20):
        """
        Plot variance analysis for features
        
        Args:
            feature_group: Which group to plot ('Spectral', 'SAR', 'VIs', 'GLCM', or None for all)
            max_features: Maximum number of features to plot at once
        """
        if self.labeled_dataset is None:
            print("❌ Dataset not labeled yet!")
            return
        
        # Get labeled data only
        labeled_data = self.labeled_dataset[self.labeled_dataset['label'] != 'Unlabeled'].copy()
        
        if len(labeled_data) == 0:
            print("❌ No labeled data available for plotting!")
            return
        
        # Select features to plot
        if feature_group and feature_group in self.feature_groups:
            features_to_plot = self.feature_groups[feature_group][:max_features]
            title_prefix = f"{feature_group} Features"
        else:
            # Plot all features (limited to max_features)
            all_features = []
            for group, features in self.feature_groups.items():
                all_features.extend(features)
            features_to_plot = all_features[:max_features]
            title_prefix = "All Features"
        
        if not features_to_plot:
            print(f"❌ No features found for group: {feature_group}")
            return
        
        print(f"📈 Plotting variance analysis for {len(features_to_plot)} {title_prefix.lower()}...")
        
        # Create color palette for classes
        unique_classes = labeled_data['layer'].unique()
        colors = plt.cm.Set3(np.linspace(0, 1, len(unique_classes)))
        palette = dict(zip(unique_classes, colors))
        
        # Set plotting style
        sns.set(style="whitegrid", font="Arial", font_scale=1.0)
        
        # Calculate compactness for all features
        compactness_scores = {}
        
        for col in features_to_plot:
            if col not in labeled_data.columns:
                continue
                
            try:
                plt.figure(figsize=(12, 6))
                
                # Plot stripplot
                sns.stripplot(y="layer", x=col, hue="layer", data=labeled_data,
                             palette=palette, jitter=True, alpha=0.7, dodge=False, legend=False)
                
                # Calculate and plot compactness lines
                compactness_values = []
                for class_name in unique_classes:
                    if class_name == 'Unknown':
                        continue
                        
                    class_data = labeled_data[labeled_data['layer'] == class_name][col].dropna()
                    
                    if len(class_data) > 1:
                        q5, q95 = np.percentile(class_data, [5, 95])
                        plt.hlines(y=class_name, xmin=q5, xmax=q95, 
                                  color="red", linewidth=2, alpha=0.8)
                        compactness_values.append(q95 - q5)
                
                avg_compactness = np.mean(compactness_values) if compactness_values else np.inf
                compactness_scores[col] = avg_compactness
                
                # Formatting
                plt.title(f"{col}\n(Compactness = {avg_compactness:.4f})", fontsize=12)
                plt.ylabel("Land Cover Class", fontsize=11)
                plt.xlabel("Feature Value", fontsize=11)
                plt.grid(True, linestyle="--", alpha=0.5)
                plt.tight_layout()
                plt.show()
                
            except Exception as e:
                print(f"⚠️ Error plotting {col}: {e}")
                continue
        
        # Store compactness scores
        self.compactness_scores.update(compactness_scores)
        
        # Print sorted compactness scores
        print(f"\n🔍 {title_prefix} - Compactness Scores (lower = better separation):")
        sorted_scores = sorted(compactness_scores.items(), key=lambda x: x[1])
        for feature, score in sorted_scores:
            print(f"   {feature:<40} {score:.4f}")
    
    def analyze_all_feature_groups(self, max_per_group: int = 15):
        """
        Analyze all feature groups sequentially
        
        Args:
            max_per_group: Maximum features to analyze per group
        """
        print("🚀 Starting comprehensive feature variance analysis...")
        
        for group_name in ['Spectral', 'SAR', 'VIs', 'GLCM']:
            if self.feature_groups[group_name]:
                print(f"\n{'='*60}")
                print(f"📊 ANALYZING {group_name.upper()} FEATURES")
                print(f"{'='*60}")
                self.plot_feature_variance_analysis(group_name, max_per_group)
            else:
                print(f"⚠️ No {group_name} features found in dataset")
    
    def get_best_features_by_group(self, top_n: int = 10) -> Dict[str, List[str]]:
        """
        Get best features by compactness score for each group
        
        Args:
            top_n: Number of top features to return per group
            
        Returns:
            Dictionary with best features for each group
        """
        best_features = {}
        
        for group_name, features in self.feature_groups.items():
            if not features:
                continue
                
            # Get compactness scores for this group
            group_scores = {f: score for f, score in self.compactness_scores.items() if f in features}
            
            # Sort by compactness (lower is better)
            sorted_features = sorted(group_scores.items(), key=lambda x: x[1])
            best_features[group_name] = [f[0] for f in sorted_features[:top_n]]
        
        return best_features

# Main execution function
def run_feature_engineering_analysis(final_dataset_with_vis, ref_shp_path):
    """
    Run complete feature engineering analysis
    
    Args:
        final_dataset_with_vis: Enhanced dataset with vegetation indices
        ref_shp_path: Path to reference shapefile for labeling
    
    Returns:
        FeatureEngineeringAnalyzer instance
    """
    print("🎯 Starting Feature Engineering Analysis Pipeline...")
    
    # Initialize analyzer
    analyzer = FeatureEngineeringAnalyzer(final_dataset_with_vis)
    
    # Step 1: Load reference shapefile
    if not analyzer.load_reference_shapefile(ref_shp_path):
        print("❌ Failed to load reference shapefile!")
        return None
    
    # Step 2: Label segments
    if not analyzer.label_segments_with_reference():
        print("❌ Failed to label segments!")
        return None
    
    # Step 3: Categorize features
    if not analyzer.categorize_features():
        print("❌ Failed to categorize features!")
        return None
    
    print("\n✅ Setup complete! Ready for variance analysis.")
    print("\nTo analyze features, use:")
    print("analyzer.analyze_all_feature_groups()")
    print("or for specific groups:")
    print("analyzer.plot_feature_variance_analysis('Spectral')")
    print("analyzer.plot_feature_variance_analysis('VIs')")
    print("analyzer.plot_feature_variance_analysis('GLCM')")
    print("analyzer.plot_feature_variance_analysis('SAR')")
    
    return analyzer

# Execute the analysis
if __name__ == "__main__":
    # Define paths
    raw_base = r"F:\_____My_Thesies____\_ImpFiles"
    ref_shp = os.path.join(raw_base, "2.Segments", "_Final_Reference_Combined", "Ref_2024.shp")
    
    # Run analysis (assuming final_dataset_with_VIs is available)
    analyzer = run_feature_engineering_analysis(final_dataset_with_VIs, ref_shp)
    
    if analyzer:
        print("🎉 Feature Engineering Analysis setup completed successfully!")
        print("Use 'analyzer' object to perform variance analysis.")
# Out:
# 🎯 Starting Feature Engineering Analysis Pipeline...
# 📂 Loading reference shapefile: F:\_____My_Thesies____\_ImpFiles\2.Segments\_Final_Reference_Combined\Ref_2024.shp
# ✅ Reference shapefile loaded
#    Columns: ['fid_1', 'Name', 'descriptio', 'layer', 'path', 'Feature_ID', 'Area', 'geometry']
#    Number of polygons: 206
#    Unique classes in 'layer': ['Wheat-polygon' 'Rice-polygon' 'Clover-polygon' 'Alfalfa-polygon'
#  'Corn-polygon' 'Sugar_Beet-polygon' 'Urban-polygon' 'Plowed-polygon'
#  'Phragmites-polygon' 'Degreed_Wetland_Poly-polygon' 'Tamarix-polygon'
#  'Mixed_TP-polygon' 'Bare-polygon']
# 🏷️ Starting segment labeling process...
# 🔄 Processing 206 reference polygons...
#    Processing reference polygon 1/206
#    Processing reference polygon 51/206
#    Processing reference polygon 101/206
#    Processing reference polygon 151/206
#    Processing reference polygon 201/206
#
# 🔧 Applying post-processing to layers...
#    Removed 2 segments belonging to ['Plowed-polygon']
#
# 📊 LABELING RESULTS:
#    Total segments: 6309
#    Labeled segments: 452
#    Unlabeled segments: 5857
#    Average IoU: 0.483
#    Eliminated reference polygons: 0
#
# 🏷️ CLASS DISTRIBUTION:
#    Unknown: 5857 segments
#    Rice-polygon: 150 segments
#    Wheat-polygon: 144 segments
#    Bare-polygon: 39 segments
#    Alfalfa-polygon: 33 segments
#    Urban-polygon: 27 segments
#    Phragmites-polygon: 17 segments
#    Clover-polygon: 14 segments
#    Sugar_Beet-polygon: 9 segments
#    Wetland_Vegs: 7 segments
#    Corn-polygon: 6 segments
#    Degreed_Wetland_Poly-polygon: 6 segments
# 🔍 Categorizing features...
# 📊 FEATURE CATEGORIZATION:
#    Spectral: 600 features
#    SAR: 122 features
#    VIs: 1062 features
#    GLCM: 995 features
#
# ✅ Setup complete! Ready for variance analysis.
#
# To analyze features, use:
# analyzer.analyze_all_feature_groups()
# or for specific groups:
# analyzer.plot_feature_variance_analysis('Spectral')
# analyzer.plot_feature_variance_analysis('VIs')
# analyzer.plot_feature_variance_analysis('GLCM')
# analyzer.plot_feature_variance_analysis('SAR')
# 🎉 Feature Engineering Analysis setup completed successfully!
# Use 'analyzer' object to perform variance analysis.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import re
from typing import Dict, List, Tuple, Optional
from collections import defaultdict
from scipy import stats
from sklearn.metrics import pairwise_distances
from itertools import combinations
import warnings
warnings.filterwarnings('ignore')

class EnhancedFeatureEngineeringAnalyzer:
    """
    Enhanced feature engineering and variance analysis for remote sensing time series data
    """
    
    def __init__(self, final_dataset_with_vis):
        """
        Initialize with the enhanced dataset containing vegetation indices
        
        Args:
            final_dataset_with_vis: GeoDataFrame with all features including VIs
        """
        self.final_dataset = final_dataset_with_vis.copy()
        self.labeled_dataset = None
        self.reference_gdf = None
        
        # Enhanced feature organization by band types
        self.feature_bands = {
            'spectral_bands': ['B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B08', 'B8A', 'B11', 'B12'],
            'sar_bands': ['VV', 'VH'],
            'vi_bands': ['NDVI', 'EVI', 'SAVI', 'TDVI', 'NDWI', '2BDA', 'NDCI', 'ENDVI', 
                        'GNDVI', 'NDRE', 'GRVI', 'MSAVI', 'LSWI', 'NDMI', 'MNDWI', 
                        'MBI', 'EMBI', 'MCARI2'],
            'glcm_bands': ["Mean_mean", "Mean_var", "Variance_mean", "Variance_var",
                          "Homogeneity_mean", "Homogeneity_var", "Contrast_mean", "Contrast_var",
                          "Dissimilarity_mean", "Dissimilarity_var", "Entropy_mean", "Entropy_var",
                          "Second_Moment_mean", "Second_Moment_var", "Correlation_mean", "Correlation_var"]
        }
        
        # Organized feature groups by band and time
        self.organized_features = {
            'Spectral': defaultdict(list),
            'SAR': defaultdict(list),
            'VIs': defaultdict(list),
            'GLCM': defaultdict(list)
        }
        
        self.compactness_scores = {}
        self.band_statistics = {}
        
    def load_reference_shapefile(self, ref_shp_path: str) -> bool:
        """
        Optimized reference shapefile loading with validation
        
        Args:
            ref_shp_path: Path to reference shapefile
            
        Returns:
            bool: Success status
        """
        print(f"📂 Loading reference shapefile: {ref_shp_path}")
        
        if not os.path.exists(ref_shp_path):
            print(f"❌ Reference shapefile not found: {ref_shp_path}")
            return False
        
        try:
            self.reference_gdf = gpd.read_file(ref_shp_path)
            
            # Validate required columns
            required_cols = ['layer', 'geometry']
            missing_cols = [col for col in required_cols if col not in self.reference_gdf.columns]
            if missing_cols:
                print(f"⚠️ Missing required columns: {missing_cols}")
                return False
            
            # Ensure valid geometries
            invalid_geoms = ~self.reference_gdf.geometry.is_valid
            if invalid_geoms.any():
                print(f"⚠️ Found {invalid_geoms.sum()} invalid geometries. Fixing...")
                self.reference_gdf.loc[invalid_geoms, 'geometry'] = \
                    self.reference_gdf.loc[invalid_geoms, 'geometry'].buffer(0)
            
            print(f"✅ Reference shapefile loaded successfully")
            print(f"   Columns: {list(self.reference_gdf.columns)}")
            print(f"   Number of polygons: {len(self.reference_gdf)}")
            print(f"   Unique classes: {sorted(self.reference_gdf['layer'].unique())}")
            
            return True
            
        except Exception as e:
            print(f"❌ Error loading reference shapefile: {e}")
            return False
    
    def label_segments_with_reference(self, overlap_threshold):
        """
        Label segments using the reference shapefile with spatial intersection,
        then apply post-processing to merge or remove specific classes.
        """
        print("🏷️ Starting segment labeling process...")

        if self.reference_gdf is None:
            print("❌ Reference shapefile not loaded!")
            return False

        # Initialize labeling columns
        segments_gdf = self.final_dataset.copy()
        segments_gdf['label'] = 'Unlabeled'
        segments_gdf['layer'] = 'Unknown'

        # Tracking variables
        iou_values = {}
        over_segmentation_values = []
        weighted_iou_values = []
        eliminated_polygons = []

        print(f"🔄 Processing {len(self.reference_gdf)} reference polygons...")

        for ref_idx, ref_row in self.reference_gdf.iterrows():
            ref_geom = ref_row.geometry
            ref_label = ref_row.get("Name", f"Ref_{ref_idx}")
            ref_layer = ref_row.get("layer", "Unknown")
            ref_area = ref_geom.area

            if ref_idx % 50 == 0:
                print(f"   Processing reference polygon {ref_idx + 1}/{len(self.reference_gdf)}")

            try:
                intersecting_segments = segments_gdf[segments_gdf.geometry.intersects(ref_geom)].copy()

                if intersecting_segments.empty:
                    eliminated_polygons.append(ref_idx)
                    iou_values[ref_idx] = 0
                    continue

                # Calculate intersection metrics
                intersecting_segments["intersection_area"] = intersecting_segments.geometry.apply(
                    lambda seg: seg.intersection(ref_geom).area if seg.is_valid and ref_geom.is_valid else 0
                )
                intersecting_segments["segment_area"] = intersecting_segments.geometry.area
                intersecting_segments["overlap_ratio"] = (
                    intersecting_segments["intersection_area"] /
                    intersecting_segments["segment_area"].replace(0, np.inf)
                )

                # Find significant overlaps (>50% of segment area)
                significant_segments = intersecting_segments[intersecting_segments["overlap_ratio"] > overlap_threshold]
                over_segmentation_values.append(len(significant_segments))

                if not significant_segments.empty:
                    for idx in significant_segments.index:
                        segments_gdf.at[idx, 'label'] = ref_label
                        segments_gdf.at[idx, 'layer'] = ref_layer

                    try:
                        combined_geometry = significant_segments.geometry.union_all()
                        intersection_area = combined_geometry.intersection(ref_geom).area
                        union_area = combined_geometry.union(ref_geom).area
                        iou = intersection_area / union_area if union_area > 0 else 0
                        iou_values[ref_idx] = iou
                        weighted_iou_values.append(iou * ref_area)
                    except:
                        iou_values[ref_idx] = 0

                else:
                    most_representative = intersecting_segments.loc[
                        intersecting_segments["intersection_area"].idxmax()
                    ]
                    idx = most_representative.name
                    segments_gdf.at[idx, 'label'] = ref_label
                    segments_gdf.at[idx, 'layer'] = ref_layer

                    try:
                        intersection_area = most_representative.geometry.intersection(ref_geom).area
                        union_area = most_representative.geometry.union(ref_geom).area
                        iou = intersection_area / union_area if union_area > 0 else 0
                        iou_values[ref_idx] = iou
                        weighted_iou_values.append(iou * ref_area)
                    except:
                        iou_values[ref_idx] = 0

            except Exception as e:
                print(f"⚠️ Error processing reference polygon {ref_idx}: {e}")
                eliminated_polygons.append(ref_idx)
                iou_values[ref_idx] = 0
                continue

        # ===== POST-PROCESSING: Merge & Remove classes =====
        print("\n🔧 Applying post-processing to layers...")
        merge_wetland = ["Mixed_TP-polygon", "Tamarix-polygon"]
        remove_classes = ["Plowed-polygon"]

        # Merge Wetland_Vegs
        segments_gdf.loc[segments_gdf['layer'].isin(merge_wetland), 'layer'] = "Tamarixs"
        # Remove unwanted classes
        before_count = len(segments_gdf)
        segments_gdf = segments_gdf[~segments_gdf['layer'].isin(remove_classes)]
        after_count = len(segments_gdf)
        print(f"   Removed {before_count - after_count} segments belonging to {remove_classes}")

        self.labeled_dataset = segments_gdf

        # ===== STATS =====
        print("\n📊 LABELING RESULTS:")
        print(f"   Total segments: {len(segments_gdf)}")
        print(f"   Labeled segments: {len(segments_gdf[segments_gdf['label'] != 'Unlabeled'])}")
        print(f"   Unlabeled segments: {len(segments_gdf[segments_gdf['label'] == 'Unlabeled'])}")
        print(f"   Average IoU: {np.mean(list(iou_values.values())):.3f}")
        print(f"   Eliminated reference polygons: {len(eliminated_polygons)}")

        print("\n🏷️ CLASS DISTRIBUTION:")
        class_counts = segments_gdf['layer'].value_counts()
        for class_name, count in class_counts.items():
            print(f"   {class_name}: {count} segments")

        return True

    
    def organize_features_by_bands(self) -> bool:
        """
        Organize features by band types and temporal information for easy access
        
        Returns:
            bool: Success status
        """
        print("🔍 Organizing features by bands and time series...")
        
        if self.labeled_dataset is None:
            print("❌ Dataset not labeled yet!")
            return False
        
        # Get all feature columns (exclude geometry and label columns)
        exclude_cols = ['geometry', 'label', 'layer', 'segment_area']
        feature_columns = [col for col in self.labeled_dataset.columns if col not in exclude_cols]
        
        # Organize features by band types
        for feature_type, band_list in self.feature_bands.items():
            # Fix group name mapping
            if feature_type == 'spectral_bands':
                group_name = 'Spectral'
            elif feature_type == 'sar_bands':
                group_name = 'SAR'
            elif feature_type == 'vi_bands':
                group_name = 'VIs'
            elif feature_type == 'glcm_bands':
                group_name = 'GLCM'
            else:
                group_name = feature_type.replace('_bands', '').upper()
            
            for band in band_list:
                # Find all columns that match this band pattern
                if feature_type == 'glcm_bands':
                    # GLCM features have different naming pattern
                    matching_cols = [col for col in feature_columns 
                                   if band.lower() in col.lower() or band.replace('_', '').lower() in col.lower()]
                else:
                    # Standard pattern: BAND_YYYYMMDD or similar
                    matching_cols = [col for col in feature_columns 
                                   if re.match(rf"^{band}_\d+", col, re.IGNORECASE) or 
                                      col.upper().startswith(band.upper())]
                
                if matching_cols:
                    # Sort by date if time series
                    date_sorted_cols = sorted(matching_cols, key=lambda x: self._extract_date(x))
                    self.organized_features[group_name][band] = date_sorted_cols
        
        # Print organization summary
        print(f"\n📊 FEATURE ORGANIZATION BY BANDS:")
        total_features = 0
        for group_name, bands in self.organized_features.items():
            group_total = sum(len(cols) for cols in bands.values())
            total_features += group_total
            print(f"   {group_name}: {len(bands)} bands, {group_total} features")
            
            # Show sample bands
            for band, cols in list(bands.items())[:3]:  # Show first 3 bands
                print(f"     - {band}: {len(cols)} features")
        
        print(f"   Total organized features: {total_features}")
        return True
    
    def _extract_date(self, column_name: str) -> str:
        """Extract date from column name for sorting"""
        match = re.search(r'(\d{8})', column_name)
        return match.group(1) if match else '00000000'
    
    def plot_feature_distributions(self, class_column: str = 'layer', 
                                 max_dates_per_plot: int = 10,
                                 save_plots: bool = False, 
                                 output_dir: str = None) -> Dict[str, float]:
        """
        Create enhanced strip plots for each band's time series with compactness analysis
        
        Args:
            class_column: Column name for class labels
            max_dates_per_plot: Maximum number of dates to show in legend
            save_plots: Whether to save plots to disk
            output_dir: Directory to save plots
            
        Returns:
            Dict: Compactness scores for each feature
        """
        print("📊 Creating enhanced feature distribution plots...")
        
        if self.labeled_dataset is None:
            print("❌ Dataset not labeled yet!")
            return {}
        
        # Prepare data - only use labeled segments
        plot_data = self.labeled_dataset[self.labeled_dataset[class_column] != 'Unknown'].copy()
        
        if plot_data.empty:
            print("❌ No labeled data available for plotting!")
            return {}
        
        if save_plots and output_dir:
            os.makedirs(output_dir, exist_ok=True)
        
        compactness_scores = {}
        
        # Process each feature group
        for group_name, bands in self.organized_features.items():
            if not bands:
                continue
                
            print(f"\n🎨 Plotting {group_name} features...")
            
            for band, columns in bands.items():
                if not columns:
                    continue
                
                try:
                    # Prepare data for this band
                    band_data = plot_data[columns + [class_column]].copy()
                    
                    # Remove columns with all NaN values
                    valid_columns = [col for col in columns if not band_data[col].isna().all()]
                    if not valid_columns:
                        print(f"⚠️ No valid data for {band}. Skipping.")
                        continue
                    
                    # Melt data into long format
                    melted = band_data[valid_columns + [class_column]].melt(
                        id_vars=class_column,
                        var_name='TimestampedFeature',
                        value_name='Value'
                    )
                    
                    # Extract date information
                    melted['Date'] = melted['TimestampedFeature'].str.extract(r'_(\d{8})')[0]
                    melted['Date'] = melted['Date'].fillna('NoDate')
                    
                    # Remove invalid values
                    melted = melted.dropna(subset=['Value'])
                    melted = melted[np.isfinite(melted['Value'])]
                    
                    if melted.empty:
                        print(f"⚠️ No valid data after cleaning for {band}. Skipping.")
                        continue
                    
                    # Create the plot
                    plt.figure(figsize=(16, 8))
                    
                    # Get unique dates and classes
                    unique_dates = sorted(melted['Date'].unique())
                    unique_classes = sorted(melted[class_column].unique())
                    
                    # Create strip plot
                    ax = sns.stripplot(
                        data=melted, 
                        x='Value', 
                        y=class_column,
                        hue='Date' if len(unique_dates) <= max_dates_per_plot else None,
                        jitter=True, 
                        alpha=0.6, 
                        palette='Spectral', 
                        dodge=False, 
                        size=4,
                        linewidth=0.5
                    )
                    
                    # Calculate and plot compactness (5th-95th percentile range)
                    compactness_values = []
                    for cls in unique_classes:
                        class_data = melted[melted[class_column] == cls]['Value'].dropna()
                        if len(class_data) >= 10:  # Minimum samples for reliable percentiles
                            q5, q95 = np.percentile(class_data, [5, 95])
                            plt.hlines(y=cls, xmin=q5, xmax=q95, 
                                     color="red", linewidth=3, alpha=0.8)
                            compactness_values.append(q95 - q5)
                    
                    # Store compactness score
                    if compactness_values:
                        avg_compactness = np.mean(compactness_values)
                        compactness_scores[f"{group_name}_{band}"] = avg_compactness
                    
                    # Enhance plot appearance
                    plt.title(f"{group_name} Feature: {band}\n"
                             f"Compactness Score: {compactness_scores.get(f'{group_name}_{band}', 0):.3f}", 
                             fontsize=14, fontweight='bold')
                    plt.xlabel("Feature Value", fontsize=12)
                    plt.ylabel("Class", fontsize=12)
                    plt.grid(True, linestyle='--', alpha=0.3)
                    
                    # Add feature count and date range info
                    date_info = f"Dates: {len(unique_dates)}" if len(unique_dates) > 1 else "Single timestamp"
                    plt.text(0.02, 0.98, f"Features: {len(valid_columns)}\n{date_info}", 
                            transform=ax.transAxes, fontsize=10, 
                            verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))
                    
                    # Manage legend
                    if len(unique_dates) <= max_dates_per_plot and len(unique_dates) > 1:
                        plt.legend(title="Date", bbox_to_anchor=(1.05, 1), loc='upper left', 
                                 borderaxespad=0., fontsize=8)
                    
                    plt.tight_layout()
                    
                    # Save plot if requested
                    if save_plots and output_dir:
                        filename = f"{group_name}_{band}_distribution.png"
                        plt.savefig(os.path.join(output_dir, filename), dpi=300, bbox_inches='tight')
                        print(f"   💾 Saved: {filename}")
                    
                    plt.show()
                    
                except Exception as e:
                    print(f"⚠️ Error plotting {group_name}_{band}: {e}")
                    continue
        
        # Store compactness scores
        self.compactness_scores = compactness_scores
        
        # Print compactness summary
        print(f"\n📊 COMPACTNESS ANALYSIS SUMMARY:")
        if compactness_scores:
            sorted_scores = sorted(compactness_scores.items(), key=lambda x: x[1])
            print(f"   Most compact features (top 5):")
            for feature, score in sorted_scores[:5]:
                print(f"     {feature}: {score:.3f}")
            print(f"   Least compact features (bottom 5):")
            for feature, score in sorted_scores[-5:]:
                print(f"     {feature}: {score:.3f}")
        else:
            print("   No compactness scores calculated.")
        
        return compactness_scores

    def calculate_bhattacharyya_distance(self, x1: np.ndarray, x2: np.ndarray) -> float:
        """
        Calculate Bhattacharyya distance between two distributions
        
        Args:
            x1, x2: Arrays of sample values from two distributions
            
        Returns:
            float: Bhattacharyya distance
        """
        try:
            # Remove NaN values
            x1 = x1[~np.isnan(x1)]
            x2 = x2[~np.isnan(x2)]
            
            if len(x1) == 0 or len(x2) == 0:
                return np.nan
            
            # Calculate means and variances
            mu1, mu2 = np.mean(x1), np.mean(x2)
            var1, var2 = np.var(x1, ddof=1), np.var(x2, ddof=1)
            
            # Handle zero variance cases
            if var1 == 0 and var2 == 0:
                return 0 if mu1 == mu2 else np.inf
            elif var1 == 0 or var2 == 0:
                return np.inf
            
            # Bhattacharyya distance formula
            sigma_pooled = (var1 + var2) / 2
            term1 = 0.25 * np.log(0.25 * ((var1/var2) + (var2/var1) + 2))
            term2 = 0.25 * ((mu1 - mu2)**2 / sigma_pooled)
            
            return term1 + term2
            
        except Exception as e:
            print(f"Warning: Error calculating Bhattacharyya distance: {e}")
            return np.nan

    def calculate_bhattacharyya_divergence(self, x1: np.ndarray, x2: np.ndarray) -> float:
        """
        Calculate Bhattacharyya divergence (coefficient) between two distributions
        
        Args:
            x1, x2: Arrays of sample values from two distributions
            
        Returns:
            float: Bhattacharyya divergence coefficient (0 = identical, 1 = completely separable)
        """
        distance = self.calculate_bhattacharyya_distance(x1, x2)
        if np.isnan(distance) or np.isinf(distance):
            return np.nan
        return 1 - np.exp(-distance)

    def perform_statistical_tests(self, feature_col: str, class_pairs: List[Tuple[str, str]] = None) -> Dict:
        """
        Perform t-test and Mann-Whitney U test for feature separability between class pairs
        
        Args:
            feature_col: Feature column name to analyze
            class_pairs: List of class pairs to compare. If None, compares all pairs
            
        Returns:
            Dict: Statistical test results
        """
        if self.labeled_dataset is None:
            print("❌ Dataset not labeled yet!")
            return {}
        
        # Get labeled data only
        labeled_data = self.labeled_dataset[self.labeled_dataset['layer'] != 'Unknown'].copy()
        
        # Get unique classes
        unique_classes = labeled_data['layer'].unique()
        if len(unique_classes) < 2:
            print("❌ Need at least 2 classes for separability analysis!")
            return {}
        
        # Define class pairs to compare
        if class_pairs is None:
            class_pairs = list(combinations(unique_classes, 2))
        
        results = {
            'feature': feature_col,
            'comparisons': {},
            'summary': {
                'total_comparisons': len(class_pairs),
                'significant_ttest': 0,
                'significant_utest': 0,
                'mean_bhattacharyya_distance': 0,
                'mean_bhattacharyya_divergence': 0
            }
        }
        
        bhatt_distances = []
        bhatt_divergences = []
        
        for class1, class2 in class_pairs:
            # Get feature values for each class
            data1 = labeled_data[labeled_data['layer'] == class1][feature_col].dropna().values
            data2 = labeled_data[labeled_data['layer'] == class2][feature_col].dropna().values
            
            if len(data1) < 3 or len(data2) < 3:
                continue
            
            # Perform t-test
            try:
                t_stat, t_pvalue = stats.ttest_ind(data1, data2, equal_var=False)
            except Exception as e:
                t_stat, t_pvalue = np.nan, np.nan
            
            # Perform Mann-Whitney U test
            try:
                u_stat, u_pvalue = stats.mannwhitneyu(data1, data2, alternative='two-sided')
            except Exception as e:
                u_stat, u_pvalue = np.nan, np.nan
            
            # Calculate Bhattacharyya measures
            bhatt_dist = self.calculate_bhattacharyya_distance(data1, data2)
            bhatt_div = self.calculate_bhattacharyya_divergence(data1, data2)
            
            if not np.isnan(bhatt_dist):
                bhatt_distances.append(bhatt_dist)
            if not np.isnan(bhatt_div):
                bhatt_divergences.append(bhatt_div)
            
            # Store results
            comparison_key = f"{class1}_vs_{class2}"
            results['comparisons'][comparison_key] = {
                'class1': class1,
                'class2': class2,
                'n1': len(data1),
                'n2': len(data2),
                'mean1': np.mean(data1),
                'mean2': np.mean(data2),
                'std1': np.std(data1),
                'std2': np.std(data2),
                't_statistic': t_stat,
                't_pvalue': t_pvalue,
                't_significant': t_pvalue < 0.05 if not np.isnan(t_pvalue) else False,
                'u_statistic': u_stat,
                'u_pvalue': u_pvalue,
                'u_significant': u_pvalue < 0.05 if not np.isnan(u_pvalue) else False,
                'bhattacharyya_distance': bhatt_dist,
                'bhattacharyya_divergence': bhatt_div,
                'separability_score': bhatt_div if not np.isnan(bhatt_div) else 0
            }
            
            # Count significant results
            if not np.isnan(t_pvalue) and t_pvalue < 0.05:
                results['summary']['significant_ttest'] += 1
            if not np.isnan(u_pvalue) and u_pvalue < 0.05:
                results['summary']['significant_utest'] += 1
        
        # Calculate summary statistics
        if bhatt_distances:
            results['summary']['mean_bhattacharyya_distance'] = np.mean(bhatt_distances)
        if bhatt_divergences:
            results['summary']['mean_bhattacharyya_divergence'] = np.mean(bhatt_divergences)
        
        return results

    def analyze_all_features_separability(self, max_features: int = None, 
                                        save_results: bool = True,
                                        output_dir: str = None) -> pd.DataFrame:
        """
        Analyze separability for all features across all class pairs
        
        Args:
            max_features: Maximum number of features to analyze (for testing)
            save_results: Whether to save results to CSV
            output_dir: Directory to save results
            
        Returns:
            DataFrame: Complete separability analysis results
        """
        print("🔬 Starting comprehensive separability analysis...")
        
        if self.labeled_dataset is None:
            print("❌ Dataset not labeled yet!")
            return pd.DataFrame()
        
        # Get feature columns
        exclude_cols = ['geometry', 'label', 'layer', 'segment_area']
        feature_columns = [col for col in self.labeled_dataset.columns if col not in exclude_cols]
        
        if max_features:
            feature_columns = feature_columns[:max_features]
            print(f"🎯 Analyzing first {len(feature_columns)} features for testing...")
        
        # Get labeled data only
        labeled_data = self.labeled_dataset[self.labeled_dataset['layer'] != 'Unknown'].copy()
        unique_classes = labeled_data['layer'].unique()
        class_pairs = list(combinations(unique_classes, 2))
        
        print(f"📊 Analyzing {len(feature_columns)} features across {len(class_pairs)} class pairs...")
        
        all_results = []
        
        for i, feature in enumerate(feature_columns):
            if i % 50 == 0:
                print(f"   Processing feature {i+1}/{len(feature_columns)}: {feature}")
            
            # Perform statistical tests
            feature_results = self.perform_statistical_tests(feature, class_pairs)
            
            if not feature_results or 'comparisons' not in feature_results:
                continue
            
            # Extract results for each comparison
            for comparison, stats_dict in feature_results['comparisons'].items():
                result_row = {
                    'feature': feature,
                    'comparison': comparison,
                    'class1': stats_dict['class1'],
                    'class2': stats_dict['class2'],
                    'n1': stats_dict['n1'],
                    'n2': stats_dict['n2'],
                    'mean1': stats_dict['mean1'],
                    'mean2': stats_dict['mean2'],
                    'std1': stats_dict['std1'],
                    'std2': stats_dict['std2'],
                    't_statistic': stats_dict['t_statistic'],
                    't_pvalue': stats_dict['t_pvalue'],
                    't_significant': stats_dict['t_significant'],
                    'u_statistic': stats_dict['u_statistic'],
                    'u_pvalue': stats_dict['u_pvalue'],
                    'u_significant': stats_dict['u_significant'],
                    'bhattacharyya_distance': stats_dict['bhattacharyya_distance'],
                    'bhattacharyya_divergence': stats_dict['bhattacharyya_divergence'],
                    'separability_score': stats_dict['separability_score']
                }
                all_results.append(result_row)
        
        # Create DataFrame
        results_df = pd.DataFrame(all_results)
        
        if results_df.empty:
            print("❌ No separability results generated!")
            return results_df
        
        # Save results if requested
        if save_results and output_dir:
            import os
            os.makedirs(output_dir, exist_ok=True)
            csv_path = os.path.join(output_dir, 'separability_analysis_results.csv')
            results_df.to_csv(csv_path, index=False)
            print(f"💾 Results saved to: {csv_path}")
        
        # Print summary
        print(f"\n📊 SEPARABILITY ANALYSIS SUMMARY:")
        print(f"   Total feature-class comparisons: {len(results_df):,}")
        print(f"   Significant t-tests: {results_df['t_significant'].sum():,}")
        print(f"   Significant U-tests: {results_df['u_significant'].sum():,}")
        print(f"   Mean Bhattacharyya distance: {results_df['bhattacharyya_distance'].mean():.4f}")
        print(f"   Mean Bhattacharyya divergence: {results_df['bhattacharyya_divergence'].mean():.4f}")
        
        return results_df

    def create_separability_heatmaps(self, separability_df: pd.DataFrame,
                                save_plots: bool = True,
                                output_dir: str = None,
                                top_n_features: int = 20) -> None:
        """
        Create improved heatmaps showing feature separability across class pairs
        
        Args:
            separability_df: Results from analyze_all_features_separability
            save_plots: Whether to save plots
            output_dir: Directory to save plots
            top_n_features: Number of top features to show in detailed heatmaps
        """
        print("🎨 Creating improved separability heatmaps...")
        
        if separability_df.empty:
            print("❌ No separability data provided!")
            return
        
        # Create output directory
        if save_plots and output_dir:
            import os
            os.makedirs(output_dir, exist_ok=True)
        
        # Create larger figure with more spacing
        plt.figure(figsize=(24, 16))  # Much larger figure
        
        # 1. Overall separability heatmap (Bhattacharyya divergence)
        # Create pivot table for heatmap
        heatmap_data = separability_df.pivot_table(
            values='bhattacharyya_divergence',
            index='feature',
            columns='comparison',
            aggfunc='mean'
        )
        
        # Get top features by mean separability
        feature_means = heatmap_data.mean(axis=1).sort_values(ascending=False)
        top_features = feature_means.head(top_n_features).index
        
        # Plot heatmap for top features - NO ANNOTATIONS
        plt.subplot(2, 2, 1)
        sns.heatmap(heatmap_data.loc[top_features], 
                    annot=False,  # Remove numbers
                    cmap='YlOrRd', 
                    cbar_kws={'label': 'Bhattacharyya Divergence'},
                    xticklabels=True,
                    yticklabels=True)
        plt.title(f'Top {top_n_features} Features - Bhattacharyya Divergence Heatmap', fontsize=14, pad=20)
        plt.xlabel('Class Comparisons', fontsize=12)
        plt.ylabel('Features', fontsize=12)
        plt.xticks(rotation=45, ha='right', fontsize=8)
        plt.yticks(rotation=0, fontsize=8)
        
        # 2. Statistical significance heatmap (t-test) - NO ANNOTATIONS
        plt.subplot(2, 2, 2)
        ttest_data = separability_df.pivot_table(
            values='t_significant',
            index='feature',
            columns='comparison',
            aggfunc='mean'
        )
        
        sns.heatmap(ttest_data.loc[top_features], 
                    annot=False,  # Remove numbers
                    cmap='RdYlBu_r', 
                    cbar_kws={'label': 'T-test Significant (1=Yes, 0=No)'},
                    xticklabels=True,
                    yticklabels=True)
        plt.title(f'Top {top_n_features} Features - T-test Significance', fontsize=14, pad=20)
        plt.xlabel('Class Comparisons', fontsize=12)
        plt.ylabel('Features', fontsize=12)
        plt.xticks(rotation=45, ha='right', fontsize=8)
        plt.yticks(rotation=0, fontsize=8)
        
        # 3. Statistical significance heatmap (U-test) - NO ANNOTATIONS
        plt.subplot(2, 2, 3)
        utest_data = separability_df.pivot_table(
            values='u_significant',
            index='feature',
            columns='comparison',
            aggfunc='mean'
        )
        
        sns.heatmap(utest_data.loc[top_features], 
                    annot=False,  # Remove numbers
                    cmap='RdYlBu_r', 
                    cbar_kws={'label': 'U-test Significant (1=Yes, 0=No)'},
                    xticklabels=True,
                    yticklabels=True)
        plt.title(f'Top {top_n_features} Features - Mann-Whitney U Significance', fontsize=14, pad=20)
        plt.xlabel('Class Comparisons', fontsize=12)
        plt.ylabel('Features', fontsize=12)
        plt.xticks(rotation=45, ha='right', fontsize=8)
        plt.yticks(rotation=0, fontsize=8)
        
        # 4. Feature ranking by separability
        plt.subplot(2, 2, 4)
        feature_ranking = feature_means.head(25)  # Show top 25
        bars = plt.barh(range(len(feature_ranking)), feature_ranking.values)
        plt.yticks(range(len(feature_ranking)), 
                [f.replace('_', '_\n') if len(f) > 15 else f for f in feature_ranking.index],
                fontsize=9)
        plt.xlabel('Mean Bhattacharyya Divergence', fontsize=12)
        plt.title('Top 25 Most Separable Features', fontsize=14)
        plt.gca().invert_yaxis()
        
        # Color bars by value
        for i, bar in enumerate(bars):
            bar.set_color(plt.cm.YlOrRd(feature_ranking.values[i]))
        
        # Add grid for better readability
        plt.grid(axis='x', alpha=0.3)
        
        # Adjust layout with more spacing
        plt.tight_layout(pad=3.0, w_pad=3.0, h_pad=3.0)
        
        if save_plots and output_dir:
            plt.savefig(os.path.join(output_dir, 'separability_heatmaps_improved.png'), 
                    dpi=300, bbox_inches='tight', facecolor='white')
            print(f"💾 Improved heatmaps saved to: {output_dir}")
        
        plt.show()
        
        # Create additional focused heatmaps for better readability
        self._create_focused_heatmaps(separability_df, top_n_features, save_plots, output_dir)

    def _create_focused_heatmaps(self, separability_df: pd.DataFrame, 
                            top_n_features: int = 15,
                            save_plots: bool = True,
                            output_dir: str = None) -> None:
        """
        Create focused individual heatmaps for better readability
        """
        print("🎯 Creating focused individual heatmaps...")
        
        # Create pivot table
        heatmap_data = separability_df.pivot_table(
            values='bhattacharyya_divergence',
            index='feature',
            columns='comparison',
            aggfunc='mean'
        )
        
        # Get top features
        feature_means = heatmap_data.mean(axis=1).sort_values(ascending=False)
        top_features = feature_means.head(top_n_features).index
        
        # Create a large focused heatmap
        plt.figure(figsize=(18, 10))
        
        # Clean up feature names for display
        clean_feature_names = []
        for feat in top_features:
            # Simplify feature names by removing dates or shortening
            clean_name = feat
            if len(clean_name) > 20:
                # Keep first part and last part if it's a date
                parts = clean_name.split('_')
                if len(parts) >= 2:
                    clean_name = f"{parts[0]}_{parts[-1][:8]}"
            clean_feature_names.append(clean_name)
        
        # Clean up class comparison names
        comparison_names = []
        for comp in heatmap_data.columns:
            # Simplify class names
            clean_comp = comp.replace('_merged', '').replace('-polygon', '').replace('_vs_', ' vs ')
            if len(clean_comp) > 25:
                clean_comp = clean_comp[:25] + '...'
            comparison_names.append(clean_comp)
        
        # Create the heatmap with cleaned data
        plot_data = heatmap_data.loc[top_features].copy()
        plot_data.index = clean_feature_names
        plot_data.columns = comparison_names
        
        ax = sns.heatmap(plot_data, 
                        annot=False,
                        cmap='YlOrRd',
                        cbar_kws={'label': 'Bhattacharyya Divergence', 'shrink': 0.8},
                        linewidths=0.5,
                        linecolor='white')
        
        plt.title(f'Top {top_n_features} Most Separable Features\nBhattacharyya Divergence Heatmap', 
                fontsize=16, pad=25)
        plt.xlabel('Class Comparisons', fontsize=14, labelpad=15)
        plt.ylabel('Features', fontsize=14, labelpad=15)
        
        # Improve tick labels
        plt.xticks(rotation=45, ha='right', fontsize=10)
        plt.yticks(rotation=0, fontsize=10)
        
        # Add colorbar label
        cbar = ax.collections[0].colorbar
        cbar.ax.tick_params(labelsize=10)
        
        plt.tight_layout()
        
        if save_plots and output_dir:
            plt.savefig(os.path.join(output_dir, 'focused_separability_heatmap.png'), 
                    dpi=300, bbox_inches='tight', facecolor='white')
            
        plt.show()
        
        # Create band-wise comparison heatmap if organized features available
        if hasattr(self, 'organized_features'):
            self._create_band_comparison_heatmap(separability_df, save_plots, output_dir)

    def _create_band_comparison_heatmap(self, separability_df: pd.DataFrame,
                                    save_plots: bool = True,
                                    output_dir: str = None) -> None:
        """
        Create heatmap comparing separability by band groups
        """
        print("🎵 Creating band group comparison heatmap...")
        
        # Create band group mapping
        band_mapping = {}
        for group_name, bands in self.organized_features.items():
            for band_features in bands.values():
                for feature in band_features:
                    band_mapping[feature] = group_name
        
        # Add band group to separability data
        separability_with_bands = separability_df.copy()
        separability_with_bands['band_group'] = separability_with_bands['feature'].map(band_mapping)
        separability_with_bands = separability_with_bands.dropna(subset=['band_group'])
        
        # Create band group summary
        band_summary = separability_with_bands.groupby(['band_group', 'comparison'])['bhattacharyya_divergence'].mean().reset_index()
        band_pivot = band_summary.pivot(index='band_group', columns='comparison', values='bhattacharyya_divergence')
        
        # Create the plot
        plt.figure(figsize=(16, 6))
        
        # Clean comparison names
        clean_comparisons = [comp.replace('_merged', '').replace('-polygon', '').replace('_vs_', ' vs ') 
                            for comp in band_pivot.columns]
        band_pivot.columns = clean_comparisons
        
        sns.heatmap(band_pivot,
                    annot=True,
                    fmt='.3f',
                    cmap='RdYlBu_r',
                    cbar_kws={'label': 'Mean Bhattacharyya Divergence'},
                    linewidths=0.5)
        
        plt.title('Mean Separability by Band Groups\nAcross All Class Comparisons', fontsize=14, pad=20)
        plt.xlabel('Class Comparisons', fontsize=12)
        plt.ylabel('Band Groups', fontsize=12)
        plt.xticks(rotation=45, ha='right', fontsize=9)
        plt.yticks(rotation=0, fontsize=11)
        
        plt.tight_layout()
        
        if save_plots and output_dir:
            plt.savefig(os.path.join(output_dir, 'band_group_separability.png'), 
                    dpi=300, bbox_inches='tight', facecolor='white')
        
        plt.show()

    def create_class_pair_separability_plots(self, separability_df: pd.DataFrame,
                                        save_plots: bool = True,
                                        output_dir: str = None) -> None:
        """
        Create detailed plots for each class pair showing most separable features
        
        Args:
            separability_df: Results from analyze_all_features_separability
            save_plots: Whether to save plots
            output_dir: Directory to save plots
        """
        print("📊 Creating class pair separability plots...")
        
        if separability_df.empty:
            print("❌ No separability data provided!")
            return
        
        # Create output directory
        if save_plots and output_dir:
            import os
            os.makedirs(output_dir, exist_ok=True)
        
        # Get unique class pairs
        class_pairs = separability_df['comparison'].unique()
        
        # Create subplots for each class pair
        n_pairs = len(class_pairs)
        cols = 3
        rows = (n_pairs + cols - 1) // cols
        
        fig, axes = plt.subplots(rows, cols, figsize=(20, 6*rows))
        if rows == 1:
            axes = axes.reshape(1, -1)
        axes = axes.flatten()
        
        for i, pair in enumerate(class_pairs):
            if i >= len(axes):
                break
                
            ax = axes[i]
            
            # Get data for this class pair
            pair_data = separability_df[separability_df['comparison'] == pair].copy()
            
            # Sort by separability score
            pair_data = pair_data.sort_values('bhattacharyya_divergence', ascending=False)
            
            # Get top 15 features
            top_features = pair_data.head(15)
            
            # Create bar plot
            bars = ax.barh(range(len(top_features)), top_features['bhattacharyya_divergence'])
            ax.set_yticks(range(len(top_features)))
            ax.set_yticklabels(top_features['feature'], fontsize=8)
            ax.set_xlabel('Bhattacharyya Divergence')
            ax.set_title(f'{pair}\nTop Separable Features', fontsize=10)
            ax.invert_yaxis()
            
            # Color bars by significance
            for j, bar in enumerate(bars):
                feature_idx = top_features.iloc[j]
                if feature_idx['t_significant'] and feature_idx['u_significant']:
                    bar.set_color('darkgreen')  # Both significant
                elif feature_idx['t_significant'] or feature_idx['u_significant']:
                    bar.set_color('orange')  # One significant
                else:
                    bar.set_color('lightcoral')  # Not significant
            
            # Add legend to first subplot
            if i == 0:
                from matplotlib.patches import Patch
                legend_elements = [
                    Patch(facecolor='darkgreen', label='Both tests significant'),
                    Patch(facecolor='orange', label='One test significant'),
                    Patch(facecolor='lightcoral', label='Not significant')
                ]
                ax.legend(handles=legend_elements, loc='lower right', fontsize=8)
        
        # Hide unused subplots
        for i in range(len(class_pairs), len(axes)):
            axes[i].set_visible(False)
        
        plt.tight_layout()
        
        if save_plots and output_dir:
            plt.savefig(os.path.join(output_dir, 'class_pair_separability.png'), 
                    dpi=300, bbox_inches='tight')
            print(f"💾 Class pair plots saved to: {output_dir}")
        
        plt.show()

    def create_separability_summary_report(self, separability_df: pd.DataFrame,
                                        save_report: bool = True,
                                        output_dir: str = None) -> Dict:
        """
        Create a comprehensive summary report of separability analysis
        
        Args:
            separability_df: Results from analyze_all_features_separability
            save_report: Whether to save report to file
            output_dir: Directory to save report
            
        Returns:
            Dict: Summary statistics
        """
        print("📝 Creating separability summary report...")
        
        if separability_df.empty:
            print("❌ No separability data provided!")
            return {}
        
        # Calculate summary statistics
        summary = {
            'overall_stats': {
                'total_features': separability_df['feature'].nunique(),
                'total_class_pairs': separability_df['comparison'].nunique(),
                'total_comparisons': len(separability_df),
                'mean_bhattacharyya_distance': separability_df['bhattacharyya_distance'].mean(),
                'mean_bhattacharyya_divergence': separability_df['bhattacharyya_divergence'].mean(),
                'ttest_significance_rate': separability_df['t_significant'].mean(),
                'utest_significance_rate': separability_df['u_significant'].mean()
            },
            'top_features': {},
            'class_pair_analysis': {},
            'band_group_analysis': {}
        }
        
        # Top 20 most separable features overall
        feature_separability = separability_df.groupby('feature')['bhattacharyya_divergence'].mean().sort_values(ascending=False)
        summary['top_features']['most_separable'] = feature_separability.head(20).to_dict()
        
        # Features with highest significance rates
        feature_significance = separability_df.groupby('feature').agg({
            't_significant': 'mean',
            'u_significant': 'mean',
            'bhattacharyya_divergence': 'mean'
        }).sort_values('t_significant', ascending=False)
        summary['top_features']['most_significant'] = feature_significance.head(20).to_dict('index')
        
        # Analysis by class pairs
        class_pair_stats = separability_df.groupby('comparison').agg({
            'bhattacharyya_divergence': ['mean', 'std', 'count'],
            't_significant': 'mean',
            'u_significant': 'mean'
        }).round(4)

        # Flatten MultiIndex columns to avoid tuple keys in JSON
        class_pair_stats.columns = ['_'.join(col).strip() if isinstance(col, tuple) else col for col in class_pair_stats.columns]
        summary['class_pair_analysis'] = class_pair_stats.to_dict('index')
        
        # Analysis by band groups (if organized features are available)
        if hasattr(self, 'organized_features'):
            band_analysis = {}
            for group_name, bands in self.organized_features.items():
                group_features = []
                for band_features in bands.values():
                    group_features.extend(band_features)
                
                # Get separability stats for this group
                group_data = separability_df[separability_df['feature'].isin(group_features)]
                if not group_data.empty:
                    band_analysis[group_name] = {
                        'n_features': len(group_features),
                        'mean_separability': group_data['bhattacharyya_divergence'].mean(),
                        'significance_rate': group_data['t_significant'].mean(),
                        'top_feature': group_data.loc[group_data['bhattacharyya_divergence'].idxmax(), 'feature']
                    }
            summary['band_group_analysis'] = band_analysis
        
        # Save report if requested
        if save_report and output_dir:
            import os
            import json
            os.makedirs(output_dir, exist_ok=True)
            
            # Save JSON report
            json_path = os.path.join(output_dir, 'separability_summary_report.json')
            with open(json_path, 'w') as f:
                json.dump(summary, f, indent=2, default=str)
            
            # Save text report
            txt_path = os.path.join(output_dir, 'separability_summary_report.txt')
            with open(txt_path, 'w') as f:
                f.write("CLASS SEPARABILITY ANALYSIS SUMMARY REPORT\n")
                f.write("=" * 50 + "\n\n")
                
                # Overall statistics
                f.write("OVERALL STATISTICS:\n")
                f.write("-" * 20 + "\n")
                for key, value in summary['overall_stats'].items():
                    f.write(f"{key}: {value}\n")
                f.write("\n")
                
                # Top features
                f.write("TOP 10 MOST SEPARABLE FEATURES:\n")
                f.write("-" * 35 + "\n")
                for i, (feature, score) in enumerate(list(summary['top_features']['most_separable'].items())[:10]):
                    f.write(f"{i+1:2d}. {feature}: {score:.4f}\n")
                f.write("\n")
                
                # Band group analysis
                if summary['band_group_analysis']:
                    f.write("BAND GROUP ANALYSIS:\n")
                    f.write("-" * 20 + "\n")
                    for group, stats in summary['band_group_analysis'].items():
                        f.write(f"{group}:\n")
                        f.write(f"  Features: {stats['n_features']}\n")
                        f.write(f"  Mean Separability: {stats['mean_separability']:.4f}\n")
                        f.write(f"  Significance Rate: {stats['significance_rate']:.4f}\n")
                        f.write(f"  Top Feature: {stats['top_feature']}\n\n")
            
            print(f"💾 Summary report saved to: {output_dir}")
        
        # Print summary to console
        print(f"\n📊 SEPARABILITY ANALYSIS SUMMARY:")
        print(f"   Total features analyzed: {summary['overall_stats']['total_features']:,}")
        print(f"   Total class pairs: {summary['overall_stats']['total_class_pairs']}")
        print(f"   Mean Bhattacharyya divergence: {summary['overall_stats']['mean_bhattacharyya_divergence']:.4f}")
        print(f"   T-test significance rate: {summary['overall_stats']['ttest_significance_rate']:.4f}")
        print(f"   U-test significance rate: {summary['overall_stats']['utest_significance_rate']:.4f}")
        
        if summary['band_group_analysis']:
            print(f"\n📊 BAND GROUP SEPARABILITY:")
            for group, stats in summary['band_group_analysis'].items():
                print(f"   {group}: {stats['mean_separability']:.4f} (avg), {stats['n_features']} features")
        
        return summary

    def run_complete_separability_analysis(self, max_features: int = None,
                                        save_all: bool = True,
                                        output_dir: str = None) -> Tuple[pd.DataFrame, Dict]:
        """
        Run the complete separability analysis pipeline
        
        Args:
            max_features: Maximum number of features to analyze (for testing)
            save_all: Whether to save all outputs
            output_dir: Directory to save outputs
            
        Returns:
            Tuple: (separability_df, summary_report)
        """
        print("🚀 Running complete separability analysis pipeline...")
        
        if output_dir:
            import os
            os.makedirs(output_dir, exist_ok=True)
        
        # Step 1: Analyze all features
        separability_df = self.analyze_all_features_separability(
            max_features=max_features,
            save_results=save_all,
            output_dir=output_dir
        )
        
        if separability_df.empty:
            print("❌ No separability results to analyze!")
            return separability_df, {}
        
        # Step 2: Create heatmaps
        self.create_separability_heatmaps(
            separability_df,
            save_plots=save_all,
            output_dir=output_dir
        )
        
        # Step 3: Create class pair plots
        self.create_class_pair_separability_plots(
            separability_df,
            save_plots=save_all,
            output_dir=output_dir
        )
        
        # Step 4: Create summary report
        summary_report = self.create_separability_summary_report(
            separability_df,
            save_report=save_all,
            output_dir=output_dir
        )
        
        print("✅ Complete separability analysis finished!")
        return separability_df, summary_report

    # Example usage function to add to your main script
    def run_separability_analysis_example(analyzer, output_dir=None):
        """
        Example function to run separability analysis
        
        Args:
            analyzer: Your EnhancedFeatureEngineeringAnalyzer instance
            output_dir: Directory to save outputs
        """
        if output_dir is None:
            output_dir = r"F:\_____My_Thesies____\_ImpFiles\plots\separability_analysis"
        
        print("🎯 Starting separability analysis...")
        
        # Run complete analysis (use max_features for testing with subset)
        separability_df, summary = analyzer.run_complete_separability_analysis(
            max_features=100,  # Remove or increase this for full analysis
            save_all=True,
            output_dir=output_dir
        )
        
        return separability_df, summary
    
    def get_feature_summary(self) -> Dict:
        """
        Get comprehensive summary of organized features
        
        Returns:
            Dict: Summary statistics
        """
        summary = {
            'total_features': 0,
            'groups': {},
            'bands_per_group': {},
            'temporal_coverage': {}
        }
        
        for group_name, bands in self.organized_features.items():
            group_features = sum(len(cols) for cols in bands.values())
            summary['total_features'] += group_features
            summary['groups'][group_name] = group_features
            summary['bands_per_group'][group_name] = len(bands)
            
            # Analyze temporal coverage
            all_dates = set()
            for cols in bands.values():
                for col in cols:
                    date = self._extract_date(col)
                    if date != '00000000':
                        all_dates.add(date)
            
            summary['temporal_coverage'][group_name] = {
                'unique_dates': len(all_dates),
                'date_range': f"{min(all_dates)} to {max(all_dates)}" if all_dates else "No dates"
            }
        
        return summary

# Enhanced analysis runner function
def run_enhanced_feature_engineering_analysis(final_dataset_with_vis, ref_shp_path: str, 
                                            overlap_threshold: float = 0.5,
                                            create_plots: bool = True,
                                            save_plots: bool = False,
                                            output_dir: str = None):
    """
    Run the complete enhanced feature engineering analysis pipeline
    
    Args:
        final_dataset_with_vis: Input dataset with features
        ref_shp_path: Path to reference shapefile
        overlap_threshold: Overlap threshold for labeling
        create_plots: Whether to create distribution plots
        save_plots: Whether to save plots
        output_dir: Output directory for plots
        
    Returns:
        EnhancedFeatureEngineeringAnalyzer: Configured analyzer instance
    """
    print("🎯 Starting Enhanced Feature Engineering Analysis Pipeline...")
    
    # Initialize analyzer
    analyzer = EnhancedFeatureEngineeringAnalyzer(final_dataset_with_vis)
    
    # Step 1: Load reference data
    if not analyzer.load_reference_shapefile(ref_shp_path):
        print("❌ Failed to load reference shapefile!")
        return None
    
    # Step 2: Label segments
    if not analyzer.label_segments_with_reference(overlap_threshold=overlap_threshold):
        print("❌ Failed to label segments!")
        return None
    
    # Step 3: Organize features
    if not analyzer.organize_features_by_bands():
        print("❌ Failed to organize features!")
        return None
    
    # Step 4: Create plots if requested
    if create_plots:
        compactness_scores = analyzer.plot_feature_distributions(
            save_plots=save_plots, 
            output_dir=output_dir
        )
        print(f"✅ Analysis complete! Generated {len(compactness_scores)} compactness scores.")
    
    # Step 5: Print summary
    summary = analyzer.get_feature_summary()
    print(f"\n📋 FINAL SUMMARY:")
    print(f"   Total features organized: {summary['total_features']:,}")
    print(f"   Feature groups: {len(summary['groups'])}")
    for group, count in summary['groups'].items():
        temporal_info = summary['temporal_coverage'][group]
        print(f"     {group}: {count} features, {temporal_info['unique_dates']} dates")
    
    print("✅ Enhanced analysis pipeline completed successfully!")
    return analyzer

# Example usage
if __name__ == "__main__":
    # Define paths
    raw_base = r"F:\_____My_Thesies____\_ImpFiles"
    ref_shp = os.path.join(raw_base, "2.Segments", "_Final_Reference_Combined", "Ref_2024.shp")
    output_dir = os.path.join(raw_base, "plots", "feature_distributions")
    
    # Run enhanced analysis
    analyzer = run_enhanced_feature_engineering_analysis(
        final_dataset_with_VIs,  # the dataset variable
        ref_shp,
        overlap_threshold=0.5,
        create_plots=False,
        save_plots=False,
        output_dir=output_dir
    )
    
    if analyzer:
        # Access organized features
        print("\n🔍 ACCESSING ORGANIZED FEATURES:")
        for group_name, bands in analyzer.organized_features.items():
            print(f"{group_name}:")
            for band, columns in list(bands.items())[:2]:  # Show first 2 bands
                print(f"  {band}: {len(columns)} features")
                if columns:
                    print(f"    Sample: {columns[0]}")
        
        # Access compactness scores
        if analyzer.compactness_scores:
            print(f"\n📊 Top 5 most compact features:")
            sorted_scores = sorted(analyzer.compactness_scores.items(), key=lambda x: x[1])
            for feature, score in sorted_scores[:5]:
                print(f"  {feature}: {score:.3f}")
# Out:
# 🎯 Starting Enhanced Feature Engineering Analysis Pipeline...
# 📂 Loading reference shapefile: F:\_____My_Thesies____\_ImpFiles\2.Segments\_Final_Reference_Combined\Ref_2024.shp
# ✅ Reference shapefile loaded successfully
#    Columns: ['fid_1', 'Name', 'descriptio', 'layer', 'path', 'Feature_ID', 'Area', 'geometry']
#    Number of polygons: 206
#    Unique classes: ['Alfalfa-polygon', 'Bare-polygon', 'Clover-polygon', 'Corn-polygon', 'Degreed_Wetland_Poly-polygon', 'Mixed_TP-polygon', 'Phragmites-polygon', 'Plowed-polygon', 'Rice-polygon', 'Sugar_Beet-polygon', 'Tamarix-polygon', 'Urban-polygon', 'Wheat-polygon']
# 🏷️ Starting segment labeling process...
# 🔄 Processing 206 reference polygons...
#    Processing reference polygon 1/206
#    Processing reference polygon 51/206
#    Processing reference polygon 101/206
#    Processing reference polygon 151/206
#    Processing reference polygon 201/206
#
# 🔧 Applying post-processing to layers...
#    Removed 2 segments belonging to ['Plowed-polygon']
#
# 📊 LABELING RESULTS:
#    Total segments: 6309
#    Labeled segments: 452
#    Unlabeled segments: 5857
#    Average IoU: 0.483
#    Eliminated reference polygons: 0
#
# 🏷️ CLASS DISTRIBUTION:
#    Unknown: 5857 segments
#    Rice-polygon: 150 segments
#    Wheat-polygon: 144 segments
#    Bare-polygon: 39 segments
#    Alfalfa-polygon: 33 segments
#    Urban-polygon: 27 segments
#    Phragmites-polygon: 17 segments
#    Clover-polygon: 14 segments
#    Sugar_Beet-polygon: 9 segments
#    Tamarixs: 7 segments
#    Corn-polygon: 6 segments
#    Degreed_Wetland_Poly-polygon: 6 segments
# 🔍 Organizing features by bands and time series...
#
# 📊 FEATURE ORGANIZATION BY BANDS:
#    Spectral: 9 bands, 540 features
#      - B2: 60 features
#      - B3: 60 features
#      - B4: 60 features
#    SAR: 2 bands, 122 features
#      - VV: 61 features
#      - VH: 61 features
#    VIs: 18 bands, 1062 features
#      - NDVI: 59 features
#      - EVI: 59 features
#      - SAVI: 59 features
#    GLCM: 16 bands, 995 features
#      - Mean_mean: 60 features
#      - Mean_var: 60 features
#      - Variance_mean: 60 features
#    Total organized features: 2719
#
# 📋 FINAL SUMMARY:
#    Total features organized: 2,719
#    Feature groups: 4
#      Spectral: 540 features, 59 dates
#      SAR: 122 features, 61 dates
#      VIs: 1062 features, 0 dates
#      GLCM: 995 features, 72 dates
# ✅ Enhanced analysis pipeline completed successfully!
#
# 🔍 ACCESSING ORGANIZED FEATURES:
# Spectral:
#   B2: 60 features
#     Sample: B2_20240105
#   B3: 60 features
#     Sample: B3_20240105
# SAR:
#   VV: 61 features
#     Sample: VV_20240105
#   VH: 61 features
#     Sample: VH_20240105
# VIs:
#   NDVI: 59 features
#     Sample: NDVI_2024-01-05
#   EVI: 59 features
#     Sample: EVI_2024-01-05
# GLCM:
#   Mean_mean: 60 features
#     Sample: GLCM_20240105_Mean_mean
#   Mean_var: 60 features
#     Sample: GLCM_20240105_Mean_var

# %%
# Define output directory for separability analysis
separability_output_dir = os.path.join(raw_base, "plots", "separability_analysis")

print("🚀 Starting Class Separability Analysis...")
print("="*60)

# Method 1: Run complete analysis pipeline (recommended)
separability_df, summary_report = analyzer.run_complete_separability_analysis(
    max_features=None,  # Set to None for full analysis, or use a number like 100 for testing
    save_all=True,
    output_dir=separability_output_dir
)

# Method 2: Run individual analyses step by step (alternative approach)
"""
# Step-by-step approach if you want more control:

print("\n📊 Step 1: Analyzing all features...")
separability_df = analyzer.analyze_all_features_separability(
    max_features=None,  # None for all features
    save_results=True,
    output_dir=separability_output_dir
)

print("\n🎨 Step 2: Creating separability heatmaps...")
analyzer.create_separability_heatmaps(
    separability_df,
    save_plots=True,
    output_dir=separability_output_dir,
    top_n_features=25
)

print("\n📈 Step 3: Creating class pair plots...")
analyzer.create_class_pair_separability_plots(
    separability_df,
    save_plots=True,
    output_dir=separability_output_dir
)

print("\n📝 Step 4: Creating summary report...")
summary_report = analyzer.create_separability_summary_report(
    separability_df,
    save_report=True,
    output_dir=separability_output_dir
)
"""

print("\n🔍 EXPLORING RESULTS:")
print("="*40)

# Explore the results
if not separability_df.empty:
    print(f"📊 Separability Results Overview:")
    print(f"   Total feature-class comparisons: {len(separability_df):,}")
    print(f"   Unique features analyzed: {separability_df['feature'].nunique():,}")
    print(f"   Class pairs compared: {separability_df['comparison'].nunique()}")
    
    # Show top 10 most separable features
    print(f"\n🏆 TOP 10 MOST SEPARABLE FEATURES (Overall):")
    top_features = separability_df.groupby('feature')['bhattacharyya_divergence'].mean().sort_values(ascending=False)
    for i, (feature, score) in enumerate(top_features.head(10).items()):
        print(f"   {i+1:2d}. {feature:<30} | Divergence: {score:.4f}")
    
    # Show most challenging class pairs to separate
    print(f"\n🤔 MOST CHALLENGING CLASS PAIRS TO SEPARATE:")
    class_difficulty = separability_df.groupby('comparison')['bhattacharyya_divergence'].mean().sort_values()
    for i, (pair, score) in enumerate(class_difficulty.head(5).items()):
        print(f"   {i+1}. {pair:<35} | Avg Divergence: {score:.4f}")
    
    # Show easiest class pairs to separate
    print(f"\n😊 EASIEST CLASS PAIRS TO SEPARATE:")
    for i, (pair, score) in enumerate(class_difficulty.tail(5).items()):
        print(f"   {i+1}. {pair:<35} | Avg Divergence: {score:.4f}")
    
    # Statistical significance summary
    print(f"\n📈 STATISTICAL SIGNIFICANCE SUMMARY:")
    total_comparisons = len(separability_df)
    t_significant = separability_df['t_significant'].sum()
    u_significant = separability_df['u_significant'].sum()
    both_significant = ((separability_df['t_significant']) & (separability_df['u_significant'])).sum()
    
    print(f"   T-test significant: {t_significant:,}/{total_comparisons:,} ({t_significant/total_comparisons*100:.1f}%)")
    print(f"   U-test significant: {u_significant:,}/{total_comparisons:,} ({u_significant/total_comparisons*100:.1f}%)")
    print(f"   Both tests significant: {both_significant:,}/{total_comparisons:,} ({both_significant/total_comparisons*100:.1f}%)")

    # Band group analysis if available
    if hasattr(analyzer, 'organized_features') and summary_report.get('band_group_analysis'):
        print(f"\n🎵 SEPARABILITY BY BAND GROUPS:")
        band_analysis = summary_report['band_group_analysis']
        for group, stats in sorted(band_analysis.items(), key=lambda x: x[1]['mean_separability'], reverse=True):
            print(f"   {group:<12} | Avg Separability: {stats['mean_separability']:.4f} | Features: {stats['n_features']:3d}")
            print(f"                 | Best Feature: {stats['top_feature']}")
    
    # Find features with perfect separability
    perfect_features = separability_df[separability_df['bhattacharyya_divergence'] >= 0.99]
    if not perfect_features.empty:
        print(f"\n⭐ FEATURES WITH NEAR-PERFECT SEPARABILITY (>0.99):")
        perfect_summary = perfect_features.groupby('feature').agg({
            'bhattacharyya_divergence': 'mean',
            'comparison': 'count'
        }).sort_values('bhattacharyya_divergence', ascending=False)
        
        for feature, stats in perfect_summary.head(10).iterrows():
            print(f"   {feature:<30} | Divergence: {stats['bhattacharyya_divergence']:.4f} | Class pairs: {stats['comparison']}")

print(f"\n💾 All results and plots saved to: {separability_output_dir}")

# Optional: Create custom analysis for specific features or class pairs
print(f"\n🔬 CUSTOM ANALYSIS EXAMPLES:")
print("="*40)

# Example 1: Analyze a specific feature across all class pairs
if not separability_df.empty:
    sample_feature = separability_df['feature'].iloc[0]
    print(f"\n📊 Detailed analysis for feature: {sample_feature}")
    feature_analysis = analyzer.perform_statistical_tests(sample_feature)
    
    if feature_analysis and 'comparisons' in feature_analysis:
        print(f"   Found {len(feature_analysis['comparisons'])} class pair comparisons")
        print(f"   Significant t-tests: {feature_analysis['summary']['significant_ttest']}")
        print(f"   Significant U-tests: {feature_analysis['summary']['significant_utest']}")
        print(f"   Mean Bhattacharyya distance: {feature_analysis['summary']['mean_bhattacharyya_distance']:.4f}")

# Example 2: Filter results for specific class pairs
if not separability_df.empty:
    print(f"\n🎯 Analysis for specific class comparisons:")
    # Find comparisons involving Rice
    rice_comparisons = separability_df[separability_df['comparison'].str.contains('Rice')]['comparison'].unique()
    if len(rice_comparisons) > 0:
        print(f"   Rice-related comparisons: {len(rice_comparisons)}")
        rice_data = separability_df[separability_df['comparison'].isin(rice_comparisons)]
        rice_top_features = rice_data.groupby('feature')['bhattacharyya_divergence'].mean().sort_values(ascending=False)
        print(f"   Top 5 features for separating Rice:")
        for i, (feature, score) in enumerate(rice_top_features.head(5).items()):
            print(f"     {i+1}. {feature}: {score:.4f}")

print(f"\n✅ Class Separability Analysis Complete!")
print(f"📁 Check the following files in {separability_output_dir}:")
print(f"   📊 separability_analysis_results.csv - Complete numerical results")
print(f"   🎨 separability_heatmaps.png - Visual heatmaps")  
print(f"   📈 class_pair_separability.png - Class pair analysis")
print(f"   📝 separability_summary_report.txt - Text summary")
print(f"   📄 separability_summary_report.json - JSON summary")
# Out:
# 🚀 Starting Class Separability Analysis...
# ============================================================
# 🚀 Running complete separability analysis pipeline...
# 🔬 Starting comprehensive separability analysis...
# 📊 Analyzing 2780 features across 55 class pairs...
#    Processing feature 1/2780: PXLVAL
#    Processing feature 51/2780: GLCM_20240110_Dissimilarity_var
#    Processing feature 101/2780: B11_20240130
#    Processing feature 151/2780: B6_20240209
#    Processing feature 201/2780: GLCM_20240214_Correlation_mean
#    Processing feature 251/2780: GLCM_20240305_Variance_mean
#    Processing feature 301/2780: B4_20240330
#    Processing feature 351/2780: GLCM_20240404_Correlation_mean
#    Processing feature 401/2780: GLCM_20240414_Dissimilarity_mean
#    Processing feature 451/2780: B12_20240429
#    Processing feature 501/2780: B2_20240514
#    Processing feature 551/2780: GLCM_20240519_Entropy_mean
#    Processing feature 601/2780: GLCM_20240529_Contrast_mean
#    Processing feature 651/2780: GLCM_20240608_Variance_mean
#    Processing feature 701/2780: B8_20240618
#    Processing feature 751/2780: GLCM_20240628_Second_Moment_var
#    Processing feature 801/2780: GLCM_20240708_Contrast_var
#    Processing feature 851/2780: GLCM_20240718_Mean_var
#    Processing feature 901/2780: B8A_20240728
#    Processing feature 951/2780: B5_20240807
#    Processing feature 1001/2780: GLCM_20240812_Second_Moment_var
#    Processing feature 1051/2780: GLCM_20240822_Contrast_var
#    Processing feature 1101/2780: GLCM_20240901_Homogeneity_var
#    Processing feature 1151/2780: GLCM_20240911_Mean_var
#    Processing feature 1201/2780: B7_20240921
#    Processing feature 1251/2780: VV_20240926
#    Processing feature 1301/2780: GLCM_20241006_Second_Moment_var
#    Processing feature 1351/2780: GLCM_20241016_Contrast_var
#    Processing feature 1401/2780: B3_20241105
#    Processing feature 1451/2780: GLCM_20241110_Correlation_var
#    Processing feature 1501/2780: GLCM_20241120_Dissimilarity_var
#    Processing feature 1551/2780: GLCM_20241205_Mean_mean
#    Processing feature 1601/2780: B6_20241215
#    Processing feature 1651/2780: GLCM_20241220_Homogeneity_mean
#    Processing feature 1701/2780: GLCM_20241230_Variance_mean
#    Processing feature 1751/2780: MNDWI_2024-01-10
#    Processing feature 1801/2780: GRVI_2024-02-04
#    Processing feature 1851/2780: NDCI_2024-02-29
#    Processing feature 1901/2780: SAVI_2024-04-04
#    Processing feature 1951/2780: EMBI_2024-04-14
#    Processing feature 2001/2780: LSWI_2024-05-09
#    Processing feature 2051/2780: GNDVI_2024-05-24
#    Processing feature 2101/2780: NDWI_2024-06-08
#    Processing feature 2151/2780: NDVI_2024-06-28
#    Processing feature 2201/2780: MNDWI_2024-07-08
#    Processing feature 2251/2780: GRVI_2024-07-23
#    Processing feature 2301/2780: NDCI_2024-08-07
#    Processing feature 2351/2780: SAVI_2024-08-22
#    Processing feature 2401/2780: EMBI_2024-09-01
#    Processing feature 2451/2780: LSWI_2024-09-16
#    Processing feature 2501/2780: GNDVI_2024-10-01
#    Processing feature 2551/2780: NDWI_2024-10-16
#    Processing feature 2601/2780: NDVI_2024-11-10
#    Processing feature 2651/2780: MNDWI_2024-11-20
#    Processing feature 2701/2780: GRVI_2024-12-10
#    Processing feature 2751/2780: NDCI_2024-12-25
# 💾 Results saved to: F:\_____My_Thesies____\_ImpFiles\plots\separability_analysis\separability_analysis_results.csv
#
# 📊 SEPARABILITY ANALYSIS SUMMARY:
#    Total feature-class comparisons: 152,900
#    Significant t-tests: 89,385
#    Significant U-tests: 92,712
#    Mean Bhattacharyya distance: inf
#    Mean Bhattacharyya divergence: 0.4312
# 🎨 Creating improved separability heatmaps...
# 💾 Improved heatmaps saved to: F:\_____My_Thesies____\_ImpFiles\plots\separability_analysis
# 🎯 Creating focused individual heatmaps...
# 🎵 Creating band group comparison heatmap...
# 📊 Creating class pair separability plots...
# 💾 Class pair plots saved to: F:\_____My_Thesies____\_ImpFiles\plots\separability_analysis
# 📝 Creating separability summary report...
# 💾 Summary report saved to: F:\_____My_Thesies____\_ImpFiles\plots\separability_analysis
#
# 📊 SEPARABILITY ANALYSIS SUMMARY:
#    Total features analyzed: 2,780
#    Total class pairs: 55
#    Mean Bhattacharyya divergence: 0.4312
#    T-test significance rate: 0.5846
#    U-test significance rate: 0.6064
#
# 📊 BAND GROUP SEPARABILITY:
#    Spectral: 0.5044 (avg), 540 features
#    SAR: 0.4381 (avg), 122 features
#    VIs: 0.5354 (avg), 1062 features
#    GLCM: 0.2760 (avg), 995 features
# ✅ Complete separability analysis finished!
#
# 🔍 EXPLORING RESULTS:
# ========================================
# 📊 Separability Results Overview:
#    Total feature-class comparisons: 152,900
#    Unique features analyzed: 2,780
#    Class pairs compared: 55
#
# 🏆 TOP 10 MOST SEPARABLE FEATURES (Overall):
#     1. B11_20240509                   | Divergence: 0.7526
#     2. B12_20240713                   | Divergence: 0.7140
#     3. B12_20240708                   | Divergence: 0.7132
#     4. ENDVI_2024-04-19               | Divergence: 0.7062
#     5. B7_20240419                    | Divergence: 0.7044
#     6. GLCM_20240419_Mean_mean        | Divergence: 0.7033
#     7. B8A_20240419                   | Divergence: 0.7032
#     8. B8_20240419                    | Divergence: 0.7020
#     9. NDMI_2024-07-08                | Divergence: 0.7010
#    10. LSWI_2024-07-08                | Divergence: 0.7010
#
# 🤔 MOST CHALLENGING CLASS PAIRS TO SEPARATE:
#    1. Tamarixs_vs_Degreed_Wetland_Poly-polygon | Avg Divergence: 0.1481
#    2. Phragmites-polygon_vs_Tamarixs      | Avg Divergence: 0.1619
#    3. Wheat-polygon_vs_Corn-polygon       | Avg Divergence: 0.2060
#    4. Wheat-polygon_vs_Clover-polygon     | Avg Divergence: 0.2183
#    5. Phragmites-polygon_vs_Degreed_Wetland_Poly-polygon | Avg Divergence: 0.2228
#
# 😊 EASIEST CLASS PAIRS TO SEPARATE:
#    1. Corn-polygon_vs_Urban-polygon       | Avg Divergence: 0.6159
#    2. Sugar_Beet-polygon_vs_Urban-polygon | Avg Divergence: 0.6258
#    3. Urban-polygon_vs_Degreed_Wetland_Poly-polygon | Avg Divergence: 0.6335
#    4. Urban-polygon_vs_Tamarixs           | Avg Divergence: 0.6344
#    5. Alfalfa-polygon_vs_Urban-polygon    | Avg Divergence: 0.6416
#
# 📈 STATISTICAL SIGNIFICANCE SUMMARY:
#    T-test significant: 89,385/152,900 (58.5%)
#    U-test significant: 92,712/152,900 (60.6%)
#    Both tests significant: 84,258/152,900 (55.1%)
#
# 🎵 SEPARABILITY BY BAND GROUPS:
#    VIs          | Avg Separability: 0.5354 | Features: 1062
#                  | Best Feature: LSWI_2024-07-18
#    Spectral     | Avg Separability: 0.5044 | Features: 540
#                  | Best Feature: B11_20240713
#    SAR          | Avg Separability: 0.4381 | Features: 122
#                  | Best Feature: VV_20240317
#    GLCM         | Avg Separability: 0.2760 | Features: 995
#                  | Best Feature: GLCM_20240320_Second_Moment_mean
#
# ⭐ FEATURES WITH NEAR-PERFECT SEPARABILITY (>0.99):
#    GLCM_20241230_Second_Moment_var | Divergence: 1.0000 | Class pairs: 1.0
#    GLCM_20240429_Second_Moment_var | Divergence: 1.0000 | Class pairs: 16.0
#    GLCM_20240429_Entropy_var      | Divergence: 1.0000 | Class pairs: 16.0
#    GLCM_20240429_Contrast_var     | Divergence: 1.0000 | Class pairs: 8.0
#    GLCM_20240429_Dissimilarity_var | Divergence: 1.0000 | Class pairs: 16.0
#    VV_20240306                    | Divergence: 1.0000 | Class pairs: 1.0
#    VV_20240318                    | Divergence: 1.0000 | Class pairs: 1.0
#    GLCM_20241225_Second_Moment_var | Divergence: 1.0000 | Class pairs: 1.0
#    GLCM_20240105_Homogeneity_mean | Divergence: 1.0000 | Class pairs: 1.0
#    PXLVAL                         | Divergence: 1.0000 | Class pairs: 3.0
#
# 💾 All results and plots saved to: F:\_____My_Thesies____\_ImpFiles\plots\separability_analysis
#
# 🔬 CUSTOM ANALYSIS EXAMPLES:
# ========================================
#
# 📊 Detailed analysis for feature: PXLVAL
#    Found 55 class pair comparisons
#    Significant t-tests: 0
#    Significant U-tests: 0
#    Mean Bhattacharyya distance: 1.3707
#
# 🎯 Analysis for specific class comparisons:
#    Rice-related comparisons: 10
#    Top 5 features for separating Rice:
#      1. MNDWI_2024-06-28: 0.9902
#      2. MNDWI_2024-06-18: 0.9870
#      3. MNDWI_2024-07-03: 0.9518
#      4. MNDWI_2024-06-13: 0.9464
#      5. EMBI_2024-06-18: 0.9316
#
# ✅ Class Separability Analysis Complete!
# 📁 Check the following files in F:\_____My_Thesies____\_ImpFiles\plots\separability_analysis:
#    📊 separability_analysis_results.csv - Complete numerical results
#    🎨 separability_heatmaps.png - Visual heatmaps
#    📈 class_pair_separability.png - Class pair analysis
#    📝 separability_summary_report.txt - Text summary
#    📄 separability_summary_report.json - JSON summary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
import warnings
warnings.filterwarnings('ignore')

class ClassSeparabilityAnalyzer:
    """
    Analyze class separability and recommend merging/deletion strategies
    """
    
    def __init__(self, csv_path):
        """
        Initialize analyzer with separability results CSV
        
        Args:
            csv_path: Path to separability_analysis_results.csv
        """
        self.csv_path = csv_path
        self.df = None
        self.class_analysis = None
        self.recommendations = None
        
    def load_data(self):
        """Load and validate the separability data"""
        print("📂 Loading separability analysis results...")
        
        try:
            self.df = pd.read_csv(self.csv_path)
            print(f"✅ Data loaded successfully!")
            print(f"   Shape: {self.df.shape}")
            print(f"   Columns: {list(self.df.columns)}")
            
            # Basic validation
            required_cols = ['comparison', 'class1', 'class2', 'bhattacharyya_divergence']
            missing_cols = [col for col in required_cols if col not in self.df.columns]
            if missing_cols:
                print(f"❌ Missing required columns: {missing_cols}")
                return False
                
            return True
            
        except Exception as e:
            print(f"❌ Error loading data: {e}")
            return False
    
    def analyze_class_separability(self, min_separability_threshold=0.3):
        """
        Analyze separability for each class and identify problematic pairs
        
        Args:
            min_separability_threshold: Minimum acceptable separability score
        """
        print("🔍 Analyzing class separability...")
        
        # Get unique classes
        all_classes = set(self.df['class1'].unique()) | set(self.df['class2'].unique())
        print(f"📊 Found {len(all_classes)} unique classes:")
        for i, cls in enumerate(sorted(all_classes)):
            print(f"   {i+1:2d}. {cls}")
        
        # Analyze each class
        class_stats = {}
        
        for cls in all_classes:
            # Get all comparisons involving this class
            class_comparisons = self.df[
                (self.df['class1'] == cls) | (self.df['class2'] == cls)
            ].copy()
            
            if class_comparisons.empty:
                continue
            
            # Calculate statistics
            separability_scores = class_comparisons['bhattacharyya_divergence'].dropna()
            
            # Find problematic pairs (low separability)
            problematic_pairs = class_comparisons[
                class_comparisons['bhattacharyya_divergence'] < min_separability_threshold
            ]
            
            # Get partner classes for this class
            partners = set()
            for _, row in class_comparisons.iterrows():
                if row['class1'] == cls:
                    partners.add(row['class2'])
                else:
                    partners.add(row['class1'])
            
            class_stats[cls] = {
                'n_comparisons': len(class_comparisons),
                'mean_separability': separability_scores.mean(),
                'min_separability': separability_scores.min(),
                'max_separability': separability_scores.max(),
                'std_separability': separability_scores.std(),
                'n_problematic_pairs': len(problematic_pairs),
                'problematic_percentage': len(problematic_pairs) / len(class_comparisons) * 100,
                'partner_classes': list(partners),
                'problematic_pairs': []
            }
            
            # Get details of problematic pairs
            for _, row in problematic_pairs.iterrows():
                partner = row['class2'] if row['class1'] == cls else row['class1']
                class_stats[cls]['problematic_pairs'].append({
                    'partner': partner,
                    'separability': row['bhattacharyya_divergence'],
                    'comparison': row['comparison']
                })
        
        self.class_analysis = class_stats
        
        # Print summary
        print(f"\n📊 CLASS SEPARABILITY SUMMARY:")
        print(f"   Minimum separability threshold: {min_separability_threshold}")
        print("="*80)
        
        # Sort classes by problematic percentage
        sorted_classes = sorted(class_stats.items(), 
                              key=lambda x: x[1]['problematic_percentage'], 
                              reverse=True)
        
        for cls, stats in sorted_classes:
            print(f"\n🏷️  {cls}")
            print(f"   Mean separability: {stats['mean_separability']:.3f}")
            print(f"   Min separability:  {stats['min_separability']:.3f}")
            print(f"   Problematic pairs: {stats['n_problematic_pairs']}/{stats['n_comparisons']} ({stats['problematic_percentage']:.1f}%)")
            
            if stats['problematic_pairs']:
                print(f"   Most problematic pairs:")
                # Show top 3 most problematic
                sorted_problems = sorted(stats['problematic_pairs'], 
                                       key=lambda x: x['separability'])
                for i, pair in enumerate(sorted_problems[:3]):
                    print(f"     {i+1}. vs {pair['partner']}: {pair['separability']:.3f}")
    
    def create_separability_matrix(self):
        """Create a matrix showing separability between all class pairs"""
        print("🎨 Creating class separability matrix...")
        
        # Get unique classes
        all_classes = sorted(set(self.df['class1'].unique()) | set(self.df['class2'].unique()))
        
        # Create empty matrix
        matrix = pd.DataFrame(index=all_classes, columns=all_classes, dtype=float)
        
        # Fill matrix
        for _, row in self.df.iterrows():
            class1, class2 = row['class1'], row['class2']
            separability = row['bhattacharyya_divergence']
            
            matrix.loc[class1, class2] = separability
            matrix.loc[class2, class1] = separability  # Symmetric
        
        # Fill diagonal with 0 (same class)
        for cls in all_classes:
            matrix.loc[cls, cls] = 0
        
        # Create visualization
        plt.figure(figsize=(14, 12))
        
        # Clean class names for display
        clean_names = [name.replace('-polygon', '').replace('_merged', '').replace('_', ' ') 
                      for name in all_classes]
        
        # Create heatmap
        mask = matrix.isna()  # Mask missing values
        sns.heatmap(matrix, 
                   annot=True, 
                   fmt='.3f',
                   cmap='RdYlBu_r',
                   center=0.5,
                   square=True,
                   linewidths=0.5,
                   cbar_kws={"shrink": .8, "label": "Bhattacharyya Divergence"},
                   xticklabels=clean_names,
                   yticklabels=clean_names,
                   mask=mask)
        
        plt.title('Class Separability Matrix\n(Higher values = Better separability)', 
                 fontsize=16, pad=20)
        plt.xlabel('Classes', fontsize=12)
        plt.ylabel('Classes', fontsize=12)
        plt.xticks(rotation=45, ha='right')
        plt.yticks(rotation=0)
        
        plt.tight_layout()
        plt.savefig('F:/_____My_Thesies____/Implimantation/3.Train_Model/3.Merge_Classes/2.Merge_TP_T_ElimPowl/separability_analysis/Class Separability Matrix.png', 
        dpi=300, bbox_inches='tight', facecolor='white')
        plt.show()
        
        return matrix
    
    def generate_merge_recommendations(self, 
                                     poor_separability_threshold=0.2,
                                     moderate_separability_threshold=0.4,
                                     min_class_size_threshold=20):
        """
        Generate recommendations for merging or deleting classes
        
        Args:
            poor_separability_threshold: Below this = recommend merge/delete
            moderate_separability_threshold: Below this = recommend merge
            min_class_size_threshold: Minimum segments to keep class
        """
        print("💡 Generating merge/delete recommendations...")
        
        if self.class_analysis is None:
            print("❌ Run analyze_class_separability first!")
            return
        
        recommendations = {
            'delete': [],
            'merge': [],
            'keep': [],
            'summary': {}
        }
        
        # Analyze each class
        for cls, stats in self.class_analysis.items():
            mean_sep = stats['mean_separability']
            min_sep = stats['min_separability']
            problematic_pct = stats['problematic_percentage']
            n_comparisons = stats['n_comparisons']
            
            # Decision logic
            if mean_sep < poor_separability_threshold:
                if problematic_pct > 80:
                    recommendations['delete'].append({
                        'class': cls,
                        'reason': f'Very poor separability (mean: {mean_sep:.3f}, {problematic_pct:.1f}% problematic)',
                        'mean_separability': mean_sep,
                        'problematic_percentage': problematic_pct,
                        'worst_pairs': stats['problematic_pairs'][:3]
                    })
                else:
                    # Find best merge candidate
                    merge_candidate = self._find_best_merge_candidate(cls, stats)
                    recommendations['merge'].append({
                        'class': cls,
                        'merge_with': merge_candidate['partner'] if merge_candidate else 'Unknown',
                        'separability_with_candidate': merge_candidate['separability'] if merge_candidate else 0,
                        'reason': f'Poor separability (mean: {mean_sep:.3f})',
                        'mean_separability': mean_sep,
                        'problematic_percentage': problematic_pct
                    })
            
            elif mean_sep < moderate_separability_threshold and problematic_pct > 50:
                # Find best merge candidate
                merge_candidate = self._find_best_merge_candidate(cls, stats)
                recommendations['merge'].append({
                    'class': cls,
                    'merge_with': merge_candidate['partner'] if merge_candidate else 'Unknown',
                    'separability_with_candidate': merge_candidate['separability'] if merge_candidate else 0,
                    'reason': f'Moderate separability with many problems (mean: {mean_sep:.3f}, {problematic_pct:.1f}% problematic)',
                    'mean_separability': mean_sep,
                    'problematic_percentage': problematic_pct
                })
            
            else:
                recommendations['keep'].append({
                    'class': cls,
                    'reason': f'Good separability (mean: {mean_sep:.3f})',
                    'mean_separability': mean_sep,
                    'problematic_percentage': problematic_pct
                })
        
        # Generate summary
        recommendations['summary'] = {
            'total_classes': len(self.class_analysis),
            'recommend_delete': len(recommendations['delete']),
            'recommend_merge': len(recommendations['merge']),
            'recommend_keep': len(recommendations['keep']),
            'poor_threshold': poor_separability_threshold,
            'moderate_threshold': moderate_separability_threshold
        }
        
        self.recommendations = recommendations
        
        # Print recommendations
        self._print_recommendations()
        
        return recommendations
    
    def _find_best_merge_candidate(self, target_class, stats):
        """Find the best class to merge with (least problematic pair)"""
        if not stats['problematic_pairs']:
            return None
        
        # Sort by separability (descending) to find least problematic
        sorted_pairs = sorted(stats['problematic_pairs'], 
                            key=lambda x: x['separability'], 
                            reverse=True)
        
        return sorted_pairs[0] if sorted_pairs else None
    
    def _print_recommendations(self):
        """Print detailed recommendations"""
        if not self.recommendations:
            return
        
        rec = self.recommendations
        summary = rec['summary']
        
        print(f"\n🎯 MERGE/DELETE RECOMMENDATIONS:")
        print("="*80)
        print(f"Total classes analyzed: {summary['total_classes']}")
        print(f"Recommend DELETE: {summary['recommend_delete']}")
        print(f"Recommend MERGE: {summary['recommend_merge']}")
        print(f"Recommend KEEP: {summary['recommend_keep']}")
        print(f"\nThresholds used:")
        print(f"  Poor separability: < {summary['poor_threshold']}")
        print(f"  Moderate separability: < {summary['moderate_threshold']}")
        
        # DELETE recommendations
        if rec['delete']:
            print(f"\n❌ CLASSES TO DELETE ({len(rec['delete'])}):")
            print("-" * 50)
            for item in rec['delete']:
                print(f"🗑️  {item['class']}")
                print(f"   Reason: {item['reason']}")
                print(f"   Worst confusions:")
                for pair in item['worst_pairs'][:2]:
                    print(f"     - vs {pair['partner']}: {pair['separability']:.3f}")
                print()
        
        # MERGE recommendations
        if rec['merge']:
            print(f"\n🔄 CLASSES TO MERGE ({len(rec['merge'])}):")
            print("-" * 50)
            for item in rec['merge']:
                print(f"🔗 {item['class']} → MERGE WITH → {item['merge_with']}")
                print(f"   Reason: {item['reason']}")
                print(f"   Separability with merge candidate: {item['separability_with_candidate']:.3f}")
                print()
        
        # KEEP recommendations
        if rec['keep']:
            print(f"\n✅ CLASSES TO KEEP ({len(rec['keep'])}):")
            print("-" * 50)
            for item in rec['keep']:
                print(f"✨ {item['class']}")
                print(f"   Mean separability: {item['mean_separability']:.3f}")
                print(f"   Problematic pairs: {item['problematic_percentage']:.1f}%")
            print()
    
    def create_recommendation_plots(self):
        """Create plots showing separability analysis and recommendations"""
        if not self.recommendations:
            print("❌ Generate recommendations first!")
            return
        
        fig, axes = plt.subplots(2, 2, figsize=(16, 12))
        
        # 1. Separability distribution
        all_separabilities = []
        class_names = []
        for cls, stats in self.class_analysis.items():
            all_separabilities.append(stats['mean_separability'])
            class_names.append(cls.replace('-polygon', '').replace('_merged', ''))
        
        axes[0,0].barh(range(len(class_names)), all_separabilities)
        axes[0,0].set_yticks(range(len(class_names)))
        axes[0,0].set_yticklabels(class_names, fontsize=9)
        axes[0,0].set_xlabel('Mean Separability')
        axes[0,0].set_title('Mean Separability by Class')
        axes[0,0].axvline(x=0.2, color='red', linestyle='--', alpha=0.7, label='Poor threshold')
        axes[0,0].axvline(x=0.4, color='orange', linestyle='--', alpha=0.7, label='Moderate threshold')
        axes[0,0].legend()
        axes[0,0].invert_yaxis()
        
        # 2. Problematic pairs percentage
        problematic_pcts = []
        for cls, stats in self.class_analysis.items():
            problematic_pcts.append(stats['problematic_percentage'])
        
        axes[0,1].barh(range(len(class_names)), problematic_pcts, color='coral')
        axes[0,1].set_yticks(range(len(class_names)))
        axes[0,1].set_yticklabels(class_names, fontsize=9)
        axes[0,1].set_xlabel('Problematic Pairs (%)')
        axes[0,1].set_title('Percentage of Problematic Pairs by Class')
        axes[0,1].axvline(x=50, color='orange', linestyle='--', alpha=0.7, label='50% threshold')
        axes[0,1].axvline(x=80, color='red', linestyle='--', alpha=0.7, label='80% threshold')
        axes[0,1].legend()
        axes[0,1].invert_yaxis()
        
        # 3. Recommendation summary pie chart
        rec_counts = [
            self.recommendations['summary']['recommend_keep'],
            self.recommendations['summary']['recommend_merge'],
            self.recommendations['summary']['recommend_delete']
        ]
        rec_labels = ['Keep', 'Merge', 'Delete']
        colors = ['lightgreen', 'gold', 'lightcoral']
        
        axes[1,0].pie(rec_counts, labels=rec_labels, colors=colors, autopct='%1.1f%%')
        axes[1,0].set_title('Recommendation Summary')
        
        # 4. Separability vs Problematic Pairs scatter
        separabilities = [stats['mean_separability'] for stats in self.class_analysis.values()]
        problematic_pcts = [stats['problematic_percentage'] for stats in self.class_analysis.values()]
        
        # Color points by recommendation
        colors = []
        for cls in self.class_analysis.keys():
            if any(item['class'] == cls for item in self.recommendations['delete']):
                colors.append('red')
            elif any(item['class'] == cls for item in self.recommendations['merge']):
                colors.append('orange')
            else:
                colors.append('green')
        
        axes[1,1].scatter(separabilities, problematic_pcts, c=colors, s=60, alpha=0.7)
        axes[1,1].set_xlabel('Mean Separability')
        axes[1,1].set_ylabel('Problematic Pairs (%)')
        axes[1,1].set_title('Separability vs Problematic Pairs')
        axes[1,1].axvline(x=0.2, color='red', linestyle='--', alpha=0.5)
        axes[1,1].axvline(x=0.4, color='orange', linestyle='--', alpha=0.5)
        axes[1,1].axhline(y=50, color='orange', linestyle='--', alpha=0.5)
        axes[1,1].axhline(y=80, color='red', linestyle='--', alpha=0.5)
        
        # Add legend
        from matplotlib.patches import Patch
        legend_elements = [
            Patch(facecolor='green', label='Keep'),
            Patch(facecolor='orange', label='Merge'),
            Patch(facecolor='red', label='Delete')
        ]
        axes[1,1].legend(handles=legend_elements)
        
        plt.tight_layout()
        plt.savefig('F:/_____My_Thesies____/Implimantation/3.Train_Model/3.Merge_Classes/2.Merge_TP_T_ElimPowl/separability_analysis/Separability vs Problematic Pairs.png',
                    dpi=300, bbox_inches='tight', facecolor='white')
        plt.show()
    
    def export_recommendations(self, output_path=None):
        """Export recommendations to CSV file"""
        if not self.recommendations:
            print("❌ Generate recommendations first!")
            return
        
        if output_path is None:
            output_path = self.csv_path.replace('.csv', '_recommendations.csv')
        
        # Prepare data for export
        export_data = []
        
        # Add all classes with their recommendations
        for cls, stats in self.class_analysis.items():
            # Find recommendation type
            rec_type = 'keep'
            merge_with = ''
            
            if any(item['class'] == cls for item in self.recommendations['delete']):
                rec_type = 'delete'
            elif any(item['class'] == cls for item in self.recommendations['merge']):
                rec_type = 'merge'
                merge_item = next(item for item in self.recommendations['merge'] if item['class'] == cls)
                merge_with = merge_item['merge_with']
            
            export_data.append({
                'class': cls,
                'recommendation': rec_type,
                'merge_with': merge_with,
                'mean_separability': stats['mean_separability'],
                'min_separability': stats['min_separability'],
                'max_separability': stats['max_separability'],
                'problematic_pairs_count': stats['n_problematic_pairs'],
                'total_comparisons': stats['n_comparisons'],
                'problematic_percentage': stats['problematic_percentage'],
                'partner_classes': ';'.join(stats['partner_classes'])
            })
        
        # Save to CSV
        export_df = pd.DataFrame(export_data)
        export_df.to_csv(output_path, index=False)
        print(f"💾 Recommendations exported to: {output_path}")
        
        return export_df

def main():
    """Main execution function"""
    # Define the path to your separability results
    csv_path = r"F:\_____My_Thesies____\Implimantation\3.Train_Model\3.Merge_Classes\2.Merge_TP_T_ElimPowl\separability_analysis\separability_analysis_results.csv"
    # Initialize analyzer
    analyzer = ClassSeparabilityAnalyzer(csv_path)
    
    # Load data
    if not analyzer.load_data():
        return
    
    # Analyze separability
    analyzer.analyze_class_separability(min_separability_threshold=0.3)
    
    # Create separability matrix
    matrix = analyzer.create_separability_matrix()
    
    # Generate recommendations
    recommendations = analyzer.generate_merge_recommendations(
        poor_separability_threshold=0.2,
        moderate_separability_threshold=0.4
    )
    
    # Create plots
    analyzer.create_recommendation_plots()
    
    # Export recommendations
    export_df = analyzer.export_recommendations()
    
    print(f"\n🎉 Analysis complete!")
    print(f"📊 Check the plots and exported CSV for detailed recommendations.")
    
    return analyzer

# Run the analysis
if __name__ == "__main__":
    analyzer = main()
# Out:
# 📂 Loading separability analysis results...
# ✅ Data loaded successfully!
#    Shape: (152900, 19)
#    Columns: ['feature', 'comparison', 'class1', 'class2', 'n1', 'n2', 'mean1', 'mean2', 'std1', 'std2', 't_statistic', 't_pvalue', 't_significant', 'u_statistic', 'u_pvalue', 'u_significant', 'bhattacharyya_distance', 'bhattacharyya_divergence', 'separability_score']
# 🔍 Analyzing class separability...
# 📊 Found 11 unique classes:
#     1. Alfalfa-polygon
#     2. Bare-polygon
#     3. Clover-polygon
#     4. Corn-polygon
#     5. Degreed_Wetland_Poly-polygon
#     6. Phragmites-polygon
#     7. Rice-polygon
#     8. Sugar_Beet-polygon
#     9. Tamarixs
#    10. Urban-polygon
#    11. Wheat-polygon
#
# 📊 CLASS SEPARABILITY SUMMARY:
#    Minimum separability threshold: 0.3
# ================================================================================
#
# 🏷️  Phragmites-polygon
#    Mean separability: 0.370
#    Min separability:  0.000
#    Problematic pairs: 14914/27800 (53.6%)
#    Most problematic pairs:
#      1. vs Clover-polygon: 0.000
#      2. vs Alfalfa-polygon: 0.000
#      3. vs Corn-polygon: 0.000
#
# 🏷️  Wheat-polygon
#    Mean separability: 0.377
#    Min separability:  0.000
#    Problematic pairs: 14644/27800 (52.7%)
#    Most problematic pairs:
#      1. vs Alfalfa-polygon: 0.000
#      2. vs Clover-polygon: 0.000
#      3. vs Corn-polygon: 0.000
#
# 🏷️  Alfalfa-polygon
#    Mean separability: 0.384
#    Min separability:  0.000
#    Problematic pairs: 14220/27800 (51.2%)
#    Most problematic pairs:
#      1. vs Clover-polygon: 0.000
#      2. vs Corn-polygon: 0.000
#      3. vs Sugar_Beet-polygon: 0.000
#
# 🏷️  Degreed_Wetland_Poly-polygon
#    Mean separability: 0.376
#    Min separability:  0.000
#    Problematic pairs: 14117/27800 (50.8%)
#    Most problematic pairs:
#      1. vs Clover-polygon: 0.000
#      2. vs Alfalfa-polygon: 0.000
#      3. vs Corn-polygon: 0.000
#
# 🏷️  Tamarixs
#    Mean separability: 0.399
#    Min separability:  0.000
#    Problematic pairs: 14098/27800 (50.7%)
#    Most problematic pairs:
#      1. vs Clover-polygon: 0.000
#      2. vs Alfalfa-polygon: 0.000
#      3. vs Corn-polygon: 0.000
#
# 🏷️  Corn-polygon
#    Mean separability: 0.405
#    Min separability:  0.000
#    Problematic pairs: 13395/27800 (48.2%)
#    Most problematic pairs:
#      1. vs Clover-polygon: 0.000
#      2. vs Alfalfa-polygon: 0.000
#      3. vs Sugar_Beet-polygon: 0.000
#
# 🏷️  Rice-polygon
#    Mean separability: 0.408
#    Min separability:  0.000
#    Problematic pairs: 13353/27800 (48.0%)
#    Most problematic pairs:
#      1. vs Tamarixs: 0.000
#      2. vs Clover-polygon: 0.000
#      3. vs Corn-polygon: 0.000
#
# 🏷️  Clover-polygon
#    Mean separability: 0.419
#    Min separability:  0.000
#    Problematic pairs: 13164/27800 (47.4%)
#    Most problematic pairs:
#      1. vs Alfalfa-polygon: 0.000
#      2. vs Corn-polygon: 0.000
#      3. vs Sugar_Beet-polygon: 0.000
#
# 🏷️  Bare-polygon
#    Mean separability: 0.525
#    Min separability:  0.000
#    Problematic pairs: 9313/27800 (33.5%)
#    Most problematic pairs:
#      1. vs Rice-polygon: 0.000
#      2. vs Corn-polygon: 0.000
#      3. vs Phragmites-polygon: 0.000
#
# 🏷️  Sugar_Beet-polygon
#    Mean separability: 0.511
#    Min separability:  0.000
#    Problematic pairs: 9309/27800 (33.5%)
#    Most problematic pairs:
#      1. vs Clover-polygon: 0.000
#      2. vs Alfalfa-polygon: 0.000
#      3. vs Corn-polygon: 0.000
#
# 🏷️  Urban-polygon
#    Mean separability: 0.569
#    Min separability:  0.000
#    Problematic pairs: 8047/27800 (28.9%)
#    Most problematic pairs:
#      1. vs Clover-polygon: 0.000
#      2. vs Alfalfa-polygon: 0.000
#      3. vs Corn-polygon: 0.000
# 🎨 Creating class separability matrix...
# 💡 Generating merge/delete recommendations...
#
# 🎯 MERGE/DELETE RECOMMENDATIONS:
# ================================================================================
# Total classes analyzed: 11
# Recommend DELETE: 0
# Recommend MERGE: 5
# Recommend KEEP: 6
#
# Thresholds used:
#   Poor separability: < 0.2
#   Moderate separability: < 0.4
#
# 🔄 CLASSES TO MERGE (5):
# --------------------------------------------------
# 🔗 Tamarixs → MERGE WITH → Wheat-polygon
#    Reason: Moderate separability with many problems (mean: 0.399, 50.7% problematic)
#    Separability with merge candidate: 0.300
#
# 🔗 Wheat-polygon → MERGE WITH → Bare-polygon
#    Reason: Moderate separability with many problems (mean: 0.377, 52.7% problematic)
#    Separability with merge candidate: 0.300
#
# 🔗 Degreed_Wetland_Poly-polygon → MERGE WITH → Urban-polygon
#    Reason: Moderate separability with many problems (mean: 0.376, 50.8% problematic)
#    Separability with merge candidate: 0.300
#
# 🔗 Phragmites-polygon → MERGE WITH → Sugar_Beet-polygon
#    Reason: Moderate separability with many problems (mean: 0.370, 53.6% problematic)
#    Separability with merge candidate: 0.300
#
# 🔗 Alfalfa-polygon → MERGE WITH → Rice-polygon
#    Reason: Moderate separability with many problems (mean: 0.384, 51.2% problematic)
#    Separability with merge candidate: 0.300
#
#
# ✅ CLASSES TO KEEP (6):
# --------------------------------------------------
# ✨ Bare-polygon
#    Mean separability: 0.525
#    Problematic pairs: 33.5%
# ✨ Sugar_Beet-polygon
#    Mean separability: 0.511
#    Problematic pairs: 33.5%
# ✨ Clover-polygon
#    Mean separability: 0.419
#    Problematic pairs: 47.4%
# ✨ Corn-polygon
#    Mean separability: 0.405
#    Problematic pairs: 48.2%
# ✨ Rice-polygon
#    Mean separability: 0.408
#    Problematic pairs: 48.0%
# ✨ Urban-polygon
#    Mean separability: 0.569
#    Problematic pairs: 28.9%
# 💾 Recommendations exported to: F:\_____My_Thesies____\Implimantation\3.Train_Model\3.Merge_Classes\2.Merge_TP_T_ElimPowl\separability_analysis\separability_analysis_results_recommendations.csv
#
# 🎉 Analysis complete!
# 📊 Check the plots and exported CSV for detailed recommendations.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import re
import pickle
from typing import Dict, List, Tuple, Optional
from collections import defaultdict
from itertools import combinations
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')

class EnhancedDeltaXMagnitudeAnalyzer:
    """
    Enhanced feature selection with date-wise analysis, Z-score filtering, and PLSR model saving
    """
    
    def __init__(self, labeled_dataset, organized_features, compactness_scores):
        """
        Initialize with labeled dataset and organized features
        
        Args:
            labeled_dataset: GeoDataFrame with labeled segments
            organized_features: Dictionary of organized features by bands
            compactness_scores: Dictionary of compactness scores
        """
        self.labeled_dataset = labeled_dataset.copy()
        self.organized_features = organized_features
        self.compactness_scores = compactness_scores
        self.feature_groups = {
            'Spectral': [],
            'SAR': [],
            'VIs': [],
            'GLCM': []
        }
        # Results storage
        self.band_magnitudes = {}
        self.category_selected_bands = {}
        self.category_eliminated_bands = {}
        self.date_wise_deltax = {}
        self.selected_dates_per_band = {}
        self.final_selected_features = []
        self.filtered_dataset = None
        self.correlation_results = {}
        self.high_corr_pairs = {}
        self.pls_features = {}
        self.pls_models = {}  # Store trained PLSR models
        self.categorized_features = {}  # Store categorized features
        
        # Vector colors for plotting
        self.vector_colors = ['red', 'blue', 'green', 'purple', 'orange', 'brown', 'pink', 'gray']
    
    def debug_vi_columns(self):
        """Debug function to understand VI column naming patterns"""
        print("🔍 Debugging VI column patterns...")
        
        vi_list = ['NDVI', 'EVI', 'SAVI', 'TDVI', 'NDWI', '2BDA', 'NDCI', 'ENDVI', 
                   'GNDVI', 'NDRE', 'GRVI', 'MSAVI', 'LSWI', 'NDMI', 'MNDWI', 
                   'MBI', 'EMBI', 'MCARI2']
        
        all_columns = list(self.labeled_dataset.columns)
        
        for vi in vi_list[:3]:  # Check first 3 VIs
            vi_columns = []
            vi_lower = vi.lower()
            
            for col in all_columns:
                col_lower = col.lower()
                if (col.startswith(f'{vi}_') or col.startswith(f'{vi}-') or 
                    col_lower.startswith(f'{vi_lower}_') or col_lower.startswith(f'{vi_lower}-') or
                    vi_lower in col_lower):
                    vi_columns.append(col)
            
            if vi_columns:
                print(f"  {vi}: Found {len(vi_columns)} columns")
                print(f"    Sample: {vi_columns[:3]}")
                
                # Test date extraction
                for col in vi_columns[:3]:
                    date = self.extract_date_from_column(col)
                    print(f"    {col} -> Date: {date}")
            else:
                print(f"  {vi}: No columns found")

    def categorize_features(self) -> Dict[str, Dict[str, List[str]]]:
        """Categorize features into Spectral, SAR, GLCM, and VIs based on column names"""
        print("🏷️ Categorizing features...")
        
        categorized_features = {
            'Spectral': {},
            'SAR': {},
            'GLCM': {},
            'VIs': {}
        }
        
        # Get all column names from the dataset
        all_columns = list(self.labeled_dataset.columns)
        
        # Define all VIs to match exactly
        vi_list = ['NDVI', 'EVI', 'SAVI', 'TDVI', 'NDWI', '2BDA', 'NDCI', 'ENDVI', 
                   'GNDVI', 'NDRE', 'GRVI', 'MSAVI', 'LSWI', 'NDMI', 'MNDWI', 
                   'MBI', 'EMBI', 'MCARI2']
        
        # Define GLCM metrics
        glcm_metrics = ['Mean_mean', 'Mean_var', 'Variance_mean', 'Variance_var',
                       'Homogeneity_mean', 'Homogeneity_var', 'Contrast_mean', 'Contrast_var',
                       'Dissimilarity_mean', 'Dissimilarity_var', 'Entropy_mean', 'Entropy_var',
                       'Second_Moment_mean', 'Second_Moment_var', 'Correlation_mean', 'Correlation_var']
        
        # Categorize based on column name patterns
        for column in all_columns:
            col_lower = column.lower()
            
            # Skip non-feature columns
            if column in ['geometry', 'label', 'layer', 'segment_area', 'PXLVAL']:
                continue
            
            # Determine category based on column name patterns
            category = None
            band_name = column
            
            # Check for Vegetation Indices first (more specific patterns)
            for vi in vi_list:
                vi_lower = vi.lower()
                # Check if column starts with VI name followed by underscore or dash
                if (column.startswith(f'{vi}_') or column.startswith(f'{vi}-') or 
                    col_lower.startswith(f'{vi_lower}_') or col_lower.startswith(f'{vi_lower}-')):
                    category = 'VIs'
                    band_name = vi
                    break
            
            # Check for GLCM features - pattern: GLCM_YYYYMMDD_Metric_stat
            if not category and column.startswith('GLCM_'):
                category = 'GLCM'
                # Extract metric from GLCM column name
                parts = column.split('_')
                if len(parts) >= 4:  # GLCM_date_metric_stat
                    metric_stat = '_'.join(parts[2:])  # metric_stat part
                    band_name = metric_stat
                elif len(parts) == 3:  # GLCM_metric_stat
                    metric_stat = '_'.join(parts[1:])  # metric_stat part
                    band_name = metric_stat
                else:
                    band_name = '_'.join(parts[1:])  # fallback
            
            # Check for SAR bands
            if not category and any(sar_pattern in col_lower for sar_pattern in ['vv_', 'vh_']):
                category = 'SAR'
                if 'vv_' in col_lower:
                    band_name = 'VV'
                elif 'vh_' in col_lower:
                    band_name = 'VH'
            
            # Check for Spectral bands (B2, B3, etc.) - be more specific
            if not category:
                # Look for patterns like B2_, B3_, B8A_, etc.
                spectral_pattern = r'b(\d{1,2}a?)_'
                match = re.search(spectral_pattern, col_lower)
                if match:
                    category = 'Spectral'
                    band_name = f'B{match.group(1).upper()}'
            
            # If categorized, add to the appropriate category
            if category:
                if band_name not in categorized_features[category]:
                    categorized_features[category][band_name] = []
                categorized_features[category][band_name].append(column)
        
        # Print categorization results
        print(f"📊 FEATURE CATEGORIZATION RESULTS:")
        for category, bands in categorized_features.items():
            total_features = sum(len(cols) for cols in bands.values())
            print(f"  {category}: {len(bands)} bands, {total_features} features")
            for band_key in list(bands.keys())[:3]:  # Show first 3 bands
                print(f"    - {band_key}: {len(bands[band_key])} features")
            if len(bands) > 3:
                print(f"    ... and {len(bands)-3} more")
        
        # Store in instance variable and return the dictionary
        self.categorized_features = categorized_features
        return categorized_features
    
    def extract_date_from_column(self, column_name: str) -> str:
        """Extract date from column name"""
        # Look for date patterns (YYYYMMDD)
        date_patterns = [
            r'(\d{8})',  # 20240101
            r'[-_](\d{4})[-_]?(\d{2})[-_]?(\d{2})',  # 2024-01-01 or 2024_01_01
            r'(\d{4})(\d{2})(\d{2})'  # 20240101 anywhere in string
        ]
        
        for pattern in date_patterns:
            match = re.search(pattern, column_name)
            if match:
                if len(match.groups()) == 1:
                    return match.group(1)
                elif len(match.groups()) == 3:
                    return f"{match.group(1)}{match.group(2)}{match.group(3)}"
        
        return None
    
    def calculate_deltaX_magnitudes_by_date(self, class_column: str = 'layer', 
                                          min_dates: int = 4, max_dates: int = 10,
                                          save_plots: bool = True, 
                                          output_dir: str = None) -> Dict[str, Dict[str, Dict[str, float]]]:
        """
        Calculate Delta-X magnitudes for each date within each band, then select best dates
        """
        print("📊 Calculating Delta-X magnitudes by date...")
        
        # Get categorized features
        categorized_features = self.categorize_features()
        
        if not categorized_features:
            print("❌ No categorized features found!")
            return {}

        if save_plots and output_dir:
            plots_dir = os.path.join(output_dir, 'plots')
            os.makedirs(plots_dir, exist_ok=True)
        else:
            plots_dir = None
        
        category_date_magnitudes = {}
        
        # Prepare data - only use labeled segments
        plot_data = self.labeled_dataset[self.labeled_dataset[class_column] != 'Unknown'].copy()
        
        if plot_data.empty:
            print("❌ No labeled data available!")
            return {}
        
        unique_classes = sorted(plot_data[class_column].unique())
        print(f"📋 Classes found: {unique_classes}")
        
        if len(unique_classes) < 2:
            print("❌ Need at least 2 classes for Delta-X analysis!")
            return {}
        
        # Process each category
        for category, bands in categorized_features.items():
            if not bands:
                continue
                
            print(f"\n📈 Processing {category} category...")
            category_date_magnitudes[category] = {}
            
            for band_name, columns in bands.items():
                if not columns:
                    continue
                
                print(f"  🔍 Analyzing band: {band_name} ({len(columns)} features)")
                
                # Group columns by date
                date_columns = {}
                for col in columns:
                    date = self.extract_date_from_column(col)
                    if date:
                        if date not in date_columns:
                            date_columns[date] = []
                        date_columns[date].append(col)
                
                if not date_columns:
                    print(f"    ⚠️ No dates found for {band_name}, skipping...")
                    continue
                
                # Calculate Delta-X for each date
                date_magnitudes = {}
                for date, date_cols in date_columns.items():
                    try:
                        # Use first column for this date (or average if multiple)
                        if len(date_cols) == 1:
                            feature_data = plot_data[date_cols[0]].dropna()
                        else:
                            # Average multiple columns for same date
                            feature_data = plot_data[date_cols].mean(axis=1).dropna()
                        
                        if len(feature_data) < 10:  # Need minimum data points
                            continue
                        
                        # Calculate class means
                        class_means = []
                        valid_classes = []
                        
                        for class_name in unique_classes:
                            class_data = feature_data[plot_data.loc[feature_data.index, class_column] == class_name]
                            if len(class_data) >= 3:  # Minimum samples per class
                                class_means.append(class_data.mean())
                                valid_classes.append(class_name)
                        
                        if len(valid_classes) >= 2:
                            # Calculate Delta-X magnitude (range of class means)
                            delta_x = max(class_means) - min(class_means)
                            date_magnitudes[date] = delta_x
                        
                    except Exception as e:
                        print(f"    ⚠️ Error processing date {date}: {e}")
                        continue
                
                if date_magnitudes:
                    # Select best dates for this band
                    sorted_dates = sorted(date_magnitudes.items(), key=lambda x: x[1], reverse=True)
                    
                    # Ensure we have between min_dates and max_dates
                    num_dates_to_select = min(max_dates, max(min_dates, len(sorted_dates)))
                    selected_dates = sorted_dates[:num_dates_to_select]
                    
                    category_date_magnitudes[category][band_name] = {
                        'all_dates': date_magnitudes,
                        'selected_dates': selected_dates,
                        'date_columns': date_columns
                    }
                    
                    print(f"    ✅ Selected {len(selected_dates)}/{len(date_magnitudes)} dates for {band_name}")
                    
                    # Plot if requested
                    if plots_dir:
                        self.plot_band_date_selection(
                            band_name, category, date_magnitudes, selected_dates, plots_dir
                        )
        
        self.date_wise_deltax = category_date_magnitudes
        return category_date_magnitudes
    
    def plot_band_date_selection(self, band_name: str, category: str, 
                               date_magnitudes: Dict[str, float],
                               selected_dates: List[Tuple[str, float]], 
                               plots_dir: str):
        """Plot date-wise Delta-X magnitudes and highlight selected dates"""
        
        plt.figure(figsize=(12, 6))
        
        dates = list(date_magnitudes.keys())
        magnitudes = list(date_magnitudes.values())
        selected_date_strs = [date for date, _ in selected_dates]
        
        # Create bar plot
        bars = plt.bar(range(len(dates)), magnitudes, alpha=0.7, color='skyblue')
        
        # Highlight selected dates
        for i, date in enumerate(dates):
            if date in selected_date_strs:
                bars[i].set_color('red')
                bars[i].set_alpha(0.9)
        
        plt.title(f'{category} - {band_name}: Date-wise Delta-X Magnitudes')
        plt.xlabel('Date')
        plt.ylabel('Delta-X Magnitude')
        plt.xticks(range(len(dates)), dates, rotation=45)
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        
        # Save plot
        filename = f"{category}_{band_name}_date_selection.png"
        plt.savefig(os.path.join(plots_dir, filename), dpi=300, bbox_inches='tight')
        plt.close()
    
    def select_features_by_category(self, min_retention_rate: float = 0.7) -> Dict[str, Tuple[List[str], List[str]]]:
        """
        Select features by category ensuring at least 70% retention per category
        """
        print(f"\n🔍 Selecting features by category (minimum {min_retention_rate*100}% retention per category)...")
        
        category_results = {}
        
        for category in self.date_wise_deltax.keys():
            if category not in self.selected_dates_per_band:
                continue
            
            print(f"\n📊 Processing {category} category...")
            
            band_data = self.selected_dates_per_band[category]
            band_names = list(band_data.keys())
            
            # Calculate average magnitude across selected dates for each band
            band_avg_magnitudes = {}
            for band_name, data in band_data.items():
                selected_dates = data['selected_dates']
                all_magnitudes = data['all_magnitudes']
                
                # Average magnitude of selected dates
                selected_magnitudes = [all_magnitudes[date] for date in selected_dates if date in all_magnitudes]
                if selected_magnitudes:
                    band_avg_magnitudes[band_name] = np.mean(selected_magnitudes)
            
            if not band_avg_magnitudes:
                continue
            
            # Calculate minimum number of bands to retain
            total_bands = len(band_avg_magnitudes)
            min_bands_to_retain = max(1, int(np.ceil(total_bands * min_retention_rate)))
            
            print(f"  Total bands: {total_bands}, Min to retain: {min_bands_to_retain}")
            
            # Get compactness scores for this category
            category_compactness = {}
            for band_name in band_avg_magnitudes.keys():
                # Find matching compactness scores
                for comp_key, comp_score in self.compactness_scores.items():
                    if (band_name.lower() in comp_key.lower() or 
                        any(part in comp_key.lower() for part in band_name.lower().split('_')) or
                        comp_key.lower() in band_name.lower()):
                        category_compactness[band_name] = comp_score
                        break
            
            # Combine compactness and magnitude scores
            combined_scores = {}
            
            for band_name in band_avg_magnitudes.keys():
                magnitude = band_avg_magnitudes[band_name]
                compactness = category_compactness.get(band_name, 0)
                
                # Normalize both scores to 0-1 range within category
                mag_values = list(band_avg_magnitudes.values())
                comp_values = list(category_compactness.values()) if category_compactness else [0]
                
                # Normalize magnitude (higher is better)
                if len(mag_values) > 1:
                    mag_min, mag_max = min(mag_values), max(mag_values)
                    if mag_max > mag_min:
                        norm_magnitude = (magnitude - mag_min) / (mag_max - mag_min)
                    else:
                        norm_magnitude = 0.5
                else:
                    norm_magnitude = 1.0
                
                # Normalize compactness (higher is better)
                if len(comp_values) > 1 and max(comp_values) > min(comp_values):
                    comp_min, comp_max = min(comp_values), max(comp_values)
                    norm_compactness = (compactness - comp_min) / (comp_max - comp_min)
                else:
                    norm_compactness = 0.5 if compactness == 0 else 1.0
                
                # Combined score (equal weight to both)
                combined_score = 0.5 * norm_magnitude + 0.5 * norm_compactness
                combined_scores[band_name] = combined_score
            
            # Sort by combined score (descending)
            sorted_bands = sorted(combined_scores.items(), key=lambda x: x[1], reverse=True)
            
            # Select top bands (ensure at least minimum retention)
            selected_bands = [band for band, score in sorted_bands[:min_bands_to_retain]]
            eliminated_bands = [band for band, score in sorted_bands[min_bands_to_retain:]]
            
            category_results[category] = (selected_bands, eliminated_bands)
            
            print(f"  ✅ Selected: {len(selected_bands)}/{total_bands} bands ({len(selected_bands)/total_bands*100:.1f}%)")
            print(f"  ❌ Eliminated: {len(eliminated_bands)} bands")
            
            for band in selected_bands:
                mag = band_avg_magnitudes.get(band, 0)
                comp = category_compactness.get(band, 0)
                combined = combined_scores.get(band, 0)
                print(f"    ✅ {band}: Mag={mag:.4f}, Comp={comp:.4f}, Combined={combined:.4f}")
        
        self.category_selected_bands = {cat: result[0] for cat, result in category_results.items()}
        self.category_eliminated_bands = {cat: result[1] for cat, result in category_results.items()}
        
        return category_results
    
    def create_selected_features_dataset(self):
        """
        Create dataset with only selected date-wise features
        """
        print("\n🔄 Creating dataset with selected date-wise features...")
        
        if not self.date_wise_deltax:
            print("❌ No date-wise analysis available!")
            return None
        
        selected_columns = ['geometry', 'label', 'layer']
        selected_features = []
        
        # Collect selected features from each category
        for category, bands in self.date_wise_deltax.items():
            for band_name, band_info in bands.items():
                selected_dates = band_info.get('selected_dates', [])
                date_columns = band_info.get('date_columns', {})
                
                for date, magnitude in selected_dates:
                    if date in date_columns:
                        # Add all columns for this selected date
                        selected_features.extend(date_columns[date])
        
        # Remove duplicates and filter existing columns
        selected_features = list(set(selected_features))
        existing_features = [col for col in selected_features if col in self.labeled_dataset.columns]
        
        all_selected_columns = selected_columns + existing_features
        
        # Create filtered dataset
        self.filtered_dataset = self.labeled_dataset[all_selected_columns].copy()
        
        print(f"✅ Created filtered dataset with {len(existing_features)} selected features")
        print(f"   Original features: {len(self.labeled_dataset.columns) - 3}")
        print(f"   Selected features: {len(existing_features)}")
        print(f"   Retention rate: {len(existing_features)/(len(self.labeled_dataset.columns) - 3)*100:.1f}%")
        
        return self.filtered_dataset
    
    def plot_correlation_by_category(self, save_plots: bool = True, output_dir: str = None):
        """
        Plot Pearson correlation matrices for each category using selected date-wise features
        """
        print("📊 Plotting Pearson correlation matrices by category...")
        
        if self.filtered_dataset is None:
            print("❌ No filtered dataset available!")
            return {}
        
        if save_plots and output_dir:
            plots_dir = os.path.join(output_dir, 'plots')
            os.makedirs(plots_dir, exist_ok=True)
        else:
            plots_dir = None
        
        correlation_results = {}
        
        # Re-categorize features in filtered dataset
        categorized_features = {}
        for category in ['Spectral', 'SAR', 'GLCM', 'VIs']:
            categorized_features[category] = []
        
        # Categorize features in filtered dataset
        for col in self.filtered_dataset.columns:
            if col in ['geometry', 'label', 'layer']:
                continue
            
            col_lower = col.lower()
            
            # Check for VIs
            vi_list = ['NDVI', 'EVI', 'SAVI', 'TDVI', 'NDWI', '2BDA', 'NDCI', 'ENDVI', 
                      'GNDVI', 'NDRE', 'GRVI', 'MSAVI', 'LSWI', 'NDMI', 'MNDWI', 
                      'MBI', 'EMBI', 'MCARI2']
            
            categorized = False
            for vi in vi_list:
                if col.startswith(f'{vi}_') or col.startswith(f'{vi.lower()}_'):
                    categorized_features['VIs'].append(col)
                    categorized = True
                    break
            
            if not categorized:
                if 'glcm' in col_lower:
                    categorized_features['GLCM'].append(col)
                elif any(x in col_lower for x in ['vv_', 'vh_']):
                    categorized_features['SAR'].append(col)
                elif any(f'b{i}_' in col_lower for i in range(2, 13)) or 'b8a_' in col_lower:
                    categorized_features['Spectral'].append(col)
        
        # Plot correlation matrix for each category
        for category, features in categorized_features.items():
            if len(features) < 2:
                print(f"⚠️ {category}: Too few features ({len(features)}) for correlation analysis")
                continue
            
            try:
                # Calculate correlation matrix
                feature_data = self.filtered_dataset[features].select_dtypes(include=[np.number])
                if feature_data.empty:
                    continue
                    
                correlation_matrix = feature_data.corr(method='pearson')
                correlation_results[category] = correlation_matrix
                
                # Plot correlation heatmap
                if plots_dir:
                    plt.figure(figsize=(12, 10))
                    mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
                    sns.heatmap(correlation_matrix, mask=mask, annot=True, cmap='RdYlBu_r', 
                               center=0, square=True, fmt='.2f', cbar_kws={"shrink": 0.8})
                    plt.title(f'{category} Features - Pearson Correlation Matrix')
                    plt.tight_layout()
                    
                    filename = f"{category}_correlation_matrix.png"
                    plt.savefig(os.path.join(plots_dir, filename), dpi=300, bbox_inches='tight')
                    plt.close()
                
                print(f"✅ {category}: Correlation matrix calculated ({feature_data.shape[1]} features)")
                
            except Exception as e:
                print(f"⚠️ Error calculating correlation for {category}: {e}")
                continue
        
        self.correlation_results = correlation_results
        return correlation_results
    
    def find_high_correlation_pairs(self, threshold: float = 0.95) -> Dict[str, List[Tuple[str, str, float]]]:
        """
        Find pairs with correlation > threshold
        """
        print(f"\n🔍 Finding high correlation pairs (threshold: {threshold})...")
        
        high_corr_pairs = {}
        
        for category, corr_matrix in self.correlation_results.items():
            pairs = []
            
            # Get upper triangle indices
            upper_triangle = np.triu(np.ones_like(corr_matrix, dtype=bool), k=1)
            high_corr_indices = np.where((np.abs(corr_matrix) > threshold) & upper_triangle)
            
            for i, j in zip(high_corr_indices[0], high_corr_indices[1]):
                feature1 = corr_matrix.index[i]
                feature2 = corr_matrix.columns[j]
                correlation = corr_matrix.iloc[i, j]
                pairs.append((feature1, feature2, correlation))
            
            if pairs:
                high_corr_pairs[category] = pairs
                print(f"  {category}: {len(pairs)} high correlation pairs found")
            else:
                print(f"  {category}: No high correlation pairs found")
        
        self.high_corr_pairs = high_corr_pairs
        return high_corr_pairs
    
    def apply_pls_feature_engineering(self, target_column: str = 'layer', 
                                    save_plots: bool = True, output_dir: str = None,
                                    save_models: bool = True):
        """
        Apply PLS regression to highly correlated pairs and save models
        """
        print(f"\n🔬 Applying PLS feature engineering...")
        
        if not self.high_corr_pairs:
            print("❌ No high correlation pairs available!")
            return {}
        
        if save_plots and output_dir:
            plots_dir = os.path.join(output_dir, 'plots')
            os.makedirs(plots_dir, exist_ok=True)
        else:
            plots_dir = None
            
        if save_models and output_dir:
            models_dir = os.path.join(output_dir, 'pls_models')
            os.makedirs(models_dir, exist_ok=True)
        else:
            models_dir = None
        
        # Prepare label encoder once if needed
        if self.filtered_dataset[target_column].dtype == 'object':
            label_encoder = LabelEncoder()
            # Fit on the entire target column
            label_encoder.fit(self.filtered_dataset[target_column])
        else:
            label_encoder = None
        
        pls_features = {}
        
        for category, pairs in self.high_corr_pairs.items():
            print(f"\n🔬 Processing {category} category ({len(pairs)} pairs)...")
            
            for i, (feature1, feature2, correlation) in enumerate(pairs):
                pls_name = f"PLS_{category}_{i+1}"
                
                try:
                    # Get feature data and target for the same rows
                    features_and_target = self.filtered_dataset[[feature1, feature2, target_column]].dropna()
                    
                    if features_and_target.empty or len(features_and_target) < 10:
                        print(f"  ⚠️ Skipping {pls_name}: insufficient data ({len(features_and_target)} samples)")
                        continue
                    
                    # Extract features and target
                    X = features_and_target[[feature1, feature2]]
                    y_raw = features_and_target[target_column]
                    
                    # Encode target if categorical
                    if label_encoder is not None:
                        y_aligned = label_encoder.transform(y_raw)
                    else:
                        y_aligned = y_raw.values
                    
                    # Scale features
                    scaler = StandardScaler()
                    X_scaled = scaler.fit_transform(X)
                    
                    # Apply PLS regression
                    pls = PLSRegression(n_components=1, scale=False)
                    pls_result = pls.fit_transform(X_scaled, y_aligned)[0].flatten()
                    
                    # Store PLS feature
                    pls_features[pls_name] = pls_result
                    
                    # Store model information
                    model_info = {
                        'pls_model': pls,
                        'scaler': scaler,
                        'label_encoder': label_encoder,
                        'features': [feature1, feature2],
                        'correlation': correlation,
                        'category': category,
                        'sample_indices': features_and_target.index.tolist()  # Store indices for reference
                    }
                    
                    if save_models and models_dir:
                        model_file = os.path.join(models_dir, f"{pls_name}_model.pkl")
                        with open(model_file, 'wb') as f:
                            pickle.dump(model_info, f)
                    
                    self.pls_models[pls_name] = model_info
                    
                    print(f"  ✅ {pls_name}: PLS feature created (r={correlation:.3f}, n={len(features_and_target)})")
                    
                    # Create plots if requested
                    if plots_dir:
                        self.create_pls_plots(pls_name, model_info, X, y_aligned, X_scaled, pls_result, plots_dir)
                
                except Exception as e:
                    print(f"  ⚠️ Error creating {pls_name}: {e}")
                    continue
        
        print(f"\n✅ Created {len(pls_features)} PLS features")
        self.pls_features = pls_features
        return pls_features
    
    def create_pls_plots(self, pls_name, model_info, feature_data, y_aligned, X_scaled, pls_result, plots_dir):
        """Create comprehensive PLS plots"""
        
        fig, axs = plt.subplots(2, 2, figsize=(15, 12))
        
        # 1. PLS vs target scatter
        axs[0, 0].scatter(pls_result, y_aligned, alpha=0.6)
        axs[0, 0].set_xlabel('PLS Component')
        axs[0, 0].set_ylabel('Target Variable')
        axs[0, 0].set_title(f'{pls_name}: PLS vs Target')
        axs[0, 0].grid(True, alpha=0.3)
        
        # 2. Original features correlation
        axs[0, 1].scatter(feature_data.iloc[:, 0], feature_data.iloc[:, 1], alpha=0.6)
        axs[0, 1].set_xlabel(model_info['features'][0])
        axs[0, 1].set_ylabel(model_info['features'][1])
        axs[0, 1].set_title(f'Original Features (r={model_info["correlation"]:.3f})')
        axs[0, 1].grid(True, alpha=0.3)
        
        # 3. PLS weights
        weights = model_info['pls_model'].x_weights_.flatten()
        axs[1, 0].bar(range(len(weights)), weights)
        axs[1, 0].set_xlabel('Feature Index')
        axs[1, 0].set_ylabel('PLS Weight')
        axs[1, 0].set_title('PLS Component Weights')
        axs[1, 0].set_xticks(range(len(weights)))
        axs[1, 0].set_xticklabels([f'F{i+1}' for i in range(len(weights))])
        
        # 4. PLS component distribution
        axs[1, 1].hist(pls_result, bins=30, alpha=0.7, edgecolor='black')
        axs[1, 1].set_xlabel('PLS Component Value')
        axs[1, 1].set_ylabel('Frequency')
        axs[1, 1].set_title('PLS Component Distribution')
        axs[1, 1].grid(True, alpha=0.3)
        
        plt.suptitle(f'{pls_name} - PLS Analysis', fontsize=16)
        plt.tight_layout()
        
        filename = f"{pls_name}_analysis.png"
        plt.savefig(os.path.join(plots_dir, filename), dpi=300, bbox_inches='tight')
        plt.close()
    
    def apply_pls_to_unlabeled_data(self, unlabeled_dataset, output_path: str = None):
        """
        Apply trained PLS models to unlabeled data
        """
        print(f"\n🔮 Applying PLS models to unlabeled data...")
        
        if not self.pls_models:
            print("❌ No trained PLS models available!")
            return None
        
        # Create a copy of unlabeled dataset
        unlabeled_processed = unlabeled_dataset.copy()
        
        for pls_name, model_info in self.pls_models.items():
            try:
                pls_model = model_info['pls_model']
                scaler = model_info['scaler']
                original_features = model_info['original_features']
                z_score_name = model_info['z_score_name']
                
                # Check if original features exist in unlabeled data
                missing_features = [f for f in original_features if f not in unlabeled_processed.columns]
                if missing_features:
                    print(f"  ⚠️ Missing features for {pls_name}: {missing_features}")
                    continue
                
                # Prepare data
                feature_data = unlabeled_processed[original_features].dropna()
                if feature_data.empty:
                    continue
                
                # Apply same preprocessing
                X_scaled = scaler.transform(feature_data)
                
                # Apply PLS transformation
                pls_result = pls_model.transform(X_scaled)[0].ravel()
                
                # Add to dataset
                unlabeled_processed[pls_name] = np.nan
                unlabeled_processed.loc[feature_data.index, pls_name] = pls_result
                
                # Calculate Z-score using the same parameters from training
                if z_score_name in self.filtered_dataset.columns:
                    # Use training data statistics
                    train_values = self.filtered_dataset[pls_name].dropna()
                    if len(train_values) > 1:
                        train_mean = train_values.mean()
                        train_std = train_values.std()
                        if train_std > 0:
                            unlabeled_processed[z_score_name] = (
                                unlabeled_processed[pls_name] - train_mean
                            ) / train_std
                
                print(f"    ✅ Applied {pls_name} to {len(feature_data)} samples")
                
            except Exception as e:
                print(f"    ⚠️ Error applying {pls_name}: {e}")
        
        if output_path:
            try:
                # Save processed unlabeled data
                if isinstance(unlabeled_processed, gpd.GeoDataFrame):
                    df_to_save = unlabeled_processed.copy()
                    if 'geometry' in df_to_save.columns:
                        df_to_save['geometry'] = df_to_save['geometry'].apply(
                            lambda x: x.wkt if x is not None else None
                        )
                else:
                    df_to_save = unlabeled_processed
                
                df_to_save.to_csv(output_path, index=False)
                print(f"  💾 Unlabeled data with PLS features saved: {output_path}")
                
            except Exception as e:
                print(f"  ⚠️ Error saving unlabeled data: {e}")
        
        return unlabeled_processed
    
    def create_final_dataset(self) -> pd.DataFrame:
        """
        Create final dataset with selected date-wise features and PLS-engineered features
        """
        print("\n🔄 Creating final dataset...")
        
        if self.filtered_dataset is None:
            print("❌ No filtered dataset available!")
            return None
        
        # Start with essential columns
        essential_cols = ['geometry', 'label', 'layer']
        available_essential = [col for col in essential_cols if col in self.filtered_dataset.columns]
        
        final_dataset = self.filtered_dataset[available_essential].copy()
        
        # Add selected features (exclude PLS input features that will be replaced)
        feature_cols = [col for col in self.filtered_dataset.columns 
                       if col not in essential_cols]
        
        # Add original selected features
        final_dataset = pd.concat([final_dataset, self.filtered_dataset[feature_cols]], axis=1)
        
        # Add PLS features
        for pls_name, pls_values in self.pls_features.items():
            final_dataset[pls_name] = pls_values
        
        print(f"✅ Final dataset created:")
        print(f"   Total features: {len(final_dataset.columns) - len(available_essential)}")
        print(f"   Original features: {len(feature_cols)}")
        print(f"   PLS features: {len(self.pls_features)}")
        print(f"   Dataset shape: {final_dataset.shape}")
        
        return final_dataset
    
    def save_final_results(self, output_path: str, final_dataset: pd.DataFrame = None):
        """
        Save final dataset as CSV
        """
        print(f"\n💾 Saving final results to {output_path}...")
        
        dataset_to_save = final_dataset if final_dataset is not None else self.filtered_dataset
        
        if dataset_to_save is None:
            print("❌ No dataset to save!")
            return
        
        try:
            # Save as CSV (geometry will be saved as WKT if present)
            if 'geometry' in dataset_to_save.columns:
                # Convert to regular DataFrame for CSV saving
                df_to_save = pd.DataFrame(dataset_to_save)
                df_to_save['geometry'] = dataset_to_save.geometry.to_wkt()
            else:
                df_to_save = dataset_to_save
                
            df_to_save.to_csv(output_path, index=False)
            print(f"✅ Dataset saved successfully: {output_path}")
            print(f"   Rows: {len(df_to_save)}, Columns: {len(df_to_save.columns)}")
            
        except Exception as e:
            print(f"❌ Error saving dataset: {e}")
    
    def save_analysis_summary(self, output_dir: str):
        """
        Save comprehensive analysis summary
        """
        print(f"\n📋 Saving analysis summary...")
        
        summary_file = os.path.join(output_dir, 'analysis_summary.txt')
        
        try:
            with open(summary_file, 'w') as f:
                f.write("ENHANCED DELTA-X ANALYSIS SUMMARY\n")
                f.write("=" * 50 + "\n\n")
                
                # Dataset info
                f.write("DATASET INFORMATION:\n")
                f.write(f"Total segments: {len(self.labeled_dataset)}\n")
                if self.filtered_dataset is not None:
                    f.write(f"Final features: {len(self.filtered_dataset.columns) - 3}\n")
                f.write("\n")
                
                # Date-wise analysis results
                f.write("DATE-WISE ANALYSIS RESULTS:\n")
                for category, bands in self.date_wise_deltax.items():
                    f.write(f"\n{category}:\n")
                    for band_name, band_info in bands.items():
                        selected_dates = band_info.get('selected_dates', [])
                        f.write(f"  {band_name}: {len(selected_dates)} dates selected\n")
                f.write("\n")
                
                # Correlation analysis
                f.write("CORRELATION ANALYSIS:\n")
                for category, pairs in self.high_corr_pairs.items():
                    f.write(f"  {category}: {len(pairs)} high correlation pairs\n")
                f.write("\n")
                
                # PLS features
                f.write("PLS FEATURE ENGINEERING:\n")
                f.write(f"Total PLS features created: {len(self.pls_features)}\n")
                
                # Count PLS features by category
                pls_by_category = {}
                for pls_name in self.pls_features.keys():
                    category = pls_name.split('_')[1]  # Extract category from PLS_category_number
                    pls_by_category[category] = pls_by_category.get(category, 0) + 1
                
                for category, count in pls_by_category.items():
                    f.write(f"  {category}: {count} PLS features\n")
                f.write("\n")
                
                # Model files
                f.write("SAVED MODELS:\n")
                f.write(f"PLS models saved: {len(self.pls_models)}\n")
                
            print(f"✅ Analysis summary saved: {summary_file}")
            
        except Exception as e:
            print(f"❌ Error saving analysis summary: {e}")

# Main runner function
def run_enhanced_deltaX_analysis(labeled_dataset, organized_features, compactness_scores,
                               min_retention_rate: float = 0.7,
                               correlation_threshold: float = 0.95,
                               class_column: str = 'layer',
                               min_dates: int = 4,
                               max_dates: int = 10,
                               save_plots: bool = True,
                               output_dir: str = None,
                               output_csv_path: str = None):
    """
    Run complete enhanced Delta-X analysis pipeline with date-wise selection and PLSR model saving
    """
    print("🎯 Starting Enhanced Delta-X Analysis Pipeline with Date-wise Selection...")
    
    # Create output directory
    if output_dir:
        os.makedirs(output_dir, exist_ok=True)
    
    # Initialize analyzer
    analyzer = EnhancedDeltaXMagnitudeAnalyzer(labeled_dataset, organized_features, compactness_scores)
    
    try:
        # Step 1: Calculate Delta-X magnitudes by date and select best dates
        print("\n📊 Step 1: Calculating date-wise Delta-X magnitudes...")
        category_date_magnitudes = analyzer.calculate_deltaX_magnitudes_by_date(
            class_column=class_column,
            min_dates=min_dates,
            max_dates=max_dates,
            save_plots=save_plots,
            output_dir=output_dir
        )
        
        if not category_date_magnitudes:
            print("❌ No date-wise magnitudes calculated!")
            return None
        
        # Step 2: Create dataset with selected date-wise features
        print("\n🔄 Step 2: Creating filtered dataset...")
        filtered_dataset = analyzer.create_selected_features_dataset()
        
        if filtered_dataset is None:
            print("❌ Failed to create filtered dataset!")
            return None
        
        # Step 3: Plot correlations by category
        print("\n📊 Step 3: Calculating correlations...")
        correlation_results = analyzer.plot_correlation_by_category(
            save_plots=save_plots,
            output_dir=output_dir
        )
        
        # Step 4: Find high correlation pairs
        print("\n🔍 Step 4: Finding high correlation pairs...")
        high_corr_pairs = analyzer.find_high_correlation_pairs(threshold=correlation_threshold)
        
        # Step 5: Apply PLS feature engineering and save models
        print("\n🔬 Step 5: Applying PLS feature engineering...")
        pls_features = analyzer.apply_pls_feature_engineering(
            target_column=class_column,
            save_plots=save_plots,
            output_dir=output_dir,
            save_models=True
        )
        
        # Step 6: Create final dataset
        print("\n🔄 Step 6: Creating final dataset...")
        final_dataset = analyzer.create_final_dataset()
        
        # Step 7: Save results
        if output_csv_path and final_dataset is not None:
            print("\n💾 Step 7: Saving results...")
            analyzer.save_final_results(output_csv_path, final_dataset)
        
        # Step 8: Save analysis summary
        if output_dir:
            print("\n📋 Step 8: Saving analysis summary...")
            analyzer.save_analysis_summary(output_dir)
        
        print(f"\n🎉 ENHANCED DELTA-X ANALYSIS COMPLETE!")
        print(f"📊 Summary:")
        print(f"   Original features: {len(labeled_dataset.columns) - 3}")
        print(f"   Selected features: {len(filtered_dataset.columns) - 3 if filtered_dataset is not None else 0}")
        print(f"   PLS features: {len(pls_features)}")
        print(f"   Final features: {len(final_dataset.columns) - 3 if final_dataset is not None else 0}")
        
        return analyzer
        
    except Exception as e:
        print(f"❌ Error in analysis pipeline: {e}")
        import traceback
        traceback.print_exc()
        return None

# Example usage
if __name__ == "__main__":
    # Define paths for output
    output_base = r"F:\_____My_Thesies____\_ImpFiles\3. Feature Selection\3.FE_Final"
    output_dir = os.path.join(output_base, "enhanced_deltaX_analysis")
    output_csv_path = os.path.join(output_base, "final_dataset_enhanced.csv")
    
    # Ensure we have the analyzer object from previous step
    if 'analyzer' in locals() or 'analyzer' in globals():
        print("✅ Using existing analyzer object...")
        
        # Run enhanced Delta-X analysis with date-wise selection
        enhanced_analyzer = run_enhanced_deltaX_analysis(
            labeled_dataset=analyzer.labeled_dataset,  # Your labeled dataset
            organized_features=analyzer.organized_features,  # Your organized features
            compactness_scores=analyzer.compactness_scores,  # Your compactness scores
            min_retention_rate=0.7,  # Ensure at least 70% retention per category
            correlation_threshold=0.95,  # High correlation threshold
            class_column='layer',
            min_dates=4,  # Minimum dates to select per band
            max_dates=10,  # Maximum dates to select per band
            save_plots=True,
            output_dir=output_dir,
            output_csv_path=output_csv_path
        )
        
        if enhanced_analyzer:
            print("\n🎉 Enhanced Delta-X analysis completed successfully!")
            print(f"Results saved to: {output_dir}")
        else:
            print("❌ Enhanced Delta-X analysis failed!")
            
    else:
        print("❌ Error: 'analyzer' object not found!")
        print("Please run the previous feature engineering analysis first to create the 'analyzer' object.")
        print("\nTo run the analysis, you need:")
        print("1. analyzer.labeled_dataset")
        print("2. analyzer.organized_features") 
        print("3. analyzer.compactness_scores")
# Out:
# ✅ Using existing analyzer object...
# 🎯 Starting Enhanced Delta-X Analysis Pipeline with Date-wise Selection...
#
# 📊 Step 1: Calculating date-wise Delta-X magnitudes...
# 📊 Calculating Delta-X magnitudes by date...
# 🏷️ Categorizing features...
# 📊 FEATURE CATEGORIZATION RESULTS:
#   Spectral: 10 bands, 600 features
#     - B2: 60 features
#     - B3: 60 features
#     - B4: 60 features
#     ... and 7 more
#   SAR: 2 bands, 122 features
#     - VH: 61 features
#     - VV: 61 features
#   GLCM: 16 bands, 995 features
#     - Mean_mean: 60 features
#     - Mean_var: 60 features
#     - Variance_mean: 60 features
#     ... and 13 more
#   VIs: 18 bands, 1062 features
#     - NDVI: 59 features
#     - EVI: 59 features
#     - SAVI: 59 features
#     ... and 15 more
# 📋 Classes found: ['Alfalfa-polygon', 'Bare-polygon', 'Clover-polygon', 'Corn-polygon', 'Degreed_Wetland_Poly-polygon', 'Phragmites-polygon', 'Rice-polygon', 'Sugar_Beet-polygon', 'Tamarixs', 'Urban-polygon', 'Wheat-polygon']
#
# 📈 Processing Spectral category...
#   🔍 Analyzing band: B2 (60 features)
#     ✅ Selected 10/59 dates for B2
#   🔍 Analyzing band: B3 (60 features)
#     ✅ Selected 10/59 dates for B3
#   🔍 Analyzing band: B4 (60 features)
#     ✅ Selected 10/59 dates for B4
#   🔍 Analyzing band: B5 (60 features)
#     ✅ Selected 10/59 dates for B5
#   🔍 Analyzing band: B6 (60 features)
#     ✅ Selected 10/59 dates for B6
#   🔍 Analyzing band: B7 (60 features)
#     ✅ Selected 10/59 dates for B7
#   🔍 Analyzing band: B8 (60 features)
#     ✅ Selected 10/59 dates for B8
#   🔍 Analyzing band: B8A (60 features)
#     ✅ Selected 10/59 dates for B8A
#   🔍 Analyzing band: B11 (60 features)
#     ✅ Selected 10/59 dates for B11
#   🔍 Analyzing band: B12 (60 features)
#     ✅ Selected 10/59 dates for B12
#
# 📈 Processing SAR category...
#   🔍 Analyzing band: VH (61 features)
#     ✅ Selected 10/61 dates for VH
#   🔍 Analyzing band: VV (61 features)
#     ✅ Selected 10/61 dates for VV
#
# 📈 Processing GLCM category...
#   🔍 Analyzing band: Mean_mean (60 features)
#     ✅ Selected 10/60 dates for Mean_mean
#   🔍 Analyzing band: Mean_var (60 features)
#     ✅ Selected 10/60 dates for Mean_var
#   🔍 Analyzing band: Variance_mean (60 features)
#     ✅ Selected 10/60 dates for Variance_mean
#   🔍 Analyzing band: Variance_var (60 features)
#     ✅ Selected 10/60 dates for Variance_var
#   🔍 Analyzing band: Homogeneity_mean (72 features)
#     ✅ Selected 10/72 dates for Homogeneity_mean
#   🔍 Analyzing band: Homogeneity_var (60 features)
#     ✅ Selected 10/60 dates for Homogeneity_var
#   🔍 Analyzing band: Contrast_mean (60 features)
#     ✅ Selected 10/60 dates for Contrast_mean
#   🔍 Analyzing band: Contrast_var (60 features)
#     ✅ Selected 10/60 dates for Contrast_var
#   🔍 Analyzing band: Dissimilarity_mean (60 features)
#     ✅ Selected 10/60 dates for Dissimilarity_mean
#   🔍 Analyzing band: Dissimilarity_var (60 features)
#     ✅ Selected 10/60 dates for Dissimilarity_var
#   🔍 Analyzing band: Entropy_mean (60 features)
#     ✅ Selected 10/60 dates for Entropy_mean
#   🔍 Analyzing band: Entropy_var (59 features)
#     ✅ Selected 10/59 dates for Entropy_var
#   🔍 Analyzing band: Second_Moment_mean (72 features)
#     ✅ Selected 10/72 dates for Second_Moment_mean
#   🔍 Analyzing band: Second_Moment_var (60 features)
#     ✅ Selected 10/60 dates for Second_Moment_var
#   🔍 Analyzing band: Correlation_mean (72 features)
#     ✅ Selected 10/72 dates for Correlation_mean
#   🔍 Analyzing band: Correlation_var (60 features)
#     ✅ Selected 10/60 dates for Correlation_var
#
# 📈 Processing VIs category...
#   🔍 Analyzing band: NDVI (59 features)
#     ✅ Selected 10/59 dates for NDVI
#   🔍 Analyzing band: EVI (59 features)
#     ✅ Selected 10/59 dates for EVI
#   🔍 Analyzing band: SAVI (59 features)
#     ✅ Selected 10/59 dates for SAVI
#   🔍 Analyzing band: TDVI (59 features)
#     ✅ Selected 10/59 dates for TDVI
#   🔍 Analyzing band: NDWI (59 features)
#     ✅ Selected 10/59 dates for NDWI
#   🔍 Analyzing band: 2BDA (59 features)
#     ✅ Selected 10/59 dates for 2BDA
#   🔍 Analyzing band: NDCI (59 features)
#     ✅ Selected 10/59 dates for NDCI
#   🔍 Analyzing band: ENDVI (59 features)
#     ✅ Selected 10/59 dates for ENDVI
#   🔍 Analyzing band: GNDVI (59 features)
#     ✅ Selected 10/59 dates for GNDVI
#   🔍 Analyzing band: NDRE (59 features)
#     ✅ Selected 10/59 dates for NDRE
#   🔍 Analyzing band: GRVI (59 features)
#     ✅ Selected 10/59 dates for GRVI
#   🔍 Analyzing band: MSAVI (59 features)
#     ✅ Selected 10/59 dates for MSAVI
#   🔍 Analyzing band: LSWI (59 features)
#     ✅ Selected 10/59 dates for LSWI
#   🔍 Analyzing band: NDMI (59 features)
#     ✅ Selected 10/59 dates for NDMI
#   🔍 Analyzing band: MNDWI (59 features)
#     ✅ Selected 10/59 dates for MNDWI
#   🔍 Analyzing band: MBI (59 features)
#     ✅ Selected 10/59 dates for MBI
#   🔍 Analyzing band: EMBI (59 features)
#     ✅ Selected 10/59 dates for EMBI
#   🔍 Analyzing band: MCARI2 (59 features)
#     ✅ Selected 10/59 dates for MCARI2
#
# 🔄 Step 2: Creating filtered dataset...
#
# 🔄 Creating dataset with selected date-wise features...
# ✅ Created filtered dataset with 460 selected features
#    Original features: 2780
#    Selected features: 460
#    Retention rate: 16.5%
#
# 📊 Step 3: Calculating correlations...
# 📊 Plotting Pearson correlation matrices by category...
# ✅ Spectral: Correlation matrix calculated (100 features)
# ✅ SAR: Correlation matrix calculated (20 features)
# ✅ GLCM: Correlation matrix calculated (160 features)
# ✅ VIs: Correlation matrix calculated (180 features)
#
# 🔍 Step 4: Finding high correlation pairs...
#
# 🔍 Finding high correlation pairs (threshold: 0.95)...
#   Spectral: 204 high correlation pairs found
#   SAR: 9 high correlation pairs found
#   GLCM: 29 high correlation pairs found
#   VIs: 579 high correlation pairs found
#
# 🔬 Step 5: Applying PLS feature engineering...
#
# 🔬 Applying PLS feature engineering...
#
# 🔬 Processing Spectral category (204 pairs)...
#   ✅ PLS_Spectral_1: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_Spectral_2: PLS feature created (r=0.982, n=6309)
#   ✅ PLS_Spectral_3: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_Spectral_4: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_Spectral_5: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_Spectral_6: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_Spectral_7: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_Spectral_8: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_Spectral_9: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_Spectral_10: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_Spectral_11: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_Spectral_12: PLS feature created (r=0.990, n=6309)
#   ✅ PLS_Spectral_13: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_Spectral_14: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_Spectral_15: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_Spectral_16: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_Spectral_17: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_Spectral_18: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_Spectral_19: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_Spectral_20: PLS feature created (r=0.970, n=6309)
#   ✅ PLS_Spectral_21: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_Spectral_22: PLS feature created (r=0.999, n=6309)
#   ✅ PLS_Spectral_23: PLS feature created (r=0.996, n=6309)
#   ✅ PLS_Spectral_24: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_Spectral_25: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_Spectral_26: PLS feature created (r=0.968, n=6309)
#   ✅ PLS_Spectral_27: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_Spectral_28: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_Spectral_29: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_Spectral_30: PLS feature created (r=0.960, n=6309)
#   ✅ PLS_Spectral_31: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_Spectral_32: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_Spectral_33: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_Spectral_34: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_Spectral_35: PLS feature created (r=0.995, n=6309)
#   ✅ PLS_Spectral_36: PLS feature created (r=0.995, n=6309)
#   ✅ PLS_Spectral_37: PLS feature created (r=0.957, n=6309)
#   ✅ PLS_Spectral_38: PLS feature created (r=0.990, n=6309)
#   ✅ PLS_Spectral_39: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_Spectral_40: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_Spectral_41: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_Spectral_42: PLS feature created (r=0.986, n=6309)
#   ✅ PLS_Spectral_43: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_Spectral_44: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_Spectral_45: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_Spectral_46: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_Spectral_47: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_Spectral_48: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_Spectral_49: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_Spectral_50: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_Spectral_51: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_Spectral_52: PLS feature created (r=0.987, n=6309)
#   ✅ PLS_Spectral_53: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_Spectral_54: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_Spectral_55: PLS feature created (r=0.973, n=6309)
#   ✅ PLS_Spectral_56: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_Spectral_57: PLS feature created (r=0.968, n=6309)
#   ✅ PLS_Spectral_58: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_Spectral_59: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_Spectral_60: PLS feature created (r=0.956, n=6309)
#   ✅ PLS_Spectral_61: PLS feature created (r=0.960, n=6309)
#   ✅ PLS_Spectral_62: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_Spectral_63: PLS feature created (r=0.956, n=6309)
#   ✅ PLS_Spectral_64: PLS feature created (r=0.970, n=6309)
#   ✅ PLS_Spectral_65: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_Spectral_66: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_Spectral_67: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_Spectral_68: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_Spectral_69: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_Spectral_70: PLS feature created (r=0.992, n=6309)
#   ✅ PLS_Spectral_71: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_Spectral_72: PLS feature created (r=0.991, n=6309)
#   ✅ PLS_Spectral_73: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_Spectral_74: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_Spectral_75: PLS feature created (r=0.988, n=6309)
#   ✅ PLS_Spectral_76: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_Spectral_77: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_Spectral_78: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_Spectral_79: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_Spectral_80: PLS feature created (r=0.988, n=6309)
#   ✅ PLS_Spectral_81: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_Spectral_82: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_Spectral_83: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_Spectral_84: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_Spectral_85: PLS feature created (r=0.989, n=6309)
#   ✅ PLS_Spectral_86: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_Spectral_87: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_Spectral_88: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_Spectral_89: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_Spectral_90: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_Spectral_91: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_Spectral_92: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_Spectral_93: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_Spectral_94: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_Spectral_95: PLS feature created (r=0.992, n=6309)
#   ✅ PLS_Spectral_96: PLS feature created (r=0.999, n=6309)
#   ✅ PLS_Spectral_97: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_Spectral_98: PLS feature created (r=0.956, n=6309)
#   ✅ PLS_Spectral_99: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_Spectral_100: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_Spectral_101: PLS feature created (r=0.990, n=6309)
#   ✅ PLS_Spectral_102: PLS feature created (r=0.968, n=6309)
#   ✅ PLS_Spectral_103: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_Spectral_104: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_Spectral_105: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_Spectral_106: PLS feature created (r=0.960, n=6309)
#   ✅ PLS_Spectral_107: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_Spectral_108: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_Spectral_109: PLS feature created (r=0.954, n=6309)
#   ✅ PLS_Spectral_110: PLS feature created (r=0.987, n=6309)
#   ✅ PLS_Spectral_111: PLS feature created (r=0.986, n=6309)
#   ✅ PLS_Spectral_112: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_Spectral_113: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_Spectral_114: PLS feature created (r=0.957, n=6309)
#   ✅ PLS_Spectral_115: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_Spectral_116: PLS feature created (r=0.954, n=6309)
#   ✅ PLS_Spectral_117: PLS feature created (r=0.973, n=6309)
#   ✅ PLS_Spectral_118: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_Spectral_119: PLS feature created (r=0.973, n=6309)
#   ✅ PLS_Spectral_120: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_Spectral_121: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_Spectral_122: PLS feature created (r=0.990, n=6309)
#   ✅ PLS_Spectral_123: PLS feature created (r=0.973, n=6309)
#   ✅ PLS_Spectral_124: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_Spectral_125: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_Spectral_126: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_Spectral_127: PLS feature created (r=0.954, n=6309)
#   ✅ PLS_Spectral_128: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_Spectral_129: PLS feature created (r=0.986, n=6309)
#   ✅ PLS_Spectral_130: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_Spectral_131: PLS feature created (r=0.954, n=6309)
#   ✅ PLS_Spectral_132: PLS feature created (r=0.954, n=6309)
#   ✅ PLS_Spectral_133: PLS feature created (r=0.956, n=6309)
#   ✅ PLS_Spectral_134: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_Spectral_135: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_Spectral_136: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_Spectral_137: PLS feature created (r=0.990, n=6309)
#   ✅ PLS_Spectral_138: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_Spectral_139: PLS feature created (r=0.990, n=6309)
#   ✅ PLS_Spectral_140: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_Spectral_141: PLS feature created (r=0.991, n=6309)
#   ✅ PLS_Spectral_142: PLS feature created (r=0.957, n=6309)
#   ✅ PLS_Spectral_143: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_Spectral_144: PLS feature created (r=0.954, n=6309)
#   ✅ PLS_Spectral_145: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_Spectral_146: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_Spectral_147: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_Spectral_148: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_Spectral_149: PLS feature created (r=0.990, n=6309)
#   ✅ PLS_Spectral_150: PLS feature created (r=0.957, n=6309)
#   ✅ PLS_Spectral_151: PLS feature created (r=0.992, n=6309)
#   ✅ PLS_Spectral_152: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_Spectral_153: PLS feature created (r=0.956, n=6309)
#   ✅ PLS_Spectral_154: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_Spectral_155: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_Spectral_156: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_Spectral_157: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_Spectral_158: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_Spectral_159: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_Spectral_160: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_Spectral_161: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_Spectral_162: PLS feature created (r=0.957, n=6309)
#   ✅ PLS_Spectral_163: PLS feature created (r=0.986, n=6309)
#   ✅ PLS_Spectral_164: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_Spectral_165: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_Spectral_166: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_Spectral_167: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_Spectral_168: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_Spectral_169: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_Spectral_170: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_Spectral_171: PLS feature created (r=0.970, n=6309)
#   ✅ PLS_Spectral_172: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_Spectral_173: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_Spectral_174: PLS feature created (r=0.984, n=6309)
#   ✅ PLS_Spectral_175: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_Spectral_176: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_Spectral_177: PLS feature created (r=0.968, n=6309)
#   ✅ PLS_Spectral_178: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_Spectral_179: PLS feature created (r=0.984, n=6309)
#   ✅ PLS_Spectral_180: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_Spectral_181: PLS feature created (r=0.984, n=6309)
#   ✅ PLS_Spectral_182: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_Spectral_183: PLS feature created (r=0.991, n=6309)
#   ✅ PLS_Spectral_184: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_Spectral_185: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_Spectral_186: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_Spectral_187: PLS feature created (r=0.956, n=6309)
#   ✅ PLS_Spectral_188: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_Spectral_189: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_Spectral_190: PLS feature created (r=0.954, n=6309)
#   ✅ PLS_Spectral_191: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_Spectral_192: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_Spectral_193: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_Spectral_194: PLS feature created (r=0.973, n=6309)
#   ✅ PLS_Spectral_195: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_Spectral_196: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_Spectral_197: PLS feature created (r=0.993, n=6309)
#   ✅ PLS_Spectral_198: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_Spectral_199: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_Spectral_200: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_Spectral_201: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_Spectral_202: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_Spectral_203: PLS feature created (r=0.957, n=6309)
#   ✅ PLS_Spectral_204: PLS feature created (r=0.960, n=6309)
#
# 🔬 Processing SAR category (9 pairs)...
#   ✅ PLS_SAR_1: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_SAR_2: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_SAR_3: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_SAR_4: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_SAR_5: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_SAR_6: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_SAR_7: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_SAR_8: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_SAR_9: PLS feature created (r=1.000, n=6309)
#
# 🔬 Processing GLCM category (29 pairs)...
#   ✅ PLS_GLCM_1: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_GLCM_2: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_GLCM_3: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_GLCM_4: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_GLCM_5: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_GLCM_6: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_GLCM_7: PLS feature created (r=0.960, n=6309)
#   ✅ PLS_GLCM_8: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_GLCM_9: PLS feature created (r=0.991, n=6309)
#   ✅ PLS_GLCM_10: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_GLCM_11: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_GLCM_12: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_GLCM_13: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_GLCM_14: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_GLCM_15: PLS feature created (r=0.995, n=6309)
#   ✅ PLS_GLCM_16: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_GLCM_17: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_GLCM_18: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_GLCM_19: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_GLCM_20: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_GLCM_21: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_GLCM_22: PLS feature created (r=0.960, n=6309)
#   ✅ PLS_GLCM_23: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_GLCM_24: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_GLCM_25: PLS feature created (r=0.973, n=6309)
#   ✅ PLS_GLCM_26: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_GLCM_27: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_GLCM_28: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_GLCM_29: PLS feature created (r=0.951, n=6309)
#
# 🔬 Processing VIs category (579 pairs)...
#   ✅ PLS_VIs_1: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_VIs_2: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_VIs_3: PLS feature created (r=0.980, n=6309)
#   ✅ PLS_VIs_4: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_VIs_5: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_6: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_VIs_7: PLS feature created (r=0.995, n=6309)
#   ✅ PLS_VIs_8: PLS feature created (r=0.994, n=6309)
#   ✅ PLS_VIs_9: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_10: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_VIs_11: PLS feature created (r=-0.952, n=6309)
#   ✅ PLS_VIs_12: PLS feature created (r=0.991, n=6309)
#   ✅ PLS_VIs_13: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_VIs_14: PLS feature created (r=0.989, n=6309)
#   ✅ PLS_VIs_15: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_VIs_16: PLS feature created (r=0.980, n=6309)
#   ✅ PLS_VIs_17: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_VIs_18: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_VIs_19: PLS feature created (r=0.987, n=6309)
#   ✅ PLS_VIs_20: PLS feature created (r=0.990, n=6309)
#   ✅ PLS_VIs_21: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_VIs_22: PLS feature created (r=0.980, n=6309)
#   ✅ PLS_VIs_23: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_24: PLS feature created (r=0.973, n=6309)
#   ✅ PLS_VIs_25: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_VIs_26: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_VIs_27: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_VIs_28: PLS feature created (r=0.987, n=6309)
#   ✅ PLS_VIs_29: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_30: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_31: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_VIs_32: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_VIs_33: PLS feature created (r=-0.960, n=6309)
#   ✅ PLS_VIs_34: PLS feature created (r=-0.960, n=6309)
#   ✅ PLS_VIs_35: PLS feature created (r=0.957, n=6309)
#   ✅ PLS_VIs_36: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_37: PLS feature created (r=0.995, n=6309)
#   ✅ PLS_VIs_38: PLS feature created (r=0.993, n=6309)
#   ✅ PLS_VIs_39: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_40: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_41: PLS feature created (r=0.996, n=6309)
#   ✅ PLS_VIs_42: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_43: PLS feature created (r=-1.000, n=6309)
#   ✅ PLS_VIs_44: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_45: PLS feature created (r=-0.969, n=6309)
#   ✅ PLS_VIs_46: PLS feature created (r=0.956, n=6309)
#   ✅ PLS_VIs_47: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_48: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_49: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_VIs_50: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_VIs_51: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_52: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_53: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_VIs_54: PLS feature created (r=0.984, n=6309)
#   ✅ PLS_VIs_55: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_56: PLS feature created (r=0.982, n=6309)
#   ✅ PLS_VIs_57: PLS feature created (r=0.984, n=6309)
#   ✅ PLS_VIs_58: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_59: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_60: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_VIs_61: PLS feature created (r=-0.963, n=6309)
#   ✅ PLS_VIs_62: PLS feature created (r=-0.958, n=6309)
#   ✅ PLS_VIs_63: PLS feature created (r=-0.970, n=6309)
#   ✅ PLS_VIs_64: PLS feature created (r=-0.981, n=6309)
#   ✅ PLS_VIs_65: PLS feature created (r=-0.985, n=6309)
#   ✅ PLS_VIs_66: PLS feature created (r=-0.962, n=6309)
#   ✅ PLS_VIs_67: PLS feature created (r=-0.959, n=6309)
#   ✅ PLS_VIs_68: PLS feature created (r=-0.988, n=6309)
#   ✅ PLS_VIs_69: PLS feature created (r=-0.961, n=6309)
#   ✅ PLS_VIs_70: PLS feature created (r=-1.000, n=6309)
#   ✅ PLS_VIs_71: PLS feature created (r=-0.970, n=6309)
#   ✅ PLS_VIs_72: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_73: PLS feature created (r=-0.975, n=6309)
#   ✅ PLS_VIs_74: PLS feature created (r=-0.968, n=6309)
#   ✅ PLS_VIs_75: PLS feature created (r=-0.972, n=6309)
#   ✅ PLS_VIs_76: PLS feature created (r=-0.955, n=6309)
#   ✅ PLS_VIs_77: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_78: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_79: PLS feature created (r=-0.970, n=6309)
#   ✅ PLS_VIs_80: PLS feature created (r=-0.955, n=6309)
#   ✅ PLS_VIs_81: PLS feature created (r=-0.970, n=6309)
#   ✅ PLS_VIs_82: PLS feature created (r=-0.955, n=6309)
#   ✅ PLS_VIs_83: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_84: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_VIs_85: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_86: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_87: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_VIs_88: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_VIs_89: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_90: PLS feature created (r=-0.966, n=6309)
#   ✅ PLS_VIs_91: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_VIs_92: PLS feature created (r=0.995, n=6309)
#   ✅ PLS_VIs_93: PLS feature created (r=0.986, n=6309)
#   ✅ PLS_VIs_94: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_95: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_VIs_96: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_97: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_98: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_VIs_99: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_VIs_100: PLS feature created (r=0.987, n=6309)
#   ✅ PLS_VIs_101: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_VIs_102: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_VIs_103: PLS feature created (r=0.970, n=6309)
#   ✅ PLS_VIs_104: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_105: PLS feature created (r=0.980, n=6309)
#   ✅ PLS_VIs_106: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_VIs_107: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_108: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_109: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_VIs_110: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_VIs_111: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_112: PLS feature created (r=-0.950, n=6309)
#   ✅ PLS_VIs_113: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_VIs_114: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_VIs_115: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_VIs_116: PLS feature created (r=0.957, n=6309)
#   ✅ PLS_VIs_117: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_VIs_118: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_VIs_119: PLS feature created (r=0.973, n=6309)
#   ✅ PLS_VIs_120: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_121: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_VIs_122: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_123: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_VIs_124: PLS feature created (r=-0.975, n=6309)
#   ✅ PLS_VIs_125: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_VIs_126: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_VIs_127: PLS feature created (r=-0.964, n=6309)
#   ✅ PLS_VIs_128: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_VIs_129: PLS feature created (r=-0.961, n=6309)
#   ✅ PLS_VIs_130: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_131: PLS feature created (r=0.954, n=6309)
#   ✅ PLS_VIs_132: PLS feature created (r=0.986, n=6309)
#   ✅ PLS_VIs_133: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_VIs_134: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_135: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_VIs_136: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_137: PLS feature created (r=0.986, n=6309)
#   ✅ PLS_VIs_138: PLS feature created (r=-1.000, n=6309)
#   ✅ PLS_VIs_139: PLS feature created (r=0.984, n=6309)
#   ✅ PLS_VIs_140: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_141: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_VIs_142: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_143: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_VIs_144: PLS feature created (r=-0.961, n=6309)
#   ✅ PLS_VIs_145: PLS feature created (r=-0.961, n=6309)
#   ✅ PLS_VIs_146: PLS feature created (r=-0.967, n=6309)
#   ✅ PLS_VIs_147: PLS feature created (r=-0.989, n=6309)
#   ✅ PLS_VIs_148: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_VIs_149: PLS feature created (r=0.989, n=6309)
#   ✅ PLS_VIs_150: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_VIs_151: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_152: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_153: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_154: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_VIs_155: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_VIs_156: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_157: PLS feature created (r=-0.958, n=6309)
#   ✅ PLS_VIs_158: PLS feature created (r=0.990, n=6309)
#   ✅ PLS_VIs_159: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_160: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_VIs_161: PLS feature created (r=-0.962, n=6309)
#   ✅ PLS_VIs_162: PLS feature created (r=-0.979, n=6309)
#   ✅ PLS_VIs_163: PLS feature created (r=-1.000, n=6309)
#   ✅ PLS_VIs_164: PLS feature created (r=-0.987, n=6309)
#   ✅ PLS_VIs_165: PLS feature created (r=-0.975, n=6309)
#   ✅ PLS_VIs_166: PLS feature created (r=-0.951, n=6309)
#   ✅ PLS_VIs_167: PLS feature created (r=-0.978, n=6309)
#   ✅ PLS_VIs_168: PLS feature created (r=-0.990, n=6309)
#   ✅ PLS_VIs_169: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_170: PLS feature created (r=-0.962, n=6309)
#   ✅ PLS_VIs_171: PLS feature created (r=0.973, n=6309)
#   ✅ PLS_VIs_172: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_VIs_173: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_VIs_174: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_VIs_175: PLS feature created (r=0.956, n=6309)
#   ✅ PLS_VIs_176: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_VIs_177: PLS feature created (r=0.960, n=6309)
#   ✅ PLS_VIs_178: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_179: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_180: PLS feature created (r=0.956, n=6309)
#   ✅ PLS_VIs_181: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_182: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_VIs_183: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_184: PLS feature created (r=0.999, n=6309)
#   ✅ PLS_VIs_185: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_VIs_186: PLS feature created (r=0.990, n=6309)
#   ✅ PLS_VIs_187: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_188: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_VIs_189: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_190: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_VIs_191: PLS feature created (r=0.989, n=6309)
#   ✅ PLS_VIs_192: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_VIs_193: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_VIs_194: PLS feature created (r=0.970, n=6309)
#   ✅ PLS_VIs_195: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_VIs_196: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_VIs_197: PLS feature created (r=-0.966, n=6309)
#   ✅ PLS_VIs_198: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_199: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_200: PLS feature created (r=0.991, n=6309)
#   ✅ PLS_VIs_201: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_VIs_202: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_VIs_203: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_VIs_204: PLS feature created (r=0.989, n=6309)
#   ✅ PLS_VIs_205: PLS feature created (r=0.994, n=6309)
#   ✅ PLS_VIs_206: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_VIs_207: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_VIs_208: PLS feature created (r=-0.964, n=6309)
#   ✅ PLS_VIs_209: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_VIs_210: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_211: PLS feature created (r=-0.967, n=6309)
#   ✅ PLS_VIs_212: PLS feature created (r=0.988, n=6309)
#   ✅ PLS_VIs_213: PLS feature created (r=0.957, n=6309)
#   ✅ PLS_VIs_214: PLS feature created (r=0.954, n=6309)
#   ✅ PLS_VIs_215: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_VIs_216: PLS feature created (r=0.984, n=6309)
#   ✅ PLS_VIs_217: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_VIs_218: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_VIs_219: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_VIs_220: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_VIs_221: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_222: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_223: PLS feature created (r=0.986, n=6309)
#   ✅ PLS_VIs_224: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_VIs_225: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_VIs_226: PLS feature created (r=0.960, n=6309)
#   ✅ PLS_VIs_227: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_228: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_229: PLS feature created (r=0.992, n=6309)
#   ✅ PLS_VIs_230: PLS feature created (r=0.960, n=6309)
#   ✅ PLS_VIs_231: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_VIs_232: PLS feature created (r=-0.972, n=6309)
#   ✅ PLS_VIs_233: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_VIs_234: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_VIs_235: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_VIs_236: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_VIs_237: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_VIs_238: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_VIs_239: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_240: PLS feature created (r=-0.974, n=6309)
#   ✅ PLS_VIs_241: PLS feature created (r=-0.971, n=6309)
#   ✅ PLS_VIs_242: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_243: PLS feature created (r=-0.950, n=6309)
#   ✅ PLS_VIs_244: PLS feature created (r=-0.985, n=6309)
#   ✅ PLS_VIs_245: PLS feature created (r=-0.981, n=6309)
#   ✅ PLS_VIs_246: PLS feature created (r=-1.000, n=6309)
#   ✅ PLS_VIs_247: PLS feature created (r=-0.964, n=6309)
#   ✅ PLS_VIs_248: PLS feature created (r=-1.000, n=6309)
#   ✅ PLS_VIs_249: PLS feature created (r=-0.980, n=6309)
#   ✅ PLS_VIs_250: PLS feature created (r=-0.955, n=6309)
#   ✅ PLS_VIs_251: PLS feature created (r=-0.960, n=6309)
#   ✅ PLS_VIs_252: PLS feature created (r=-0.968, n=6309)
#   ✅ PLS_VIs_253: PLS feature created (r=-0.950, n=6309)
#   ✅ PLS_VIs_254: PLS feature created (r=-0.974, n=6309)
#   ✅ PLS_VIs_255: PLS feature created (r=0.968, n=6309)
#   ✅ PLS_VIs_256: PLS feature created (r=-0.961, n=6309)
#   ✅ PLS_VIs_257: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_VIs_258: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_259: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_VIs_260: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_VIs_261: PLS feature created (r=-0.958, n=6309)
#   ✅ PLS_VIs_262: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_VIs_263: PLS feature created (r=0.956, n=6309)
#   ✅ PLS_VIs_264: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_265: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_266: PLS feature created (r=0.995, n=6309)
#   ✅ PLS_VIs_267: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_268: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_VIs_269: PLS feature created (r=-0.958, n=6309)
#   ✅ PLS_VIs_270: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_VIs_271: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_272: PLS feature created (r=-0.960, n=6309)
#   ✅ PLS_VIs_273: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_274: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_275: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_VIs_276: PLS feature created (r=0.968, n=6309)
#   ✅ PLS_VIs_277: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_278: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_279: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_VIs_280: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_281: PLS feature created (r=0.987, n=6309)
#   ✅ PLS_VIs_282: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_283: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_VIs_284: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_285: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_286: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_VIs_287: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_VIs_288: PLS feature created (r=0.968, n=6309)
#   ✅ PLS_VIs_289: PLS feature created (r=-0.954, n=6309)
#   ✅ PLS_VIs_290: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_VIs_291: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_VIs_292: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_VIs_293: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_294: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_295: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_VIs_296: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_VIs_297: PLS feature created (r=0.960, n=6309)
#   ✅ PLS_VIs_298: PLS feature created (r=0.954, n=6309)
#   ✅ PLS_VIs_299: PLS feature created (r=-0.953, n=6309)
#   ✅ PLS_VIs_300: PLS feature created (r=-1.000, n=6309)
#   ✅ PLS_VIs_301: PLS feature created (r=-0.955, n=6309)
#   ✅ PLS_VIs_302: PLS feature created (r=-0.966, n=6309)
#   ✅ PLS_VIs_303: PLS feature created (r=-0.985, n=6309)
#   ✅ PLS_VIs_304: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_305: PLS feature created (r=0.980, n=6309)
#   ✅ PLS_VIs_306: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_VIs_307: PLS feature created (r=0.960, n=6309)
#   ✅ PLS_VIs_308: PLS feature created (r=0.968, n=6309)
#   ✅ PLS_VIs_309: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_VIs_310: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_311: PLS feature created (r=-0.968, n=6309)
#   ✅ PLS_VIs_312: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_VIs_313: PLS feature created (r=0.973, n=6309)
#   ✅ PLS_VIs_314: PLS feature created (r=0.984, n=6309)
#   ✅ PLS_VIs_315: PLS feature created (r=0.991, n=6309)
#   ✅ PLS_VIs_316: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_VIs_317: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_318: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_VIs_319: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_320: PLS feature created (r=0.970, n=6309)
#   ✅ PLS_VIs_321: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_VIs_322: PLS feature created (r=0.995, n=6309)
#   ✅ PLS_VIs_323: PLS feature created (r=0.968, n=6309)
#   ✅ PLS_VIs_324: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_325: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_326: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_VIs_327: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_VIs_328: PLS feature created (r=-0.986, n=6309)
#   ✅ PLS_VIs_329: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_330: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_331: PLS feature created (r=0.970, n=6309)
#   ✅ PLS_VIs_332: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_333: PLS feature created (r=-0.960, n=6309)
#   ✅ PLS_VIs_334: PLS feature created (r=-1.000, n=6309)
#   ✅ PLS_VIs_335: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_VIs_336: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_337: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_338: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_339: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_340: PLS feature created (r=0.970, n=6309)
#   ✅ PLS_VIs_341: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_VIs_342: PLS feature created (r=0.984, n=6309)
#   ✅ PLS_VIs_343: PLS feature created (r=-0.979, n=6309)
#   ✅ PLS_VIs_344: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_VIs_345: PLS feature created (r=0.999, n=6309)
#   ✅ PLS_VIs_346: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_347: PLS feature created (r=0.982, n=6309)
#   ✅ PLS_VIs_348: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_349: PLS feature created (r=0.980, n=6309)
#   ✅ PLS_VIs_350: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_VIs_351: PLS feature created (r=0.954, n=6309)
#   ✅ PLS_VIs_352: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_VIs_353: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_354: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_VIs_355: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_356: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_357: PLS feature created (r=0.988, n=6309)
#   ✅ PLS_VIs_358: PLS feature created (r=-0.978, n=6309)
#   ✅ PLS_VIs_359: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_VIs_360: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_361: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_VIs_362: PLS feature created (r=0.992, n=6309)
#   ✅ PLS_VIs_363: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_VIs_364: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_VIs_365: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_VIs_366: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_367: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_VIs_368: PLS feature created (r=0.960, n=6309)
#   ✅ PLS_VIs_369: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_370: PLS feature created (r=0.970, n=6309)
#   ✅ PLS_VIs_371: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_VIs_372: PLS feature created (r=0.987, n=6309)
#   ✅ PLS_VIs_373: PLS feature created (r=0.991, n=6309)
#   ✅ PLS_VIs_374: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_375: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_VIs_376: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_VIs_377: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_378: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_VIs_379: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_380: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_381: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_VIs_382: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_383: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_VIs_384: PLS feature created (r=-0.966, n=6309)
#   ✅ PLS_VIs_385: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_386: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_387: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_VIs_388: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_VIs_389: PLS feature created (r=-0.950, n=6309)
#   ✅ PLS_VIs_390: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_VIs_391: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_VIs_392: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_VIs_393: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_394: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_VIs_395: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_VIs_396: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_VIs_397: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_VIs_398: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_399: PLS feature created (r=-0.961, n=6309)
#   ✅ PLS_VIs_400: PLS feature created (r=-0.951, n=6309)
#   ✅ PLS_VIs_401: PLS feature created (r=-0.971, n=6309)
#   ✅ PLS_VIs_402: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_403: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_404: PLS feature created (r=0.991, n=6309)
#   ✅ PLS_VIs_405: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_VIs_406: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_VIs_407: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_VIs_408: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_409: PLS feature created (r=0.980, n=6309)
#   ✅ PLS_VIs_410: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_411: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_412: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_VIs_413: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_414: PLS feature created (r=0.984, n=6309)
#   ✅ PLS_VIs_415: PLS feature created (r=-0.961, n=6309)
#   ✅ PLS_VIs_416: PLS feature created (r=0.970, n=6309)
#   ✅ PLS_VIs_417: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_VIs_418: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_VIs_419: PLS feature created (r=-0.974, n=6309)
#   ✅ PLS_VIs_420: PLS feature created (r=-0.974, n=6309)
#   ✅ PLS_VIs_421: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_VIs_422: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_VIs_423: PLS feature created (r=-0.959, n=6309)
#   ✅ PLS_VIs_424: PLS feature created (r=0.988, n=6309)
#   ✅ PLS_VIs_425: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_VIs_426: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_427: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_VIs_428: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_VIs_429: PLS feature created (r=0.994, n=6309)
#   ✅ PLS_VIs_430: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_VIs_431: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_432: PLS feature created (r=0.986, n=6309)
#   ✅ PLS_VIs_433: PLS feature created (r=-0.961, n=6309)
#   ✅ PLS_VIs_434: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_VIs_435: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_VIs_436: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_VIs_437: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_438: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_439: PLS feature created (r=0.982, n=6309)
#   ✅ PLS_VIs_440: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_441: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_VIs_442: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_VIs_443: PLS feature created (r=-0.952, n=6309)
#   ✅ PLS_VIs_444: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_VIs_445: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_VIs_446: PLS feature created (r=0.996, n=6309)
#   ✅ PLS_VIs_447: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_448: PLS feature created (r=0.995, n=6309)
#   ✅ PLS_VIs_449: PLS feature created (r=0.996, n=6309)
#   ✅ PLS_VIs_450: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_VIs_451: PLS feature created (r=0.961, n=6309)
#   ✅ PLS_VIs_452: PLS feature created (r=0.984, n=6309)
#   ✅ PLS_VIs_453: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_454: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_VIs_455: PLS feature created (r=0.968, n=6309)
#   ✅ PLS_VIs_456: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_VIs_457: PLS feature created (r=0.960, n=6309)
#   ✅ PLS_VIs_458: PLS feature created (r=0.984, n=6309)
#   ✅ PLS_VIs_459: PLS feature created (r=0.968, n=6309)
#   ✅ PLS_VIs_460: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_461: PLS feature created (r=0.970, n=6309)
#   ✅ PLS_VIs_462: PLS feature created (r=-0.958, n=6309)
#   ✅ PLS_VIs_463: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_VIs_464: PLS feature created (r=0.968, n=6309)
#   ✅ PLS_VIs_465: PLS feature created (r=0.972, n=6309)
#   ✅ PLS_VIs_466: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_VIs_467: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_468: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_469: PLS feature created (r=0.987, n=6309)
#   ✅ PLS_VIs_470: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_VIs_471: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_472: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_473: PLS feature created (r=0.990, n=6309)
#   ✅ PLS_VIs_474: PLS feature created (r=-0.978, n=6309)
#   ✅ PLS_VIs_475: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_VIs_476: PLS feature created (r=-0.960, n=6309)
#   ✅ PLS_VIs_477: PLS feature created (r=-0.972, n=6309)
#   ✅ PLS_VIs_478: PLS feature created (r=-0.960, n=6309)
#   ✅ PLS_VIs_479: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_VIs_480: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_VIs_481: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_482: PLS feature created (r=-1.000, n=6309)
#   ✅ PLS_VIs_483: PLS feature created (r=0.995, n=6309)
#   ✅ PLS_VIs_484: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_VIs_485: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_VIs_486: PLS feature created (r=0.964, n=6309)
#   ✅ PLS_VIs_487: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_488: PLS feature created (r=0.962, n=6309)
#   ✅ PLS_VIs_489: PLS feature created (r=0.958, n=6309)
#   ✅ PLS_VIs_490: PLS feature created (r=-0.958, n=6309)
#   ✅ PLS_VIs_491: PLS feature created (r=0.971, n=6309)
#   ✅ PLS_VIs_492: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_VIs_493: PLS feature created (r=0.987, n=6309)
#   ✅ PLS_VIs_494: PLS feature created (r=-0.967, n=6309)
#   ✅ PLS_VIs_495: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_496: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_497: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_VIs_498: PLS feature created (r=0.988, n=6309)
#   ✅ PLS_VIs_499: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_VIs_500: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_VIs_501: PLS feature created (r=-0.988, n=6309)
#   ✅ PLS_VIs_502: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_VIs_503: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_VIs_504: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_505: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_VIs_506: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_VIs_507: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_VIs_508: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_509: PLS feature created (r=0.954, n=6309)
#   ✅ PLS_VIs_510: PLS feature created (r=0.985, n=6309)
#   ✅ PLS_VIs_511: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_VIs_512: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_513: PLS feature created (r=0.955, n=6309)
#   ✅ PLS_VIs_514: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_515: PLS feature created (r=0.984, n=6309)
#   ✅ PLS_VIs_516: PLS feature created (r=0.995, n=6309)
#   ✅ PLS_VIs_517: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_VIs_518: PLS feature created (r=0.988, n=6309)
#   ✅ PLS_VIs_519: PLS feature created (r=0.987, n=6309)
#   ✅ PLS_VIs_520: PLS feature created (r=0.986, n=6309)
#   ✅ PLS_VIs_521: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_522: PLS feature created (r=-0.967, n=6309)
#   ✅ PLS_VIs_523: PLS feature created (r=0.987, n=6309)
#   ✅ PLS_VIs_524: PLS feature created (r=-0.986, n=6309)
#   ✅ PLS_VIs_525: PLS feature created (r=0.992, n=6309)
#   ✅ PLS_VIs_526: PLS feature created (r=0.965, n=6309)
#   ✅ PLS_VIs_527: PLS feature created (r=0.987, n=6309)
#   ✅ PLS_VIs_528: PLS feature created (r=0.991, n=6309)
#   ✅ PLS_VIs_529: PLS feature created (r=-0.974, n=6309)
#   ✅ PLS_VIs_530: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_531: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_532: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_VIs_533: PLS feature created (r=-0.951, n=6309)
#   ✅ PLS_VIs_534: PLS feature created (r=0.998, n=6309)
#   ✅ PLS_VIs_535: PLS feature created (r=0.967, n=6309)
#   ✅ PLS_VIs_536: PLS feature created (r=-1.000, n=6309)
#   ✅ PLS_VIs_537: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_VIs_538: PLS feature created (r=0.969, n=6309)
#   ✅ PLS_VIs_539: PLS feature created (r=0.997, n=6309)
#   ✅ PLS_VIs_540: PLS feature created (r=0.970, n=6309)
#   ✅ PLS_VIs_541: PLS feature created (r=0.957, n=6309)
#   ✅ PLS_VIs_542: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_543: PLS feature created (r=0.950, n=6309)
#   ✅ PLS_VIs_544: PLS feature created (r=-0.967, n=6309)
#   ✅ PLS_VIs_545: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_VIs_546: PLS feature created (r=-0.984, n=6309)
#   ✅ PLS_VIs_547: PLS feature created (r=-0.959, n=6309)
#   ✅ PLS_VIs_548: PLS feature created (r=-0.962, n=6309)
#   ✅ PLS_VIs_549: PLS feature created (r=-0.978, n=6309)
#   ✅ PLS_VIs_550: PLS feature created (r=0.963, n=6309)
#   ✅ PLS_VIs_551: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_VIs_552: PLS feature created (r=0.977, n=6309)
#   ✅ PLS_VIs_553: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_VIs_554: PLS feature created (r=0.952, n=6309)
#   ✅ PLS_VIs_555: PLS feature created (r=0.983, n=6309)
#   ✅ PLS_VIs_556: PLS feature created (r=0.976, n=6309)
#   ✅ PLS_VIs_557: PLS feature created (r=0.996, n=6309)
#   ✅ PLS_VIs_558: PLS feature created (r=0.953, n=6309)
#   ✅ PLS_VIs_559: PLS feature created (r=0.974, n=6309)
#   ✅ PLS_VIs_560: PLS feature created (r=0.986, n=6309)
#   ✅ PLS_VIs_561: PLS feature created (r=0.986, n=6309)
#   ✅ PLS_VIs_562: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_563: PLS feature created (r=-0.966, n=6309)
#   ✅ PLS_VIs_564: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_565: PLS feature created (r=0.959, n=6309)
#   ✅ PLS_VIs_566: PLS feature created (r=0.982, n=6309)
#   ✅ PLS_VIs_567: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_568: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_569: PLS feature created (r=0.978, n=6309)
#   ✅ PLS_VIs_570: PLS feature created (r=0.996, n=6309)
#   ✅ PLS_VIs_571: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_VIs_572: PLS feature created (r=1.000, n=6309)
#   ✅ PLS_VIs_573: PLS feature created (r=0.951, n=6309)
#   ✅ PLS_VIs_574: PLS feature created (r=0.966, n=6309)
#   ✅ PLS_VIs_575: PLS feature created (r=0.981, n=6309)
#   ✅ PLS_VIs_576: PLS feature created (r=0.975, n=6309)
#   ✅ PLS_VIs_577: PLS feature created (r=0.979, n=6309)
#   ✅ PLS_VIs_578: PLS feature created (r=-0.963, n=6309)
#   ✅ PLS_VIs_579: PLS feature created (r=0.959, n=6309)
#
# ✅ Created 821 PLS features
#
# 🔄 Step 6: Creating final dataset...
#
# 🔄 Creating final dataset...
# ✅ Final dataset created:
#    Total features: 1281
#    Original features: 460
#    PLS features: 821
#    Dataset shape: (6309, 1284)
#
# 💾 Step 7: Saving results...
#
# 💾 Saving final results to F:\_____My_Thesies____\_ImpFiles\3. Feature Selection\3.FE_Final\final_dataset_enhanced.csv...
# ✅ Dataset saved successfully: F:\_____My_Thesies____\_ImpFiles\3. Feature Selection\3.FE_Final\final_dataset_enhanced.csv
#    Rows: 6309, Columns: 1284
#
# 📋 Step 8: Saving analysis summary...
#
# 📋 Saving analysis summary...
# ✅ Analysis summary saved: F:\_____My_Thesies____\_ImpFiles\3. Feature Selection\3.FE_Final\enhanced_deltaX_analysis\analysis_summary.txt
#
# 🎉 ENHANCED DELTA-X ANALYSIS COMPLETE!
# 📊 Summary:
#    Original features: 2780
#    Selected features: 460
#    PLS features: 821
#    Final features: 1281
#
# 🎉 Enhanced Delta-X analysis completed successfully!
# Results saved to: F:\_____My_Thesies____\_ImpFiles\3. Feature Selection\3.FE_Final\enhanced_deltaX_analysis
